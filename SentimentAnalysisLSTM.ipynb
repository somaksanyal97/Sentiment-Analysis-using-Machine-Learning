# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.8/dist-packages (2.9.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.28.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.12)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow) (21.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.23.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.12.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow) (3.0.9)

# %%
import numpy as np
import pandas as pd
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords_list = set(stopwords.words('english'))
from numpy import array
from numpy import asarray
from numpy import zeros
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from keras.preprocessing.text import one_hot, Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, GlobalMaxPooling1D, Embedding, Conv1D, LSTM

# %%
dataTrain = pd.read_csv("/content/drive/MyDrive/Sentiment Analysis Project final/Tweets_train.csv")
print(type(dataTrain))
dataValidate = pd.read_csv("/content/drive/MyDrive/Sentiment Analysis Project final/Tweets_dev.csv")
print(dataValidate.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (1318, 3)

# %%
import seaborn as sns
sns.countplot(x='airline_sentiment', data = dataTrain)

# %%
temp = dataTrain.iloc[:,0:2]
temp.head()
# Out:
#              tweet_id                                               text
# 0  569179849518161920                    @united you're good. Thank you!
# 1  569835751275433984  @AmericanAir way to ruin a vacation, my brothe...
# 2  568588936852799488  @JetBlue yes thankfully! Catering just got her...
# 3  569525116725567491  @USAirways The automated message isn't helpful...
# 4  568807823187976193  @JetBlue I'm #MakingLoveOutofNothingAtAll on m...

# %%
TAG_RE = re.compile(r'<[^>]+>')
def remove_tags(text):
    return TAG_RE.sub(' ',text)

# %%
def preprocessing(sentence):
    statement = sentence.lower()
    statement = remove_tags(statement)
    statement = re.sub('[^a-zA-Z]',' ',statement)
    statement = re.sub(r'\s+[a-zA-Z]\s',' ',statement)
    statement = re.sub(r'\s+', ' ', statement)
    #pattern = re.compile(r'\b(' + r'|'.join(stopwords_list) + r')\b\s*')
    statement = [ps.stem(word) for word in statement if not word in set(stopwords_list)]
    statement = ''.join(statement) 
    return statement

# %%
corpus_Train = []
sentences = list(dataTrain['text'])
for x in sentences:
    corpus_Train.append(preprocessing(x))
corpus_Train
# Out:
# [' une u re g hnk u ',
#  ' ercnr w  run vcn  brher h clle ll ngh n h ulple plce n lne nl  ge e r n cll bck',
#  ' jeblue e hnkfull cerng ju g here n nw he re lng bu ver frure w uppe  be here b ',
#  ' urw he ue ege n helpful n  pble  pek wh hun rgh nw eperel nee ur luggge ',
#  ' jeblue  knglveufnhngll n  brnlveffr  lx hp c khruf w',
#  ' ercnr ju wnle he pp fr phne nce rnk cupn bu nhng  ple geng re  fl ',
#  ' une n p lnk  n rcle h verfe he nl cpln wh cen ng he e hng hrr',
#  ' jeblue  n ure f u cn  nhng  help e wh h bu f u cn h be gre ',
#  ' ercnr  bggge  l  flgh cncelle flghle n ge n ccn n even  nher rlne  le ne free hel ',
#  ' urw chrle ff nee prer ppne n repne  hp l f pe ff peple here ',
#  ' urw ugge u flure ke huge nn  he u chrle nc  he prve gre cuer ervce  unlke u ',
#  ' ercnr plee expln wh  c l he e prce f full runrp fr  nl chnge he eprure e f flgh ',
#  ' uhwer  when ur plne en wrk he luxure p fr g w bu u keep  ne nee h bz el ',
#  'elee ur ccun jeblue',
#  ' vrgnerc hve n nereng flng wh u fer h wll cncelle flgh  nex fur flgh plnne neverflvrgnfrbune',
#  ' vrgnerc pple ver week g hven her bck n  flng h week ppne',
#  ' ercnr he  ell h ur luggge e ne he plne lk h ve hp c kkhhqcp',
#  ' uhwer ee lke u cul ke re ne b penng up e n re erble flgh ',
#  ' uhwer ll re f we lre hve ur wnner cngr ',
#  ' uhwer everhng k h   r cll fr he  n h e ve been n hl fr hr ll hng up n r gn ',
#  ' ercnr h exr hur f rvel e e vcn e n nw u gu re eng wh  prfenl lfe ',
#  ' une n ce u re reng h u rgh nw  n verze crrn kng up  uch r enfrce ur rule ',
#  ' uhwer ju  l ngh hnk fr fllwng up ',
#  ' urw l h n help e   eeng  wrk  eeng   preenn w n here jr rke gn e ',
#  ' une h  e n  prner fr rp  nc bugh he cke  he e e plee e u nex  ech her cnf lc hp',
#  ' ercnr re h n cn ge hrugh ',
#  ' vrgnerc n nw he flgh flgh bkng prble e  ll wn flk wh  he prble ',
#  ' vrgnerc prner wh v checku  ble pen eh  help b ble cnvern re elwe pen v',
#  ' urw n un cn w ee u hen',
#  ' jeblue wh re u kng   frekng hr fr e   g hng bu u jebluefl hp c b rbcx',
#  ' urw hve never been ree  prl b n rlne n  lfe  lr fl we  l f flng ',
#  ' une  h pn e  he n  wn ',
#  ' uhwer frunegzne cngr ',
#  ' une lrgh hnk u uch pprece ',
#  ' urw ju relze  ercnr vnge nuber wn ue fr  flgh hw  ge  ff le ',
#  ' jeblue u gu pere wrl cl cpn n fr h hnk u',
#  ' uhwer cnf f fnll g hrugh p l he flgh w cpleel bke h wul hve been beer nf hn ve cll',
#  ' une h wul hve been nce erler   le flgh nw hpe ',
#  ' une wll  ju nee  ge cvg n  bg  hnk',
#  ' une ve never experence wr cuer ervce plcng ble n cehre prner n n ung repnbl  unccepble',
#  ' urw rke gn le flgh crew fr he rp n nennce wrh he exr rp fr le hle n fewer el',
#  ' une fren  hre n cn ge n flgh bc he  n prf he bugh  cl k he h brng p ',
#  ' ercnr we n n he fee we were l we cn chnge ne n cke  ll ',
#  ' urw n hl hr rng  recheule ur flgh cn nne here plee help u ',
#  'hnk uhwer herln',
#  ' une bke flgh fr fr w chrge wce en cn reee cc pn prperl wul hve gne elewhere ',
#  ' une b he w ple plg ge lng w even f   hllw ne  bvu h u n cre bu e r  well beng ',
#  ' une  u hnk here wll prble  newrk nj n ur ue  expece nw ',
#  ' jeblue k cl nee  len  e re n np en rue  l h wul hve been he ',
#  ' jeblue nwhere wr cue  freezng n nc',
#  ' vrgnerc u uck ',
#  ' urw cn bk ung e r f breveen prgr nee  ge he fr  pp funerl',
#  ' urw ercnr ernl n   ll he wr  ell rpr ever hnk fr nhng ',
#  ' une n here  n rec phne nuber fr u ch ek rell regre flgh bkng prble wh une nw ',
#  ' uhwer hw n lef  n ww',
#  ' r jeblue ur flee n fleek hp c ebel',
#  ' une  b fr he wr rlne ve ever h he frune f flng wh n ll he cunre ve flwn   urgeu ',
#  ' une wn hel r n whke ',
#  ' vrgnerc  vng  n rgh nw hp c elbljul ',
#  ' ercnr flgh  been ele ever hur nce  ',
#  ' une well perhp u cul hghlgh where h  e we rvel beween cn p u n une wh nl nexu',
#  ' urw l e eerve  be ele becue bke he l flgh n hen her he nl ncnvence  ng ur flgh ',
#  ' une u cn cl weher wh ur hrwrkng crew pullng e u f plne  he rgh hng bu we bh knw u wn ',
#  ' une en chnge plne he eng ver wng f wne wul hve bke  wll ge frl cpln',
#  ' une l ngh we we frever  he ge becue ene fr crpre pch frg  cll he crew unfrenlke',
#  ' vrgnerc wjere  ur luggge  lw  lx',
#  ' ercnr  g jb verellng h flgh ele nue  eplne he verflw penger bg ',
#  ' une ju ele j cpn n jeff ek  hpefull u p enn nw',
#  ' ercnr gue w ne f he elec few h hn h n prble befre h n ll he uen  whle rp g jcke',
#  ' jeblue f  flgh w ele cn hw up  he rpr wh he pprpre un f e fr he el r  hve  g n e ',
#  ' urw gf w n hl fr hur n cll w rppe help nee flgh ',
#  ' urw  p w l ke  n quen bg gh ll be n flgh hul be e  check when  ln n ele ',
#  ' uhwer pprenl echnc h  be flwn n  fx e plne n he  urng gn',
#  ' une elneprng we ll ee wh we cn  kn we re runnng  f h plne  runnng hnk fr he help ',
#  ' une  wn ',
#  ' urw hve been n hree plne fr flgh n ll hven lef he grun b ervce ',
#  ' ercnr n even n he bg u wll ke cn gn h cpn  ncreble hw rrepnble re wh he cuer',
#  ' uhwer  cncerne h u wll cncelle flgh  flgh u f bn rrw  hul be ',
#  ' une  chngng  legeplu prgr wnner n ler hp c lzk rlne rvel ll rewr',
#  ' une hnk e e fr er l n brken v flgh er  l n ur rlne ',
#  ' urw ercnr be cul  gh ge  refun whn bllng ccle nh f gu kng fr nher chnce  ne',
#  ' une hnk r g rebke lre bu l  fr cl e uch  lfe ',
#  ' une cul rell ue ur help geng ur bg   we re hee  w bu nw gng  xu',
#  ' une when wll h hppen  rell cnfue when he  cnen  ce n he n creen  bu hw echnlg frwr une  ',
#  ' ercnr n pce n  e bu hnk  ur pl  bck n erl  hre n hnk h w pble n r ',
#  ' jeblue cn bk flgh becue f ue frce p n verfe b v nnene help grl u ju wn  ge  xw',
#  ' une hnk ll fll up he fr  n  ln n lke beng upe  hpe u wll pprece  feebck p wll be beer',
#  ' une uck here n h wng n flgh  hnlulu fr hur ue  nennce ue cul we hve gen new plne fl',
#  ' ercnr nuber wll n even le u w fr nex cuer rep ver frurng cn lk  hun ',
#  ' jeblue hvn cub  hre  lve f phgrph n leve pcure behn  well   elver uch neee e flngfrwr',
#  ' une  u fn u where   hnk',
#  ' uhwer chnge ur hl uc gng n hur n  bu  le ',
#  ' une  wh he lun ',
#  ' ercnr b he e he hr pe befre g cll bck he cke w re  wn  ful e h  p exr',
#  ' une wh hven u upe h flgh  ele uper frurng',
#  ' une n chnce u cul lk n  prble fr erler ',
#  ' urw wh chcle flgh plee  elng hp c jjfb',
#  ' une n gu uck ll never fl wh gn n ur upervr uck  ',
#  ' jeblue he helpe e wh  prble  el n w  nce u gu rck ',
#  ' jeblue eh  wre f h hence  rgnl g  u ',
#  ' une ll wng repl fr ur cuer ervce  n repne lu unerlne',
#  ' une wnn be re une rlne lve rplne',
#  ' jeblue wll cll hnk u ',
#  ' uhwer wh  cuer reln ll n pen n ex ',
#  ' jeblue lekvhg wn  ee wh he c wul be  chnge  he flgh',
#  ' jeblue ure el creenh belw lnk hp c qrn j hp c bvvzl e',
#  ' ercnr h  rher clunk prce whever egne h clerl en unern l ',
#  ' une hnk u ',
#  ' une he were ep upn keff wh cn ene  here ',
#  ' ercnr re exreel rue even he upervr n when ke  pek  h upervr w l n',
#  ' urw n p n geng hel h ur rlne wn ge fr n f u even hugh we were l h we ke ur flgh ',
#  ' jeblue h cul be he begnnng f blueful relnhp lfeneefrng',
#  ' une crewng e ver wce n ne nh lerne  len we re hrugh ',
#  ' vrgnerc plu u ve e cercl  he experence ck ',
#  ' urw  he wr nue el n bn n weher rele flgh gng   ur cnnecng flgh gng up he plne ue ',
#  ' uhwer  wful he hve l  bg n ren prvng n nf h   n nhng wrrlneever',
#  ' uhwer when re u gng  be flng n n u f nhvlle he ecer  n re u hr n plne n   rrw rnng ',
#  ' une berccpupp ur pupp   cue we lk frwr  hvng bh f u n br hnk fr he hgh fve e ',
#  ' urw he wr n cuer ervce urw cllng fr ver nh  bk flgh prcuerervce urwffler',
#  ' ercnr  wn rupe  w cncelle flghle rpr gen were hrrenu hrn w ur vur',
#  ' ercnr re u ncpng weher rele flgh cncelle flghn fr fernn eprure u f u  ',
#  ' urw cn u plee rn ur echnc ech he  brng he l  fx he plne wh he n n leve he n he hnger ',
#  ' une wh   f ehng  ng fr  checke bggge ',
#  ' uhwer ennrgn gnergn  huge fn wul lve x  ur hw ',
#  ' uhwer nce gn n glr be plce  wrk nggng verll nurprng luvhe',
#  ' une cugh erler flgh  r ge checke bg n u ve l   hre rgnl flgh ln n nue frurng ',
#  ' une e lhr lunge  fnc f nl he u ne cul be reel lr ',
#  ' jeblue e fr flgh n rln h rnng',
#  ' jeblue hul expec el  c fr  eprure gng  rln n flgh ',
#  ' ercnr k ju receve n el wh  regrn fr ur e hnk l',
#  ' une culn hve pbl ee up ur rp nre hn he  hnk fr beng uch errble rlne ppne',
#  ' ercnr ju when hugh u gu were ne eng up u ke  wre ur rlne run hpe n re ',
#  ' uhwer  n fun hvng el fr nhvlle  l veg bu he crew  he ge ek h been wee pence luvw',
#  ' jeblue hr flgh n rw fr  wfe wh her v n wrkng ',
#  ' ercnr unccepble  cler lng ju ne cuer en er  ercn bu hw n re bnkrupce wll  ke',
#  ' vrgnerc ur bck f e enernen e e n ccep cre cr h hve n prphe n he urne prphefl',
#  ' uhwer receve n errr nlne n hve been n hl fr ver hur cpleel unccepble ',
#  ' jeblue hnk fr replng feel lle beer we ll ee hw  ge ',
#  ' ercnr we n he rpr fr w   ge he n weher rele flgh el wh hrrble cuer ervce fnll wche ',
#  ' jeblue f h w he ce wh  ur ler rrve  le flgh fur hur el n bu  ',
#  ' uhwer vh ju ge he rr cre cr n ge he pn f fl h w',
#  ' urw hnk uggen p he pr ege fer b n ju run uc p g h  cll vlue  hgh vr',
#  ' une hr erchng fr fl fn n e p cn bk he ffere bc eg n rell vlble le fleverng',
#  ' une rc flgh cncelle flghle lve  nw rve he wh n ueful ubue',
#  ' urw hve en leer fer leer n ge bck nhng bu fr leer n hlf bke repl urwuck',
#  ' urw  he wr hve  p ju  n ke  fr flgh n run rp herwe he ll cncelle flgh  whle flgh ',
#  ' jeblue hw uch lnger  jfk pen   bec n nee ugr plne n hve nhng',
#  ' uhwer cn ge n kn f upe n he ele flgh fr bn  hun  rell nee  be bck he ngh ',
#  ' urw knw e flk hve  ue ur rlne bu en cuer ervce ever er rell he  cpln bu  brul ',
#  ' urw hve n gen wh reervn cnc e ne f kng e  we  e b ng n he phne fr hur',
#  ' urw jrexcl hur n hl fe   n ne  wrkng ',
#  'bu re ur flgh enn fuckng h r jeblue ur flee n fleek hp c wgznjcx',
#  ' n e jeblue h n wh u  l ngh hugh ',
#  ' ercnr cn we ge u upe n flgh re we gng  ke  he ngh ',
#  ' jeblue wh  pernl el h cn cnc hve cpln h u hul knw bu',
#  ' uhwer hw ce n ble cn prcee  enerng pce  purche  fr reln n n hve pce ju ',
#  ' une hnk fr ur enn wul cull lke  ke pecfc cpln bu cuer ervce  c wh   be pn ',
#  ' uhwer flgh  fr phl  l cncelle flghle n n hl rebke fr rrw nw h flgh  cncelle flghle n hl gn ',
#  ' une rllnce g be h wll ke up fr lng  elln prbbln',
#  ' urw wll wre cr n ure wh g  ll   he cuer ervce experence w hrrble ',
#  ' urw n flgh wng fr wegh n blnce nf fr he p nue ',
#  ' une hnk fr he upe ',
#  ' urw hve vucher fr p rp h w ele hugh h  lk  ene n he phne  ue   h n rue ',
#  ' une hpng  ge u erler hn nl phne pn r nce wh hel ',
#  ' une h jh e plee nce l l whle  n he w u cul u help e chnge  reurn fr ne  le flghr ',
#  ' uhwer rell lve ur cuer ervce lu nn n phx rck hnk w be urgue',
#  ' ercnr hnk ll lk frwr  he repne ',
#  ' urw n cherr n p flgh w n runw fer we lne n e fr n ll n ge hlf he luggge ',
#  ' vrgnerc ve  e wh n nce beer e  cbn elec n behn he rw elece ppne',
#  ' urw  ck f lvng n n rpr gegeher',
#  ' ercnr wh cn u hnle ur cuer nee cncelle flghle flgh nuber le  quck gbe ver  ',
#  ' une here  n excue fr levng nr  pen he ngh bbng hur n plc chr u cn errble une',
#  ' une fer ll hve been hrugh n h rp cn u ge e n nher rlne he ',
#  'hh jeblue ur flee n fleek hp c knlqbh ',
#  ' uhwer unvel new flgh nclung fr h hp c grkbj bxlk',
#  ' ercnr l hve  w re hn hur befre cn pek  ene n he phne cn w hur ',
#  ' ercnr n wrre n ble u fr weher ',
#  ' jeblue   nl fr  n bg  bg  full ',
#  ' une hnk h  he be fr cl hve ever gen enver  lx n  wnerful ',
#  ' urw e w rebke he nex  we hnk ju upe h l nl wrk  n p fr  wn hel lng',
#  ' une nw h hp c ugew nr',
#  ' urw ng  he ge n flgh fr n hur ue  bre beng wn wh bckup pln  n plce f bre cnn be fxe ',
#  ' une wn  bk ul c fre hve le fr f flgh n pn  p fr  flgh wh le n wh up v hnk ',
#  ' une we bke  he e e n he clle w l cnfre we were lnke even fer he h  ke chnge  h rez ',
#  ' uhwer llw u  chnge flgh nce fr n fee  wll lw bk flgh wh he ercnr chnge u ',
#  ' uhwer fferng u bluel nhng fr ur ruble eher ble he ',
#  ' une u re rell rng e  ',
#  ' urw rvel genc  h f urw ccep we wll refun ne n unern wh n refun',
#  ' ercnr  lkng fr help n urw wr rvel bke fr wfe n w b n e gne ',
#  'rell hur une jennferwlhpr we n lke el n  ll we cn  v he we ll hve u n ur w p',
#  ' urw n rec nuber  ven le ccun nf ever e r he ge cull hung up n',
#  ' une  been bke n fr cl wh curbe elver hur fr nw  cunng n  eu',
#  ' une wll hnk ',
#  ' une wll never fl wh u gn wen n vcn h week n u l  bg bh w nw hve n clhe hnku',
#  ' une  n h wh  ver cncerne ',
#  ' ercnr purche n cbn x fr u flgh w cncelle flghle n w recheule n wh regulr e cre ',
#  ' une we re ng n u geng ele becue he pern cn fn cpn rculu une',
#  ' jeblue ce chllenge ppee penger wll ree he clubn hp c pg  w',
#  ' une pr cbn luggge ervce n u  b w frce  check n even when here w ep pce fr bg n he verhe ',
#  ' uhwer hve  be hne n expec f repne hnk u ff  chber we g ',
#  ' urw k  h r  gvng up   fer nue hl e errble hp c p rpl',
#  ' jeblue rw  cnnue vru cercl relnhp wh lufhn cp vn hp c fhp r',
#  ' uhwer grc pprece h ',
#  ' ercnr  n nee n plg nee u  fx  n cpeen nner ',
#  ' ercnr flgh n epr flp enrue  fwrpr hp c hkvl',
#  ' ercnr n  n he gen rchel wng n rl penel were ver plen n wrl f ch bg hnk u',
#  ' ercnr e n whu  bg fr cl cke  h wul be nce ju ng',
#  ' jeblue ur flee n fleek hp c pulp w h',
#  ' urw h e e hve  cncelle flgh  cr reervn n  ce u  re ne wh  u recheule e whu he crew ',
#  ' une he nqure n hen  nhng bu  preen he re neree repne  ur  n n repne bck ',
#  ' ercnr fgh g cncelle flghe cn help e rebk flgh cll cener   bu  nwer cll r even pu e n hl uck',
#  ' vrgnerc  lgn rpr n wng  checkn fr   flgh checkn ek n pen wh ',
#  ' vrgnerc u hul ll evelp n pp hen u wll be  fvre rlne ',
#  ' uhwer hnk ge h  lk lke ll bw j ervce p fer ug  h he ce cn fn ne e wh flgh ',
#  ' uhwer h  rell unhelpful wh cn  rebk nlne hp c  vl ',
#  ' vrgnerc jezzeglz club vrgn  bupng n new rk hp c hqc gg c',
#  ' ercnr lve he new plne fr he jfk lx run be ne  wll be n ne where he ene ll funcn nchrge ever',
#  ' ercnr hpe u lke he ph hp c fluxegw',
#  ' urw hnk fr geng bck  e clle h nuber erler bu n pn  leve v n ju rng wh bu ne',
#  ' uhwer flgh eer cncelle flghe g  rpr   fr n n e flgh w ele cncelle flghe hn rene whch cue',
#  ' une nhjek une ce h ece  uurce n r puh u re n re f her klle n ll eplee lck f ff',
#  ' une u knw ur upe ever hur ellng e u n knw where  bg re  l equll rrng clngbg',
#  ' une here w hnkng hw cul   n nce hng fer geng upgre bu hen u ele  flgh  k ',
#  ' urw hve w gh cnnecn n chrle n frnkfur',
#  ' jeblue gre hnk u le hpe  cul u plee nf e f flgh leve jfk hnk u gn',
#  ' jeblue h  n ver grcu f jeblue  ell e where cn g bu wer r nck when ur flgh  ele ver hur ',
#  ' uhwer n hnk',
#  ' une hw  u g fr lver ele fr w rgh er  grup ll he e ge n grup bu be r wh up ',
#  ' urw u kn f crewe   up  le  w ubun bu u  ve  b rnng e n renhel rrrewr',
#  ' une  rher hve he ruh bu  flgh hn be frce   here ll  rng  ge he  h hp c ffqhf',
#  ' ercnr  prfng n he blln n hrwng crp  he peple wh pu he here ercn  hurng brn',
#  ' urw nnceebng hur hl e  he en n cunng grce',
#  ' une  en ',
#  ' urw n n ne h been  ll helpful wll never fl h rlne gn nevergn prehewr',
#  ' une wr rlne ever hnk fr he lew f rue gen n ff kng  ele flgh even wre ',
#  ' urw u re bluel errble  ngng hee el been ele n unele n ele e nw  ffce hur ',
#  ' une hw  u lg u f wf n flgh n ee n pn n e p when lggng n help ',
#  'chr elfe jeblue ccrb phlrpr hr everne lk flwle we re  pru f ur phl crew blueher ',
#  ' une cn u n ee he hre ',
#  ' jeblue fgure  u flgh rrw hr  beleve wh l  lw n he kllng ke h even pr f hel cn be cp ',
#  ' ercnr  flgh hrugh ll w cncelle flghle n lke  reervn gen n g new flgh bu hve n receve n el',
#  ' urw hpe flgh  n beng ele becue flgh enn n ce  wrk nbckup',
#  ' jeblue ve experence beer ervce kng cnnecng flgh fr une n ercnr bcuerervce jfk pr',
#  ' uhwer hve n ebe bge n pche uperr  he ne u re currenl ung hp c fq xelbn',
#  ' urw  u  wrk h ken e u f phll ve been n flgh fr b g phl  n e hul hve re e',
#  ' une b hw nee h plne  ge  buffl  cn leve ngh n prgre ',
#  ' vrgnerc hnku he l u rue ke   ',
#  ' ercnr wll  l pe he webe run  her penger ',
#  ' une ehw knew h u w unl w rbrne  repn hck jker nevergn ',
#  ' une w n nh n une cke rerue   ue  weher n jfk cn u ge u he n une r ',
#  ' jeblue u f jfk n ne h nf p n nwer   wh we bre he plne he e  n n wkwr p p everne  crnk',
#  ' jeblue n ge e wrng lve flng wh u v free bg n ecen fre he recen plne prble re ju nnng ',
#  ' uhwer grn l fr lnng  geng bg ne hur h ver  ',
#  ' uhwer herefre nce ve receve n recure hrugh phne hve ube n el cpln p leer v l wll fllw ',
#  ' uhwer plee hre n effcenc cnuln  nge ur phx bggge checkn w  n pen kk wh f ppl wng',
#  ' ercnr cnnbrk he re he re n ng nhng  he wul lk  ewre bu ervng runk rnk hw e h help',
#  ' urw hve been pen epecll he fr e wll never fl wh u gn',
#  ' une when wll el re uerne gn n be vlble  been whle ',
#  ' urw hw bu vng  e  where bugh he nh g h hppen fr  fen ',
#  ' une hnk u pprece he repne',
#  ' ercnr hnew when  ercn rlne r flng  n fr ber w h  he u  ',
#  ' ercnr glfwhw n bu  w he re kng  uch wre wh unerffng ruene n pre rke ke',
#  ' urw  rvelng run he wrl unl he en f he er nuber  e n g ',
#  ' urw n ble  n weher rep  cuner c e enre  n weher prne brng p  le flgh kerepnbl',
#  ' jeblue e n f n ',
#  ' ercnr he flgh  rng  chnge  n hur n ve been rng  rech n gen fr nw h  unbelevble ',
#  ' vrgnerc lgg crreunerw jule nrew fr bu l gg ww e l ngh crre eh ',
#  ' une  ure u wll ffer e nhng fr he ncnvenence u hve pu e hrugh wce h nh wee n cu ',
#  ' jeblue hnk bu ll nnng epecll f   flgh cn wee  he  ',
#  ' une cll w e re ver nue n rpr w e re lnger',
#  ' une u ure e he rk n ngh reee fr lx  chcg wh e u cn  beer ',
#  ' uhwer leennhele w ll eh le fre g plce  fl h n rgh lve where w en fl wh',
#  ' ercnr plee el e  err hl c wllng  cu  experence p gve nher r wul lke  pek recl',
#  ' vrgnerc  b u   ke   v ur cnfrn el when nqure fer week u cl  week ',
#  ' urw hrrble rvel  ur rlne  flgh  brngh w cncelle flghle n nfcn  culn ge n he ',
#  ' une nee he phne nuber  bggge cl n lx   lef her phne n ene clle ng he wul pu  here bu n',
#  ' uhwer hw bu fxng he wf r flgh where  n wrkng ere plne  n lke  n l plne ',
#  ' urw hunre f peple n lne n le hn hlf he ek beng nne  cl help ',
#  ' une bg up he pl f fr urnng hr n he rc  ju n ele rrvl',
#  ' ercnr rng  ge  flgh chnge hrugh ll cllng ur nuber ju  hnk fr cllng n hng up gue  uck',
#  ' uhwer u cul be lle re ccng wh exenng  flgh cre wh exr  nhpprveler',
#  ' urw here  n errr  preferre u p  n ble  rech n gen v phne rvel fr nee relve cnc nf ',
#  ' uhwer gnergn ennrgn cvenger hun rule hp c vhgkzw',
#  ' ercnr  wh f n hve he fun  purche nher cke ur errr wul cue  fl   he funerl',
#  ' uhwer he l e ve rrve lrpr ur ge h been blcke b lw  epr plne leng  n el',
#  ' ercnr ke h hur nw',
#  ' jeblue rlne ruble h wner p n geng g cuer ervce cnc hp c qjn hwnc we nege relun fr u ',
#  ' une hence wh ve been kng fr he cuer ervce phne nuber  cn pek  rel pern  ge h re u',
#  ' urw hnk u fr kng ',
#  ' une he   excellen n  relble hppcuer',
#  ' urw cn ell e f fr cl  jn h gen u f he ge e wll hve gh cnnecn u f cl  c ',
#  ' une f ur r rffc crew cul ge her h geher n ne wul nce he ruene f he grun ff',
#  ' jeblue ur flee n fleek hp c b hvfqb ee wh hp re ',
#  ' urw rn cn  p  ll ff recheule flgh  p   lre ele hw cn he be h b ',
#  ' ercnr nee  be bck he rrw n n ne  helpng e plee help e rebk fr flgh rrw ',
#  ' ercnr flgh enn eenhernnez prve excellen ervce ng peculr cnn hrughu he  ',
#  ' ercnr n u hul  ehng bu everhng hppene eer ',
#  ' ercnr fllw he len p f b prn e hp c uqgw qffu new ecn ungen cl cng hp c pl p hu',
#  ' vrgnerc cn we ke ever vx plne wh nerbr wh hul un be he nl ne geng ner lve ',
#  ' uhwer unern bu  cnen n been cnen fr er  knwn run he cunr ',
#  ' jeblue ur flee n fleek hp c jnkj bc je blzzue n he hzue ',
#  ' urw ercnr we re ng ur cnnecn ue  el u f l wh re we uppe   nw ',
#  ' jeblue ppne we weren llwe  brng n n rcrf pprve cre n n ep plne n cl ',
#  ' ercnr n njrpr  n fr prr bg  rrve nw le flgh fr evenng pln el n bg gurnee nne ',
#  ' uhwer c  he be hnk  fr he b f  her ennrgn wh fren n l hle ee fr',
#  ' ercnr u gu hul rell prve he ervce experence wh ur n e pernnel h h been ne f he wr experence ',
#  ' une rr wrng lnk fr he bg hp c pzl wrez h he ne en',
#  ' ercnr  crg n n helpe ne b cull ene up rvng he ue  exree rgnzn n lck f cuncn ',
#  ' urw u wre ur w e  lk  le gen  lw nue unccepble  le epl cll bck feure ',
#  ' uhwer  en hnk  uch fr repnng ur repne w  el e  ',
#  ' uhwer e wn ge n plne n hl e n he bulkhe fr her fren wh brng pe p erlbr hx',
#  ' jeblue he gc egh bll h never eere e wrng ',
#  ' une hnk u ver uch fr he help we re  pck up  bg pen rpr p re he cng n  n flgh ',
#  ' une lnng n chcg w  nce we were lre rbrne ',
#  ' une hnk u  uch fr ur help wh  brh rp cke re cnfre ',
#  ' uhwer flng bck  enver rrw hul rebk ',
#  ' jeblue ng pnr e  lk lke   ge puhe bck re r  h lkel  ',
#  ' urw le   recl crrele flgh  he chnce f replceen ce knw whch wul c he rlne le ',
#  ' uhwer e fgure n hur w lng enugh e  hl befre gvng up cn eb cll e ',
#  ' urw ve never been ree h bl',
#  ' ercnr wh re cuer vc rep unble  hnle cll  here hr cncelle flghln plc bke eer nee  cncelle flgh',
#  ' ercnr he u n  nerr  n reque n re wh h en ',
#  ' une pprece he fllw up ',
#  ' urw been n hl fr nue n cunng fr nh l chnge fee refun reque fr funerl h  phec ',
#  ' une ur gen n ervce n  weeken rp hve been zng hnk u ',
#  ' une  he wul gve u refun  le flghr n refun ',
#  ' une  feebck n cncern v ur e ren gng  prve  pr rpr experence ',
#  ' une nce gn ur lck f cuer cenrc u unng',
#  ' urw  bu he rel  wh ur ff cn behve ffenvel flgh plee lk n  ege e f u wn prculr',
#  ' ercnr wll  be h er  u hnk ',
#  ' une ju en hnk ',
#  ' une wuln ecrbe fece prnkle n ur bhr  n ncnvenence  help u gh fn  bggge u l p reurn  ',
#  ' uhwer hnk u hve gre peple wrkng fr u ',
#  ' une checke e n hrugh ecur uner he wrng ne n gven he wrng brng p rlneecur',
#  ' jeblue u fun  cer hnk u u rck ',
#  ' uhwer lkng frwr  flng nce gn wh w n fr he luv rlne w w u',
#  ' une el ngener n check ur bggge f u n hve  he wll le  ',
#  ' jeblue ever e lk  he flgh u re nue  e  he el hw bu e pn fr ruble ',
#  ' une  pere er fr newrk  zurch zrh rpr replcng er beween  ep ne ll c vgeek',
#  ' ercnr when  he r  ell wer rlclub ',
#  ' uhwer plee  ehng bu he pee f ur wf cnnecn n ur plne  gh  well be nn exen ',
#  ' rel r jeblue ur flee n fleek hp c erzh kqz',
#  ' urw hrubrg wll r nw uck n rc wng n ge   cnnecn ',
#  ' une hx fr checkng n never g hrugh v phne n hl ver hur hw lng   lng  w n hl ugh cfl',
#  ' urw ju we nher hur f  lfe n hl h  nn here h  be nher w  ue  vucher  pen nlne',
#  ' une g n el ng chnge   legeplu ccun re cnfre bu n ke n chnge help ',
#  ' uhwer here  n pn ju  cncelle flgh n wn  chnge flgh wn  cncelle flgh ',
#  ' uhwer k ur b  bw plne fr flgh  l n pre replceen hur le flghr nw hur ele n hpp ',
#  ' ercnr ve been rng  chnge fr   lx   n rnng hen  fr lx  f  flgh  help',
#  ' uhwer hw ce  n geng  pn fer bu fr he rp rewr hppng e ',
#  ' une unfrunel h b experence flng wh u n ur nple crew b el ',
#  ' uhwer lee ce  ennrgn h unver uen cul ue brek fr ll hee bk ',
#  ' ercnr ll g  cchng he flgh ngh hnk fr he repne ',
#  ' ercnr l n fun  lke lkng  hrnl eenger wh refue  lk  u uele weeffr fl',
#  ' une en  l week re u regrng ur errr n repne w gven plee nwer  r ell e wh  en u  ',
#  ' vrgnerc ele ur cuer ervce e le e knw f u nee he rckng nuber ',
#  ' jeblue ce n lre ele hr n flgh  we we fr he pl  ce fr bn nw u regn h enle rp ',
#  ' urw u ll wrk hr  kng ure hng flw hl keepng pve ',
#  ' urw  wfe lef her phne n flgh we n fr februr h upn lnng n nnepl hw cn we ge  bck hnk ',
#  ' une hnk u en n n rc ',
#  ' une benge he rlne llebeer rrve  lx n n ge hwhpble lw he e hng u',
#  ' uhwer re  rebk nlne bu   h hve  p fr fference n prce plee help',
#  ' ercnr   nw gng  be repre  he plce ue  he exul ul  h u n cre',
#  ' une rb g h fr cl  wfe glbl ervce n h heche ue  ur neghbr kng cgree cnc e pl',
#  ' ercnr new rkeng ng hp c lfulcbq le u knw wh u hnk hp c nbzkhzf v',
#  ' uhwer he e g hru everhng  g nw well n  when he vucher ge hrugh pprece  ',
#  ' jeblue ncenll hel  jfk eerve re becue he wee ',
#  ' une n beleve h u  hp c gqebfk ',
#  ' jeblue where   cng fr hugh p ',
#  ' une n here hugh ercn w b hrrble ervce ver n le flgh n excue ',
#  ' une we re uck  gg lk lke flgh wll be cncelle flghle cn u help ',
#  ' urw  ll nee   n hl hp c  z',
#  ' uhwer lk lke bellg  e g luck peple ee u  he hw  vnl',
#  ' urw w n hl fr hur n ll n nwer  h rell hw u run ur bune hp c xfhq kp',
#  ' ercnr flgh rrw  u plee hnk',
#  ' uhwer  exce  bu perhp u cul cle ur exceen bck b few week ',
#  ' une f cure bu he were ju  helple  everne ele ',
#  ' urw cll vlue re hgh  he be nwer   hng up n e ',
#  ' urw ugh ngh w nue cll n hl ele here n phenx fr w  becue f ne rcrf n re n ccepble',
#  ' urw cn he pu her n p fle ne hnk he n nw wr cuer ervce ever nee  fx  ',
#  ' une wll  hnk ',
#  ' urw n h f n hur flgh crz culn e n phl c ur rgnl cnnecn w n le flgh wh gve phll',
#  ' ercnr h he ee  hve reppere nw ll',
#  ' uhwer hnk ',
#  ' uhwer h experence w he wre flng experence ve ever h  be e cnep fr ur cuer ervce ke  wre',
#  ' urw re u fuckng kng e hp c qjlzrwfj ',
#  ' ercnr gbuckee n w n hl fr hur ff gen ech fferen nfrn frurng kep geng xf ',
#  ' urw en hr le flghr n ll here n r c rpr wng fr  flgh prlhnle urhe hp c fr n ',
#  ' une begnnng f feb clle une he  he wul en nher vucher b l never g nhng refwng',
#  ' ercnr n  n hve he e clle fr bggge u e eer ',
#  ' urw ercnr ju h  bu fe cke nlne u ll refun whchever cke re unue n full whu penl ',
#  ' une frg h nl flgh u f lx n g fr nl ernl ee re check n ever w ',
#  ' uhwer flgh eer n re bu nu n prezel l n rg n he gzne new plce lplcewbeer',
#  ' jeblue receve vucher bu f u wn  prve reln be up frn wh penger ',
#  ' jeblue nl le e f g b n fun he keep geng cre wul uch rher hve wrkng v ',
#  ' une hrlle  hve  crr n checke gn  wll b w n ge gen nl  ee n enre ep bn when bre l ',
#  ' vrgnerc hve l f flgh  bk n ur e  n wrkng ve been n he phne wng fr ver nue ',
#  ' urw ll crcke fr cuer ervce ',
#  ' une re ervce eber lke crp never flng gn wh he unerlne cnn',
#  ' une w  n pn fr f  flgh h p week bu h l ne rell uck h',
#  ' ercnr cn u  nhng  ge  vng been l hr n hunre  jfk upe re n wn  ge  b ',
#  ' une hw  frll cpln bu ur cuer ervce hnler wh cnnece e w ene brng p nw l  bg help ',
#  ' une n wheelchr',
#  ' une flgh rllng el f hur nue',
#  ' ercnr  ll n hl f u re wnerng hur nue n cunng ervcefl nhlfrever ubpl',
#  ' vrgnerc wh  he ren fr he el f he eprure f vx fr jfk h fernn ',
#  ' ercnr rgh  e  cnnecn h hree hur k ver hen u l  bg ',
#  ' uhwer hx fr he fllw up ju en ',
#  ' jeblue n e wh cue he el n flgh fll g jx ',
#  ' uhwer hnk u  uch fr eppng up ur ge n kng   fer ngh f elevr uc uch pprece ',
#  ' une he wr cuer ervce n enver ',
#  ' une h rel ecn p cncern ur plge n fx he ue nr n f he erble ue ve h ver he p  ',
#  ' une hnk he w hvng rugh en b penger fr n erler flgh hng g cnerbl beer hnk ',
#  ' une  w que enjble excep nw he uck n he runw n hun ',
#  ' jeblue hnk u',
#  ' jeblue cncelle flghe ',
#  ' uhwer lve rgn hl fucknf h',
#  ' uhwer u gu re ju beng repecful  h pn lerne  len bu h rlne',
#  ' ercnr fer runnng fr ne flgh becue we h n  ur nex flgh we hen  n ur plne fr n hur ',
#  ' une cn u ell e hw  fle cl fr clhng h h  be purche ',
#  ' une wh  u he ur penger ',
#  ' une hwexper wh  gng n wh une lege prgr u p fr cke n ge frcn f h  pq cre ',
#  ' uhwer  r xl flgh fr clubu h  bn bnlgn n ug vgeek',
#  ' jeblue unern bu everne  fferen hng n here w flgh u le flghr h ngh bu nl ne f u g  ke ',
#  ' vrgnerc ce bck  phl lre we nee u  ke u u f h hrrble cl pleecebck hp c glxfwp nqh',
#  ' une  ur uper cpuer  pn l f crnk peple n lne  ch reflgh bkng prble elng check n f n e rec fler',
#  ' vrgnerc  u  e n wrr we ll be geher ver n ',
#  ' jeblue  n  ke ff n nw we were l hr re el p pble cncelle flghln hw  pln  recf h frure',
#  ' urw even when  ple ggle erch b flgh nuber  ell e whch ge  wn be h ffcul  ure ppne',
#  ' jeblue u gu nee lve ch ',
#  ' jeblue ur flee n fleek hp c rkwugn l u knw whe pern  h',
#  ' une  ne uckng rlne wh errble errble cuer ervce',
#  ' une wh he hl up wh flgh fr lc  en ',
#  ' ercnr he el  nhng bu he pernnel beng  cbve up  he pn f ng wh he hur he plne  n levng',
#  ' ercnr n wche hee bg be bnne  epr ge wche fr g n unl wner reurne n fer repre',
#  ' uhwer e n ne f ur plne hnk fr kng e rzn hp c fnq fh ue',
#  ' une h n  rebke hur fer  rgnl rrvl e we cn lk cpenn ',
#  ' une hnk u we re gne up fr nfcn we hll wch n w ',
#  ' une u gu e   ree e well hnk u ',
#  ' uhwer bu f  bg ke  wh e  greenvlle ngh hen ll  frgven hghhpe',
#  ' une cnn rec ege u u  n fllw u wn  luggge plee hep',
#  ' une lng n ',
#  ' ercnr where  lk fr cbn crew vcnce ',
#  ' ercnr  h he recr lcr ',
#  ' ercnr he hul n nl ge refun bu l n plg fr he eplrble ervce ',
#  ' urw  here n fer w  ge e  club c hn kng e  n cl ver ngh fer  ele flgh ',
#  ' une nue wng  he ge fr he brken jew fferen ge be ',
#  ' une ur ervce uck  exc fr hun u fnll relze h nck n  n wrk u chep  ',
#  ' une hw cn fle cl when ur gen wn le e pek  upervr  cl nuber  expre becue u wn fn  bg',
#  ' une  pq n pq re n lnger hwng up crrecl n  legeplu cc hw cn ge h fxe ',
#  ' ercnr n plge requre e  he fe hnk  u ku   ',
#  ' une when wll u ffer rel f n ercn club lke he zng f u ffer n hehrw ',
#  ' une pprece he enen n u were ble  ge e ff he grun ll e cnnecn',
#  ' urw wh  here n cnc el fr cuer cpln ',
#  ' ercnr urw  nul  njur u gu plce  bg cn beleve u hve  p ne  be ree h prl ',
#  ' une hen wche  cnnecng flgh n en pull w fr he ge nl  pull n he e ge lpnhefce',
#  ' une hnk gh wn  fx h lne ur cuer cre e  currenl repnng   nqure whn bune  ',
#  ' ercnr  n bu he weher  bu he fc h cn ge hl f nne  help bu u cn wee e bck ',
#  ' uhwer n n n w lw fre n n e ervce  gre bu nufcure qurkne  n  uch gne cpveuence',
#  ' urw ele epr bc ur flgh enn wn here hen fer lnng k hr  ge ge nw  nher he n n bg',
#  ' urw e peple n lne hve been wng nue fr cuer ervce repreenve',
#  ' uhwer bre plne nl  be l  ge ff   wn ur plne nw n hur el ',
#  ' uhwer receve wee phne help fr j  helpe e wch run flgh bke wh pn ',
#  ' jeblue   cnfrn ce hnk gn fr ur help   n k pprece  ',
#  ' uhwer rrchr cn u fllw bck fr quck  w fllwe',
#  ' jeblue well nw ng ur flgh  gng  be cncelle flghe p h b n chngng erler we e ur chnce  ge u rrw ',
#  ' jeblue nwhere w fr h nw glbe  wrh n n pl ree ',
#  ' ercnr wh  u rp  cll wh n u hve re peple nwerng phne wh   lw hgh cll vlue when cll',
#  ' une erul fer wng hur n he plne fr  flgh  leve  p hve  leve he plne gre ju gre ',
#  ' urw n epe lwn wll ll be le flgh ',
#  ' une hnk  le n he chcg ffce fr her help n wchng ur cncelle flghe flgh ',
#  ' ercnr k ke n ene h nce u ll gve e free upgre  fr ',
#  ' une u nee  chnge he w cuer ervce  hnle hve been wng fr upervr  cnc e fr  wh gve ',
#  ' ercnr  w l ver n hur le flgh  epr hre n nw we hve n luggge n hpp nng n lng lne  bggge vc',
#  ' urw he nl w     cull nwer he phne ',
#  ' une ur rlne  he bgge jke f n pern n he wrl ',
#  ' une ll f u re n nb n hun rrw fr flgh  clgr f u cul ge u n ne r w f he h wul help',
#  ' ercnr ejcqu f u upe he creen hen peple wul knw he le flgh nf g r b n h wuln wrk becue ',
#  ' une  flgh fr c h been ele p cheule  rrve fer  cnnecn epr wh pn  hve ',
#  ' ercnr flgh nc buen re h been el nce eer  p  gng  ke ff  p nw gve u nwer ',
#  ' urw hnk u ',
#  ' ercnr n nb lne upe nlne r n pp eher  rublng',
#  ' une he flgh urne run fr echncl ren n never  fl une gn  he n check her plne prperl ',
#  ' une ju be hne wh ur cuer he new e re egne  f re rw n he plne re rw re ne ',
#  ' jeblue rk n un w gre hnlng  bg ue hnk',
#  ' une nrener u ll nee  upgre he e  even n ecn plu  lke ng n cncree bench ',
#  ' ercnr rng  check n fr flgh n lne n wrkng p gen  bu  ke  cll ',
#  ' uhwer f rvel vr  pe fr en cn hen ke chnge   cke nhng nee  knw befre cll ',
#  ' uhwer ur phne ervce uck',
#  ' urw ever  n hl n ju le rck f e hp c qhk ljbn',
#  ' une u cn w fr e  n he grun rng  ge  he ge fer we were ve  h  crp ',
#  ' une u gu uck nher cncelle flghe flgh ever flgh wh u h n ue ',
#  ' uhwer en lr perfrng eufr free ll hp c qwfq ql hp c kbb fxk heenfbune',
#  ' urw p  upgre  fr cl wen up  rl club  phx rpr  be urne w becue ur flgh   cun n n c',
#  ' ercnr phec nwer ju fun u  bg h been ng  lg fr hur n n cll fr u  lk r elver f bg b',
#  ' une ur lver nerr w wppe fr lver nerr rell ',
#  ' ercnr we re wng flgh we re  jfk fr bu newrk vrcp ercnrlne hp c fhe lpu',
#  ' ercnr ur flgh   ele u f prvencle n wll be ng ur cnnecn  n   e wh  we cll ',
#  ' une hr  beleve nce ur ff f checke he uner ene b he ne f rc wh flew  ewr he e  ',
#  ' ercnr n wrre u re wpe knw ju  bck hnk u',
#  ' uhwer fe bck n ll ',
#  ' urw e hnk u pprece checkng ',
#  ' une che  n referrl bnu hnk ',
#  ' une fl e  ng hp c xpn xqb une brek gur l l ',
#  ' jeblue nkng hewfhe feel nl few free rvel vucher wll uge  ngnn ',
#  ' une ju cnfre e cr vere beer wn be e nw',
#  ' ercnr nw u ve cncelle flghle  flgh fr prr cke bupe n nw h u re lng cuer peple re furu ',
#  ' jeblue wh up wh he rn el n flgh n chnce f  beng fle lr ',
#  ' urw ble brng p el ',
#  ' jeblue flgh en  jfk lre hr ele n e hw h gh chnge gn ue  weher frec ec ',
#  ' urw we even ffere  fl n  nher rpr n he  he culn  h n explnn wh he cn ',
#  ' uhwer hx fr ur quck repne n cn bf wll ke g ue f he vucher fe hppcuer',
#  ' une he le u cul   ffer e cke n cch ne f ju cncelle flghng  reervn becue f ur glch nfr',
#  ' urw ur flgh w rebke wh u n we wn  chnge ur e r upgre   cl cn u help phne re wn ',
#  ' ercnr llr r cke  chcg e plee ',
#  ' une e u hnk u',
#  ' urw hur n he phne wng fr cll bck  fn  luggge henu',
#  ' urw ll rre h ur well plnne n bke reurn w ee wh p wh n wrnng ',
#  ' uhwer  flgh  g en n cull cncelle flghle been n hl fr ver n hur n ur webe  cnflcng ege',
#  ' ercnr lvng n fw ur hub he hvng  fl  jfk  ge  reln',
#  ' une f cure bu nereng hw une en ee  hve g ene n wh hppenng wh flgh',
#  ' une he fl  r  crrec per     he flgh fr r  cvg w chrge fr ncrrecl',
#  ' urw bg hnk u  ur ckeng gen ue  ulle whngn fr unng gue ervce  ge e rebke',
#  ' jeblue ce ble  ppee penger n wll ree werbur republcn ercn hp c xf pnje',
#  ' ercnr  n nl  bg  he cplee lck f repec when clle w hung up n n    ugher bg',
#  ' uhwer flgh w rrve  flp fllwng flgh fr chellrpr hp c lj kr q',
#  ' urw uner  pl feel  f he ff  n beng enrel ruhful bu he un ',
#  ' ercnr gh h   frurng nb h  re here n he u where re  bg  rgne ',
#  ' uhwer e bu lke nee  luggge befre rrw rnng',
#  ' une knw  ure u her  ll he e n lke he new e  ll gu n feel he new plne re gh',
#  ' uhwer he were ve  he p flgh n cncern nw  luggge rrvng wh he he were l h w w hvng',
#  ' uhwer hx fr he ne flgh w cncelle flghle n   ll bke  h  g wh nher crrer ',
#  ' urw hee chnge  well  le flghr fn u h he flgh w cheule fr n re',
#  ' urw ell reervn  rebk e fr  ',
#  ' jeblue  u hnk nw n bn n wll effec  flgh ',
#  ' jeblue  flgh  ele n  cnnecng fr bn   pble  wch e  flgh  cn ke  cnnecn ',
#  ' ercnr cncelle flghle  flgh fr rrw n ell e  cll reervn bu hen refue  ke  cll n cl heful',
#  ' une wh cn  ge brng p fr  urn rlne cehre flgh rebk ncl hur lver p  uck ue ec',
#  ' une wr uneflghever u   l echncl prble wche rcrf ele hur ',
#  ' jeblue plng n gfng re cpleel fferen huln hve  be chrge  en pn  gung ',
#  ' ercnr e bu u re ll hun hpe elng wh ll he hrrr re peple hre cplne   everne hul',
#  ' uhwer rng    g n he flgh bu cn ge hrugh ',
#  ' une rkrk wh e u ce  h cn we help u wh nhng jp free cke fr he cnvnce ',
#  ' une  u knw hw  ue wer br ur ernl lk lke  n bn here nher pc hp c nwr kb',
#  ' urw  lve hp c jrwpkk nc ',
#  ' urw rlelber ww u wuln ',
#  ' une u fle e l week  h nex nl rp n el ll ul flgh fr lx bke h  ',
#  ' uhwer g  cvere hnk ',
#  ' une re ur ernng  lw h checkn peple hve  l be n rc lng bg jn',
#  ' uhwer  h wh hppen when ur pwer level ge ver fee n he r ',
#  ' jeblue l week bugh plne cke run rp  fl p ju fun lk  he prce f he  n he wen wn nhpp',
#  ' une cuer ervce  he wr hngng up n cuer nennll fer ne hur n hl ',
#  ' urw prble wh flgh n gnevlle u rw  cl wll  cnnecng flgh   when cn ge nher flgh',
#  ' urw he le u cul   ke up fr wh u hve cue u re runng peple ere u hul be he ',
#  ' une p pckng n u cle hp c vqe l ',
#  ' uhwer wh re u he nl rlne  cncelle flgh ll flgh n bn been rne n phll fr  hpng  ge u n he ',
#  ' ercnr he en hve wer ',
#  ' ercnr  h  e n prve n flgh wf n he rue  chn be n e feerl lw bu une e wh  h ',
#  ' une wke up  nfcn flgh ve hr erl brel e flgh hen hr lver n f wne  hp n erler pn',
#  ' urw  rell g  eferrng repnbl ',
#  ' urw h u l  fher wheelchr ever e we cll we ju ge vcel   nee   g he plee  e ',
#  ' une h wul help r hw bu negre  n he pp  cn ju cve  n urf ',
#  ' ercnr fwrpr u geher re he be pr f flng ',
#  ' ercnr h wh  n  cke n  cnfrn el nhng ele ',
#  ' uhwer he here cn u fllw u  we cn  u quen ',
#  ' ercnr ver he l er f  flgh hve been ele r cncelle flghle  ne wh u ',
#  ' ercnr ve been rng  rech ur cuer ervce fr w  hve receve zer repne never rvelng  gn ',
#  ' jeblue hpe ur e wn hcke cue ene ele ppr nf w n  reervn p culn ge  brng p',
#  ' vrgnerc  lve  knw wh ur plc  fr ge luggge ',
#  ' une  n fl une wh checke bggge  wll never fn u ',
#  ' jeblue hnk u fr he refun f he chnge fee fr recen flgh ffece b ur bzrre wner excellen cuer ervce n fcu',
#  ' ercnr rlelhun recr re g el we culn ge recheule n nher flgh bu n knw f flgh  cncelle flghle',
#  ' uhwer  n flgh w cncelle flghle  w n hl hur  n vl cn u help e rebk ',
#  ' ercnr hnk fr fllwng up  fnll wrke fnger cre he new flgh wrk ',
#  ' une n flgh  rrw ',
#  ' jeblue wee berlneever',
#  ' urw ur ervce h been wful n bn n h  p exr llr hn w uppe   ver fe ',
#  ' ercnr  fl  fr g cncle n cn ge hl f cr  cn ge lerne rrngeen plz help',
#  ' urw hnk fr he nfrn ',
#  ' jeblue u never g  wfe  her enn n u expec gwll cre wll ke everhng hunk r u blew  ',
#  ' uhwer gree r new ne rlne  he fl w fvre   newbune hp c wln',
#  ' jeblue wee hnk hnk fr he quck repne u gu rck ',
#  ' urw wll hee prce be hnre ve we h hur n hl  ke ure cn ll ge he prce rgnll re',
#  ' urw cle  flgh cncelle flghe becue phl runw n g bu el flgh  e exc e  kng ff n e ',
#  ' ercnr hnk fr hrng hee ph run f pplue fr ur crew we pprece ll her hr wrk ',
#  ' urw recenl ve n g new lcene n when bke  flgh nh g ue  l lcene  nee  chnge h ',
#  ' une  pplle  ur lck f cuncn urng ur wful jurne n ewr  b hr el nee  be explne beer ',
#  ' urw e cn p u f pcke h u n helpng e fr lng  fr cl cke  cch wn relun r cp',
#  ' ercnr here u g hp c  veg ',
#  ' urw  here nuber  cll  f reervn plee help ver frurng wh ercn n u r erger',
#  ' urw lre plnnng  lcl bc fr whngn c re ',
#  ' uhwer f u re gng  chrge fr wf  u ll l n ke ure  en ke he lengh f he flgh  pen pge',
#  ' une gre jb lng ne f  x bg n rec flgh n knw hw u nge    ',
#  ' ercnr ju k ff ng wh ene wh  cheule n buen re u f jfk n re f he wll ke  h hlng plne ',
#  ' urw ercnr l ur n hl ege  rng  ell vlenne  gf ver week le flgh un bu rgh fr ur',
#  ' une verbke b ff peple he wr ',
#  ' urw kernhn nee w ngh  hel n phenx unl he cn ge bck  phll becue f plne equpen crz ',
#  ' jeblue when  n p cheule e n eprure n gh flgh n lnger qulfe  n e upeurwebe ',
#  ' uhwer hw   n pble  cll w n he phne u pu e n hl fr n hur n hen cu e ff ',
#  ' urw ercnr vlln prve u he be lgc experence fr peple ll ver n ub ur nvub',
#  ' ercnr ercnvew he vew f regn fr e flgh  hp c jbn wzq',
#  ' une  cwrker h h he e cnflc  e wh he hel ue rng  hre pe n her fcebk pge n he ere  ',
#  ' une  exce w pu n n erler flgh  ge he w h rvel ',
#  ' urw ur rue ff  n cre h we re u f rke plce f u re gng n vcn n hve  wrk nce huh',
#  ' jeblue ur gen l u  n hve crew  ge bg ',
#  ' uhwer krju k we wll hnk u ',
#  ' jeblue rng  chrge u llr ch fr cke we p fr nh n vnce hrel neverlu jeblue nevergn',
#  ' urw  he e nex  e n flgh  ele h r ble h  fllng ff hp c hj lkqjw ',
#  ' jeblue frenl enggng pernble hnle clrfng quen bu bggge fee well n k n nere n wh w ng ',
#  ' une h  been hr e ',
#  ' uhwer  h urrwchuck',
#  ' ercnr u pu ur e n h cuer vcn  w jke wchng he we cre hnk fr chng u ve',
#  ' vrgnerc h gew el hrugh  fr ne w l f cl ce hp c x g chepflgh frecpre',
#  ' vrgnerc cn u gve e lver u fr nh ',
#  ' uhwer pke  n  bg w l ',
#  ' une receve n her flgh une rul brek gur unebrekgur wnnebck',
#  ' ercnr he lvr freeze prble wh nrgen lne lw re wh he nflng equpen lfuncnng  n ',
#  ' jeblue wh n ju ke her nf n he begnnng n f cu ff cll bck we  h n  ecl prcce we re frequen fler ',
#  ' une wh gng n wh he lege plu ccun lgn hrugh uerne n el hve been wn fr  le hree  ',
#  ' uhwer cn u hve ene cll e bck hve been n hl w e  fr ver n n ll hven gen hrugh',
#  ' uhwer wul be gre f le w nex   hubn wh  flng n he e reervn',
#  ' uhwer ju en  ver',
#  ' uhwer pre errble cuer ervce  n hl n hen bu gnl hen cnnece  ll rlne hve  uck ',
#  ' jeblue  unn n grgeu n n cull wh he rel ren ',
#  ' une f fw l f r',
#  ' uhwer ju g ne nw where  g ',
#  ' uhwer n flgh u f nhvlle  re u kng e wh re her rlne flng n u re n  frure ',
#  ' urw hve nw clle e n he l hree  h unccepble  wllng  w n hl bu h n n pn ',
#  ' jeblue cn ee   u gu jhp',
#  ' jeblue well he  cncelle flgh n he p e gue he re rng  ge plne fr bn n n cnfre',
#  ' jeblue en n el re hn hur g kng few quen ll n repne nee nwer befre hpefull flgh bkng prble flgh ',
#  ' une  w n u lx  en we re cheule  ln lx  plee rebk  enver be flgh',
#  ' urw hur n cunng wh kn f rvel vucher  ge fr h ',
#  ' ercnr f h  hw u gu wrk hen wll never fl wh u gu gn ',
#  ' ercnr  crg n ge gen n nl p upe fr hur hne  bnnen hrrble experence fr ll penger ',
#  ' r jeblue ur flee n fleek hp c lzqwe ',
#  ' urw wll  knwn rveler n rnfer ver fr ercnr when check n   n  ele cn ge chce e ',
#  ' une checke n brngp n checkn bgge gue  ll e ',
#  ' uhwer hevenlchc   le enj free cckl r w ',
#  ' jeblue hnk u  u ll   uch  h he lnk  he blg r h h chnge ',
#  ' vrgnerc  flgh cncelle flghle n wh   f   ',
#  ' urw never e rewr reervn becue n ne ever nwere he phne he nlne ne e g cncelle flghe n cn chnge',
#  ' une ju exe e   flgh  ele ue  r rffc cnrl b he pulle he plne n le flgh le',
#  ' ercnr flgh cncelle flghle webe   cll phne nuber phne   check nlne hw  uppe  ge e help ',
#  ' urw u rw cr  phenx rpr fxe he prble',
#  ' urw we ve flgh been ng n he rc f c fr whle nw wng n ge cn we ju ue nher ge ',
#  ' uhwer  hubn  repnng  h n he n  reve h fr he e bw gn re n bh englh n pnh ',
#  ' jeblue vrlech cree nunl qul chne rven jeblue revenue precve nlc n frec ung publc bg  ',
#  ' ercnr hnk flgh  gre crew ',
#  'nl bz  clenr  repn   nqur une hpe ur nr re unverll pe bcuerervce',
#  ' ercnr ',
#  ' urw here  n exree weher n  pck up he phne hre re peple ',
#  ' jeblue unern h bu h plc f rgeng ur penger  n g fr bune n hul be ree wh ecur',
#  ' uhwer hve een n f he ege he p hur ',
#  ' ercnr ene  n crrece  cpln v wer wh h  he brve new wrl we lve n hnk u ercn r ',
#  ' jeblue unern bu wh u wul hve nnunce he el hur erler v ng fr hr  c',
#  ' uhwer hnk u fr ur e ',
#  ' ercnr cnnue  wn ve never e flgh befre bu nce lle que ge chnge e  pble heeh ',
#  ' uhwer cn plee g ee gnergn n fr pre ll nl fl uhwe when gng bck he  nh hfrlfe',
#  ' jeblue reeber  ver ubful n n ver hpeful ',
#  ' une flgh fr r culn le e knw bu h fun u v pp nue befre lnng wful flgh hp c qjl vz ',
#  ' uhwer prve  cuz he uhwe peple here n even knw wh  behn cheule ',
#  ' urw he le flghr flgh  chrlen  levng befre he flgh cheule erler h  wrng',
#  ' uhwer we n nhng w rune ju we ju frurng when fer rvelng fr hur u cn chnge n clen clhe',
#  ' jeblue hnk pprece ur prp repne ',
#  ' une nw we re rng  ge  n jun fr chcg hre hvng l f prble  ge nb flgh ',
#  ' une nce gn u gu n le e wn fur hur el  hnlulu fr hun hnk fr he rn wreck f ue nw cng',
#  ' une jeehbl kp  n rvelng we rng  cheer up  bl ',
#  ' une h he be cuer experence v wer huge fn ',
#  ' jeblue ge un ue  weher n k n he re bu bu h  crz',
#  ' une hnk fr hvng chnge e nge  rrve wh nl hur f el n exhue',
#  ' uhwer w n hl fr ver hur n  cll g cnnece hnk l ',
#  ' urw fer hr f rng  rech rel hun fnll  n been n hl fr hr fr u f nch reervn ',
#  ' urw h hrrble experence flng fr neg b  phlelph n check glf bg cnn ellng n flgh',
#  ' urw been n hl fr re hn hur h fer n geng hrugh fer hur n hl h rnng wh n nwer help ',
#  ' uhwer ure  l re n here h uhwe en beleve   lble fr he ncen hw    ful h w l  ',
#  ' urw gl peple cn pu her c n he rge re hugh  wul be uper unfrune  leve he n he flr',
#  ' ercnr n p f h  nlne recr w unvlble  well n hen culn ge nne n he phne ',
#  ' urw wh hven u ue rvel vr fr chrle wene ngh n hur nche f nw ',
#  ' ercnr cn u help wh  cncelle flghle flgh  lke  bk nher flgh ve been n hl fr nue n cunng ',
#  ' uhwer hw  knw h  nfrn  n fun n her peple ccun cn ee ene ele reervn rr n rp',
#  ' jeblue plee ce  nnpl ',
#  ' ercnr ure   runnng vern ',
#  ' urw cn u plee p w e hve been n hl fr w hur',
#  ' une n nee  ke n chnge reerve  e when bugh  cke n here w n errr p nw here re n cp e',
#  ' uhwer when wll w reurn  cuer ervce bune rveler e w nw w gnre u ',
#  ' urw  pre hlru h u wn weengr  fnh h wful experence befre ng ehng ke  rgh nw ',
#  ' une ble weher ll n wn n n clu n he k ele bh w ru kng e  chrge e fr lb el ',
#  'wh we cn hve nce hng r jeblue ur flee n fleek hp c hp rppcvhx',
#  ' urw gng  ncheer uk nw  gng   weng u gng  rebk h  wh hve u chen  cncelle flgh  flgh ',
#  ' ercnr eprure ure  here cerng rke  jfk fxnew cnbc blbergr hp c hpgxzrw ',
#  ' ercnr ve g b flgh  ur rpr culn cce u we were lef whu n nf n vucher fr f nhng ',
#  ' une re he le gng  be rerucure help lver u brh u hugh w wnnng wh u gu unl  ll',
#  ' ercnr cn ene cnc e bu  wful experence wh ercn rlne h weeken',
#  ' uhwer wh e he cuer ervce hve rher ncnen nfrn',
#  ' jeblue nh g h flgh bke bu hen h  cncelle flgh   nw flgh bkng prble epre flgh fr fferen ccn ',
#  ' urw g hrugh n  ble  wch  flgh wh n chrge hnk u',
#  ' ercnr  been hur n ll n cll n nw we re bck  beng hung up n b n ue e ercnrlne',
#  ' ercnr  b  ',
#  ' une r ge n fl reeber when cuer were vluble    hr  be nce  ene luggng gur p crrn ',
#  ' jeblue rpr ce e g lc b c',
#  ' jeblue lr ',
#  ' jeblue rgh nw cpleel pe ff',
#  ' urw rell hr el n vrgn ln n n even f vucher ',
#  ' ercnr rng  chnge flgh v fw rrw cn ge hru n phne lng w hen cu ff cn u help plee ',
#  ' une bugh run rp  chcg w  g  he e flgh  hlf h  here n w fr e  ge h cun ',
#  ' jeblue re h e runnng fr curb e  elf check p wng even re e ene up flgh bkng prble une fr   upe',
#  ' une uck n r becue une cn fn her rplne ll upe ernl rgh nw ',
#  ' ercnr check  plee ',
#  ' vrgnerc lve  cn w fr n reurn flgh l ju  wch he nflgh fe ve gn rrnrr',
#  ' une le plee',
#  ' urw geng exreel frure he phne nlne ervce fr ergng frequen fler le ',
#  ' une we ve been here nce  n u ve cncelle flghle ur flgh wce',
#  ' ercnr hnk  ur rlne nw hve rune bg n u refue   nhng bu  ',
#  ' une w rebke hwever  wul hve been nce n  hve  w n exr n  he rpr hw wll u ke h rgh ',
#  ' une hnk fnll e  e eeng bu wh cn  nw ',
#  ' jeblue rxgl hh u n ppn well ne jvch',
#  ' urw hve h ecl ue le flgh eer n nee  chnge  flgh  been n hl fr n hur n ll n hrugh',
#  ' jeblue hnk u  exce  fl wh u fr he fr e ',
#  ' une  ffcll  fvre rlne he hve cree gc fr e ll  frenlke cren',
#  ' ercnr prbbl h ne n bennhenern he   hell wh cwbcerrne ll',
#  ' urw wr rp ever wh pl wul ve le e ff plne  p urng  el nw p n ll ng n runw ',
#  ' uhwer ne',
#  ' uhwer krkwger h hw e he crbben un hp c  vg l wr hnk ',
#  ' ercnr flgh cncelle flghle cn g he unl rrw cul ue nner n pl ercnr   fr e n nc ',
#  ' uhwer we re hvng rel ue rng  ge hru  u n hl fr hur p g cnnece plee help ',
#  ' une hnk fr ur repne bg ce bu  w lng w n prr g weren hnre  ll ppnng',
#  ' une h f cure n lx',
#  ' ercnr plee cll u bck  rebk we nee  ge bck  clubu plee help',
#  ' urw wh  u cncelle flgh flgh  phl whle el flew flgh  he e e n e u cncelle flghe fr n ren',
#  ' ercnr urw nee  be repre  he bbb e fr her cplee regr fr png cuer nflwhhe',
#  ' une hnk fr h vce  helpful cn beleve u gu cull chrge peple  fl une',
#  ' urw wll hll ee n he nex cuple f nue ',
#  ' jeblue lf ',
#  ' ercnr u hell ',
#  ' une flgh rrve  flp fllwng flgh fr h hp c rvc nne',
#  ' une he lnk n he ege w replng  hpr prble',
#  ' urw fuckng he ur cuer ervce ve been n hl ll rnng rng  fgure u wh u cncelle flghe  flgh ',
#  ' vrgnerc lghng  he nl w  fl be experence ever cl n clng ln',
#  ' uhwer fr grup  grup we hve never g   nex  ech her n n uh we flgh n even n ur hne n',
#  ' ercnr hnk  uch ',
#  ' ercnr plee r  urelf cll n ee wh hppen hen u ll unern llrepreenvebu npn',
#  ' ercnr fer beng pen bu  ele bg fr week w l h  cul ke nher  week unccepble ',
#  ' ercnr  wfe p nfn ugher re n  b fw en rue bu ele cn ll hl   ru  he cn cnnec ',
#  ' uhwer  b w eer n  grl gve brh   fr brn n culn ge cure flgh chnge fr lnn hnk ',
#  ' jeblue  ff e  helge hul be fun  eneelw nrewbg ccleverl hece herpllck',
#  ' jeblue wh ele n h plne  uc pe hb hulgeunpuh rplne flng hp c zvzurlw',
#  ' ercnr lve he rl club hnk he cn u fllw e ',
# ...
#  ' jeblue een n lufhn ncenve ffer ckhue hp c bf jbpc ',
#  ' jeblue ehng  hnk bu when u re elng wh peple ju wrng n excue fgure  u p expec he unexpece',
#  ' ercnr h ele bg w fr  fren l pfe he g her bg fer  n c rc ue n upe n ur e ',
#  ' ercnr fer everl  cuncn w ble  ge  r bu  n he e n n ure wll ge here ue  her errr',
#  ' une ur bg  r  n be  he rpr unfrunel n ne  he rpr  pckng up he phne r repnng  ege ',
#  ' une  uch nf  hre v wee plee en e ur ne n cnc nf hpp  uppl u wh ge n c rep ne ',
#  ' urw h  rculu plnebrken cn w  br h ne he hur le flghr neverne brul pb',
#  ' une reurne fr vcn wen  luggge ervce glf bg w preene n cler wrp h cul ve been ue n he fr plce ',
#  ' jeblue n bggge crew upe ur ff  ncpeen wh n nwer fer hur ',
#  ' urw ur ervce n phll  unccepble lk n beer ervce r l huln hve hr e hp c wkr j',
#  ' urw  upe wh cuer ervce hve ple quen n he phne e h cnnece e ll   n eer ',
#  ' une gg  rr une n ble  keep  wr cuz her   ll neque bu he ll    cuer ful ',
#  ' urw  flgh bkng prble l ju e u when elec  uner nge  flgh bkng prble fr nh nw hve ele bu n repne help ',
#  ' ercnr ve been rng  ge hrugh  reervn nce eer  ke chnge  reervn hl when wll  be up ',
#  ' une cull we ren ll prke here ',
#  ' urw erul  u n ee h ve pen  fr ulple hur n hl ju  hve  hng up fer he hur ',
#  ' urw  u cncelle flghle  flgh gn re u png fr  hel ',
#  ' urw we g ur bg  hnk ',
#  ' une u huln pge he h  be  cll n hl n',
#  ' ercnr hnk fr he  recheulng unfrunel ur pern prce  lx  ch p he rep refue  prn he cke',
#  ' uhwer lvvpr n bece be fren bcuz f gnergn  here n her w ',
#  ' urw pln chnge  h wh cll n ben ble prk n e plne  hr lver b ble ke ur cnnecn erul',
#  ' jeblue flngfrwr perer clb  help he k fr crg ree n elver l f clhe h hve pcke  ne ',
#  ' urw ju  fllw up here   experence hp c wjgzwg',
#  ' ercnr uljc wh   gng    fx her uerl ebrrng cuer ervce u wn even nwer he ng phne ',
#  ' uhwer lk frwr  he rec flgh  clfrn  ee  fl re fen hnk u chelbclen bebeurlne',
#  ' uhwer  ju he prncple  hr  ge ugge p n be upe u k  ne p n gve e nhng wrngwrng',
#  ' ercnr u hul be cncng her fr refun  e n wll prve phne nuber',
#  ' une hnk kp wh gng n ngh b upe nlne n phne cn u gve cuer g nf n we her e ',
#  ' jeblue h  enugh fr e  p flng jeblue ',
#  ' ercnr ll ge  n ue e h hng up n e fnll ge ege h e wll cll e bck n hur ',
#  ' urw ur  k ur plne p gve   ene ele fuger flgh fr phll  rln',
#  ' ercnr we wll n be flng wh u r u r gn he chnge n cncelle flghn leng up   bg fnle  unccepble ',
#  ' vrgnerc requee wnw e n cnfre wnw bu g uck n le e n g w  re lver eber ',
#  ' uhwer wh  ur w ge hve  n fewer e hn ur plne ',
#  ' uhwer  fren fr bn uck n enver her ne jne rnchll plee cnc her ',
#  ' uhwer wll n hve  ppr n e fr  rp cul ll fl wh ph  hnghulknw feelub',
#  ' une ju bke flgh fr when vew  reervn  h  cnnece  fr ne  h prble cn  be chnge ',
#  ' jeblue fer n he ell u he cn check eperure fr  le re hur   bck  he ge  w cfl',
#  ' uhwer gruch bu h flgh cplenrbevergeneee',
#  ' jeblue h wh we ve been l hwever hw wul h wrk f u re gng vere b lne  penger feel  f here ',
#  ' jeblue cn prbbl fn e f he re he cke n here ',
#  'p h ne r jeblue ur flee n fleek hp c ubj fv',
#  'n jeblue ju n jeblue ur flee n fleek hp c b pg zq ',
#  ' jeblue here w clure peple here nee  nfr penger n en he ge  ge n nf n br re upe eprure',
#  ' jeblue uhwer vrgnerc ercnrbr wnl jek he ercn pp fr r rveler',
#  'hnk une rn h quen bu he w e fr bggge n u ',
#  ' jeblue ervce geng wre n wre plne cn fl wng n n rcrf  uch fr plnnng ',
#  ' jeblue f u cn ge u n flgh  veque ll wll be g rgh nw n lkng prng ',
#  ' urw f ng he u ',
#  ' ercnr plee pr fr u h ur ger  n l r len ue  ur ncpeen eplee cnn bcnew nbc phgrph',
#  ' ercnr f  n  bckpck wh  nee  ee gen ',
#  ' uhwer ren u be n chcg wh re u ng hun n l n n ur he c plee brng ne he',
#  ' une perfecble efnel n n wr fr epler f he er une ',
#  ' jeblue clle je blue  ge n explnn n ke ure  wul n hppen n he fuure w l  wre he fru ep ',
#  ' une w ervce gen hung up n e he hr w ble  ge e flgh n u r  hree cll n hur  ge flgh',
#  ' ercnr  n n cll bg r nne  pck up  cll hel n ph l  n hlng gn nw nne help',
#  ' urw ercnr when  u r wchng    pp  pp  uch beer ',
#  ' une plee u ve  e n l  upgre h e hve cke n  hn fr l',
#  ' ercnr une wre bck ng  been chllengng week h fr ure n h ',
#  ' uhwer rng  ge hrugh  cu reln  here nher  ue ',
#  ' urw bg hnk  he ge gen fl keepng u nfre f he el grecuerervce',
#  ' uhwer g hng we nce becue he h re rue l penger n n pble rple cnnecn  well',
#  ' urw plee cn ene cnc e regrng  ng bg  h been  nlne rckng hw nhng ',
#  ' urw u cn en  luggge   hue ',
#  ' urw pl ple  le brng begn fr full flgh whle wng fr h flgh enn ene b n cnrl grrrr',
#  ' jeblue new ce eek he rgh blnce  plee penger n wll weburn revew hp c rqjcvq ',
#  ' urw  vcn buge w blwn bc f he lck f cuncn fr urw wll never ue he gn r refer nne ',
#  ' urw gue he nl repn  cplen rr cn hnk f even ne ',
#  ' urw wul hnk f were gng  cncelle flgh  flgh u rebk ur e  ehng her hn he l rw urwfl',
#  ' urw ge ur c geher r reng ur penger kner hve re nze plne ke pge fr el perhp ',
#  ' ercnr nrew wl we re rr u were uncfrble nrew wh cn we  fr u ',
#  ' une re n re el n c help  ll n nfcn ',
#  ' uhwer hve never been r ppne n cpn chrgng  ue ur wf whch nl wrk fr bu pp prhec',
#  ' une h  epcble pke  n ff peple p everne  ellng e ehng fferen hve cl n nee  bg nw',
#  ' ercnr becue f u  ng he ne hng re  v hnk u fr enng e  bggge cl ',
#  ' jeblue he chr cul ue e lc n re pwer ule n he re wul be bnu hee  unverlrl ',
#  ' jeblue ercnr h h re he en e  beng n hnk fr clrfng ',
#  ' ercnr fl weekl wh u n hven een ne',
#  ' jeblue e f cure befre lef he rpr kep lkng bu cl  ll pen ',
#  ' uhwer h ju g ege h pr f  flgh  cncelle flghle cn rebk nlne n nb nwer  phne cll help e',
#  ' une h hppene n her rlne n he ve gven u flgh vucher n been re rnpren bu he prble ',
#  ' uhwer fjbfc ll nee  recep hwng he chrge hve n  ex n he xx h keep geng en',
#  ' ercnr fle pr wh n gen  nnpl rpr unble  pull up nfrn nlne n ur e hve e el ',
#  ' ercnr urw  pregnn wh wn n u re gng  bnn e verngh n n rpr n hel when  ur ful ',
#  ' une  wfe n wll be hrng h reful experence n preen u cre bu ung grl rvelng lne une rlne',
#  ' une   cur  upgre flgh enn n unfr v penger ne  n n fl nw  h',
#  ' une u plee  n burn  re burnngn cke le  ',
#  ' urw never gne  wul be  hr  pen ne hrugh u r ubbrnl hpng ene wll ce bck  he phne ',
#  ' urw l bg cn rech hun elver rver  he wn gve u cre unl we reurn lner we hv n lnr help',
#  ' une nee  lk wh n cul pern bu ng luggge plee ve n hw  ke h hppen ',
#  ' ercnr   r  prcpe  rc fcl repreenng cnere urrhere',
#  ' uhwer n webe  cnc rlne fr flgh rrw  l n hl fr ver n hur cn u gve e n re nf ',
#  ' urw he  n ur phne e when wng fr rep  he  nnng hng ever epecll when wng fr ver n ',
#  ' uhwer  u hnk he flgh u f nhvlle wll be cncelle flghe rrw ',
#  ' jeblue e well he re perng ue f ur ernl n rgeng vulnerble penger n beer hn heve ',
#  ' ercnr hnk u  uch pprece we hve been n he plne fr n nw  he ge ',
#  ' uhwer h he be cuer ervce ',
#  ' jeblue  c h uer n help lcl uh ge re  reurn  chl wh h refreher cure flfrwr',
#  ' jeblue hnk u fr cre hwever ube cpln bu he prper n vcn pckge hpe u len ',
#  ' ercnr b he u ll',
#  ' ercnr wh wh ur bggge hnler cllng u  fw  n luggge nbr he plne ',
#  ' une k cre f  elf h  ren cr n rve hur  rereve  belngng ue  une errr ',
#  ' urw ure bng ever flgh ve ken  ele wr rlne ever ',
#  ' une u re rgh g u cugh he echncl flure  b here re n blnke bu k ',
#  ' uhwer hve been ng h fr hur lre',
#  'll gre nwer ercnr jfrncech ur gen re checkng n penger  quckl  pble we pprece ur pence ',
#  ' urw u re he be rw fllw e plee ',
#  ' jeblue ervce fr bggge  jfk  ncprehenble n eplee knw where ur luggge  fr flgh lx  nc  n hr w nw',
#  ' une npe gve up be he ll elver ',
#  ' uhwer  hubn fr e fler wh u h h he wr experence n br rcrf ju few nue g ',
#  ' jeblue u gu cnnue  pre ur crew c ge helpe ur fl wh e ue prfenl',
#  ' uhwer n el  ckrpr  rln ',
#  ' ercnr fnll clle e bck bu hn pken  e lke he wr prnk cll ever ',
#  ' ercnr  gung chcken enree ve ever een ur nr hve erul neve newercn hp c efw',
#  ' uhwer been ll up n wn he re where he pc w ken n n ee n lbu ',
#  ' jeblue u rebure everne n he flgh prn f her cke ll lve jeblue be ercn rlne ',
#  ' une hnk u hnk u hnk u fr cncng e hnk u fr he ffer f rvel cerfce unerlne',
#  ' une plee rrnge ene  he rrvng ge f flgh  chcg fr eher refun r fr cl upgre',
#  ' uhwer rvel gen rrel here  lve fel hng pper rplne cne  enern ll he chlren w  wee  ee ',
#  ' urw when l cr wul cle cc he culn cre le',
#  ' ercnr ve been rn  ue  vucher  bk flgh he l  lne re bu ple help e he flgh  g up ',
#  ' ercnr e he  hp c wczzqpe',
#  ' une hnk fr he lnk nw fnll rrve n bruel fer cheule ',
#  ' ercnr h  unl l ngh bu becue evere weher cul ke he neee chnge n nw fr ge up ech ',
#  ' uhwer ju relze h he wrng eprure e hnk fr kng chnge e ',
#  ' uhwer ju en creen h f he ncen repr ',
#  ' urw reeee heelve flgh u  h  cll n nege bu hnk he lr  heng he ',
#  ' uhwer ure w wh el lk lke ll ke  brh celebrn fer ll ',
#  ' ercnr w hur le flghr n ll wng fr cllbck nee  recheule flgh hpefull  he le flghr ne  n cncelle flghe',
#  ' urw u re rell fugn up wh ll hee el juwnbe',
#  ' jeblue he jeblue ll wng  her where u l  urfbr beween jfk n bqn rpr ',
#  ' uhwer  here nw  p re  ge prr brng ',
#  ' urw u re rgh  n fun epecll when n hve uch f chce ll curvgrlrvel',
#  ' urw ju reerve flgh wh  cpnn cerfce where  l he cerfce fr verfcn hx ',
#  ' ercnr rhzu rnln we n renve ur h prf n he cuer ervce experence cue we n cre ',
#  ' urw h  ng bck  nv hve been en bck n frh beween u n ere en   grce ',
#  ' une pck',
#  ' jeblue hell we re ng wrl recr ep n he un f bll pn pen n cllecn plee cul u help wh pen ',
#  ' ercnr h flgh rebke   n cncelle flghe w h gng  ke   lgurr',
#  ' ercnr ur  ff re refung  llw wn  br he w here  fr eprure gn ll nw brng ',
#  ' uhwer hnk fr levng e hngng here ennrgn flgh ll fucke up nw n help ',
#  ' urw ju pen hur n g nwhere enre experence epcfl',
#  ' une ur bggge pern l e  g hrugh rcn he re hnlng  cnnecng flgh ',
#  ' une hnk u fr wnerful glbl fr cl flgh n ur  fr gre ervce cn hp c kcxu',
#  ' urw pprece ur prp repne ',
#  ' urw flgh fr hur w fr ehe crew hen ehe crew ke verhe bn pce png cuer nne',
#  ' uhwer  fferng cpnnpe  ln reng frequen fler hp c n e ze',
#  ' ercnr jkerunnng h hppene  e  ',
#  ' jeblue hul cnnue ',
#  ' jeblue ge flgh n he r',
#  ' urw quen fren flgh g cncelle flghle hw cn he bk be flgh levng ch  phll  gern',
#  ' uhwer ju receve ur brh cr  w zng n e e le wh j nce ve hnk ',
#  ' une h clle hrwng ll u he wnw n rng  gve le wr ',
#  ' une wr rlne ever ff  n wf wn bg re ele ue  weher n nw he bel  brken ellng ul ck n ',
#  ' ercnr n le fl knw  cng ge crew hve e  rrve  le u ff fl fw',
#  ' une u lre hve v  u re hlfw here',
#  ' urw n nw ur hlf e plne  fllng pr e ne ell  fl lve he beer hp c u u l',
#  ' une h jp wh he help f n wee  repreenve w ble  ge  ll ken cre f hnk u ',
#  ' une cn u  e been n hl wh cuer ervce ver lng e n n geng he run run hnk ',
#  ' ercnr  here nher lne cn cll when  n hl fr hur l hw cn ge cpene fr h l f e n ne ',
#  ' jeblue we h e jr plne we recv ue eer e kep beng ree b crew eber ',
#  ' urw n flgh u f phll becue f e we ech ue cbphll',
#  ' une gen help he pern n frn f e fnhe up wh he n hen wlk w he gu behn e   hcke   ',
#  ' jeblue lernng bu ur wee wer ngeen  n  cl e rkeng cl keep up he g wrk xu ph  ',
#  ' ercnr wh   fr june hru eceber here re n bu fr lever wr vlble fr cun  nc expln whfl',
#  ' uhwer   wrkng n fferen evce hugh n help  pprece ',
#  ' une nce when  u ge  g gn rncnnenl flgh n wh pleure relef u were ',
#  ' urw lk u fr flng rck h e   br   plne nh never n  ju rck ',
#  ' vrgnerc flgh ele hur n l ue  echncl prble hnle lke pr bu u cul hve e u free rnk ',
#  ' ercnr  wh re u gng   fr e nce cn ke he pn u gve e wh pe f refun wll u  fr e ',
#  ' ercnr rng  rebk flgh wh u becue f cncelle flghln  nghre w hung up n nce cn u help e rebk ',
#  ' ercnr  n h  he rue gen wh wuln len  nhng wul  n  clerl f n he zer',
#  ' uhwer ll well g cpe wh ulple her bg whch ju e   hp c vvreph',
#  ' une hhhhh  re h lre',
#  ' urw nhng prn   wh w l  w n he ercnr lne pencerunnngu',
#  ' ercnr wrk n he c kll he gen  phx  w cnfre n flgh u f fw p g here n h w nl nb ',
#  ' ercnr hnkx b n help nw we wll nee  g w u f ur w  ge where we nee  be fr he chrge h ux nevergn',
#  ' jeblue cflngn he n  ehng',
#  ' uhwer lve hw u hl flgh n phx fr le flgh penger n ke u ll ver n hur le flgh gre jb ',
#  ' uhwer bung erl br w pnle u ve e  ff flgh c fr ne w ele  l  brng pn ',
#  ' ercnr  been hr f w n he phne wr cuer ervce rng  knw where  uce  n w re ngr',
#  ' ercnr rrve n lx fr r flgh  n luggge',
#  ' jeblue  blng  fr flgh luggge ebcle lugggege',
#  ' ercnr  u fl gn flgh  ru ng wng n flgh enn ur lgc re n g',
#  ' vrgnerc he fr e fler nex week exce bu  hvng hr e geng  flgh e   eleve ccun help ',
#  ' urw gh hve been cncelle flghe echncl ue hur le flghr peple ll wng n zer nfrn plee en help ',
#  ' jeblue when cn we r flgh bkng prble flgh fr nveber ',
#  ' ercnr u gu cncelle flghle  flgh fr  n bke e fr rrw  unfrunel hve rebke hnk',
#  ' une  we knw wh u  ele h  geng crz ve lre h verngh el unerlne',
#  ' urw hnk kng  pbl expenve chnge flgh levng le hn hr erler hn  reervn lecuer',
#  ' vrgnerc h  pen hur wrrng h e n crrn wul be brken len nce culn crr he n plne r lck bg ',
#  ' jeblue hnk fr he quck repl ju wne  ke ure  wn ju  ccun ',
#  ' uhwer e n plen une ffcul n reful lerne  len ',
#  ' urw   p ll n bg ',
#  ' une verge  burlngn vern h uck ',
#  ' urw ur cuer ervce  rcu ',
#  ' jeblue gn lue bu kwe h urbulence jblu kw nver bune l hp c hu lxur',
#  ' une r  ure her bune wll g ele where fr rlne rvel her ne  khrn el',
#  ' une nce ee hve ene f hur hurel ju wn he bu ll ele fr h beer nce fel n he r f cure',
#  ' une peple c  el preferbl wh je rw ewr bru el egen ne n eceber',
#  ' vrgnerc hhh vrgnerc u gu re zng lve u gu ',
#  ' ercnr plee cnfr fr c fw  eprure wll be  cncelle flghe n wn  ke he hur rve ',
#  ' jeblue g  hnk',
#  ' uhwer ur hl uc nee be fxe cern rck hve lu phne bun hng ne n he ee w e wul help ',
#  ' une wul lve help geng here  n ewr nw wll ke n rlne n cnnecn hx',
#  ' vrgnerc u gu re perfec  lw l wervrgn',
#  ' une n pe f flgh el gre cuer ervce prve b jne n bggge eplee kren u hve wnerful eplee une ',
#  ' une w n he r ju  u',
#  ' une u  chre flgh n unble  check n hr prr ',
#  ' une wul encurge u  re nervew he le flgh enn n ul fr buf  r blnl n ble uncfrble ',
#  ' jeblue curer llz n fleek ',
#  ' une fl ele becue f nennce h fxe bu cn br becue flgh crew n  n brng re fl',
#  ' urw ng n cepl f ger n he grun n phl fr hur nw ',
#  ' uhwer hpe cn be pr f he e wh h jb penng ',
#  ' une h w f brken n plne h e uge n n fr hw cn uhwe ge  rgh n ever plne bu une cn ',
#  ' urw hw e n rlne plce n rlne enn been  regn rpr nce p  cnc  ele rng  fn her',
#  ' ercnr hg hw bu u p cung n png plge n ge e nl phne rep   her jb',
#  ' une h e  n fl l her rlne w when cnnecr le flgh uck n h ',
#  ' ercnr plz brng re gen up  fw  cr rvc cr ge here re nl gen n ppl hp c ucveu hurz',
#  ' ercnr knw h  prbbl n bu  here w  ge cheper rfre cke f he flgh  levng n few hur ',
#  ' uhwer wll he n be vlble n free v ',
#  ' urw ue re n wh peple wh nce r r el wh wrng phne nuber u rebke flgh  nn cnnecng ce',
#  ' une he h n prr n ve ',
#  ' une hnk u  uch h help n whever  n h wer cc  eerve hnhke n h chcle flgh prblelver',
#  ' une well nw fnll n br hpefull we ke ff h e n quckl well ver n hur el ',
#  ' urw cu vc en nhng  ppne rng nce  pek  hun ge b weher n b ervce clnru',
#  ' ercnr nee n enre cuer ervce verhul el wul never re  cuer wh nhng le h ervce',
#  ' ercnr g cll ng flgh cncelle flghle bu checke nlne n  n cncelle flghle n where ner b weher hve jb nervew',
#  ' ercnr n we epre hur le flghr wh crz crew ne f he l pl freke u n g w fr jb befre eprure ',
#  ' jeblue here  nhng here becue pprenl hve  cnnec he fr h  be rue ',
#  ' uhwer hve been n hl fr ver nue plee help hp c fx bjlx',
#  ' urw hr f rvelng n h ju welce bck he  he u hr lver n ge  wch  gng  wrng enn ',
#  ' une n chnce n hell  rher wlk wr rlne ever ',
#  ' urw wul  kll u  n le le expre',
#  ' urw ll n hl hur n nue n cunng plnu wh cre prble checkng n wh cre ',
#  ' urw new prble h wrng l ne n reervn whch  rw fxe new cn ge hrugh ',
#  ' jeblue chnge n he r fr rveler nver blbergnew hp c re vc ',
#  ' uhwer hnk ',
#  ...]

# %%
corpus_Dev = []
sentences = list(dataValidate['text'])
for x in sentences:
    corpus_Dev.append(preprocessing(x))
type(corpus_Dev)
# Out:
# list

# %%
sentiment_Train = dataTrain['airline_sentiment']
sentiment_Train = np.array(list(map(lambda x:1 if x== "positive" else (0 if x == "negative" else 2), sentiment_Train)))
print(sentiment_Train)
# Out:
# [1 0 1 ... 0 0 0]

# %%
sentiment_validate = dataValidate['airline_sentiment']
sentiment_validate = np.array(list(map(lambda x:1 if x== "positive" else (0 if x == "negative" else 2), sentiment_validate)))
print(sentiment_validate)
# Out:
# [1 1 0 ... 0 0 1]

# %%
word_tokenizer = Tokenizer()
word_tokenizer.fit_on_texts(corpus_Train)
word_tokenizer.fit_on_texts(corpus_Dev)

# %%
X_train = word_tokenizer.texts_to_sequences(corpus_Train)
X_dev = word_tokenizer.texts_to_sequences(corpus_Dev)

# %%
vocab_length = len(word_tokenizer.word_index) +1
print(vocab_length)
# Out:
# 7133

# %%
max_len = 1100
X_train = pad_sequences(X_train,padding = 'post', maxlen =max_len)
X_dev = pad_sequences(X_dev,padding = 'post', maxlen =max_len)
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
embeddings_dictonary = dict()
glove_file = open('/content/drive/MyDrive/Sentiment Analysis Project final/a2_glove.6B.100d.txt',encoding = "utf8")

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype ='float32')
    embeddings_dictonary[word] = vector_dimensions
glove_file.close()

embedding_matrix = zeros((vocab_length,100))
for word, index in word_tokenizer.word_index.items():
    embedding_vector = embeddings_dictonary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector
        
print(embedding_matrix.shape)
# Out:
# (7133, 100)

# %%
lstm = Sequential()
embedding_layer = Embedding(vocab_length,100,weights = [embedding_matrix],input_length=max_len, trainable = False)

lstm.add(embedding_layer)
lstm.add(LSTM(128))

lstm.add(Dense(1, activation='sigmoid'))

lstm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
print(lstm.summary())
lstm_history = lstm.fit(X_train,sentiment_Train, batch_size=128, epochs=6, verbose=1, validation_split=0.2)
score = lstm.evaluate(X_dev,sentiment_validate, verbose=1)
print("Test Score:", score[0])
print("Test Accuracy:", score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1100, 100)         713300
#
#  lstm (LSTM)                 (None, 128)               117248
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 830,677
# Trainable params: 117,377
# Non-trainable params: 713,300
# _________________________________________________________________
# None
# Epoch 1/6
# 75/75 [==============================] - 272s 4s/step - loss: 0.6813 - acc: 0.1677 - val_loss: 0.6809 - val_acc: 0.1594
# Epoch 2/6
# 75/75 [==============================] - 272s 4s/step - loss: 0.6808 - acc: 0.1619 - val_loss: 0.6782 - val_acc: 0.1594
# Epoch 3/6
# 75/75 [==============================] - 267s 4s/step - loss: 0.6800 - acc: 0.1619 - val_loss: 0.6768 - val_acc: 0.1594
# Epoch 4/6
# 75/75 [==============================] - 277s 4s/step - loss: 0.6794 - acc: 0.1619 - val_loss: 0.6790 - val_acc: 0.1594
# Epoch 5/6
# 75/75 [==============================] - 269s 4s/step - loss: 0.6803 - acc: 0.1619 - val_loss: 0.6783 - val_acc: 0.1594
# Epoch 6/6
# 75/75 [==============================] - 270s 4s/step - loss: 0.6798 - acc: 0.1619 - val_loss: 0.6768 - val_acc: 0.1594
# 42/42 [==============================] - 21s 503ms/step - loss: 0.6788 - acc: 0.1616
# Test Score: 0.6787837147712708
# Test Accuracy: 0.1616085022687912

# %%
import matplotlib.pyplot as plt

plt.plot(lstm_history.history['acc'])


plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()

plt.plot(lstm_history.history['loss'])


plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()

# %%
dataTest = pd.read_csv("/content/drive/MyDrive/Sentiment Analysis Project final/New_Tweets_test-1.csv")

# %%
unseen_reviews = dataTest['text']

unseen_processed = []
for review in unseen_reviews:
    unseen_processed.append(preprocessing(review))
unseen_processed
# Out:
# [' ercnr nee refun ',
#  ' urw fer cncelle flghln n el cung e   cnnecng flgh nher ngh n beng he hnk phec',
#  ' jeblue hnk  uch cn w  fl wh u gu ',
#  ' une hve never been re frure hn  cnvern wh une wh cn pek pnh  he curer cpn h h  bg ',
#  ' urw he wr hl e crz gen hrrble n ccunbl uruck',
#  ' ercnr  pleure nex  flgh h wene  ln l fr exhbn ee u hen ',
#  ' une frnkl wre cuer ervce ever prble wll hppen hw u el efne cpn never gn une ',
#  ' uhwer u nee  ge ur c geher u new h rnng  ur plne w lfuncnng e ve been ele e ',
#  ' ercnr n he cncelle flghe  flgh n lef e wh n help  fn hel   n lep n n rpr fr ngh ',
#  ' jeblue flgh fr b  p keff n le flgh',
#  ' une  r xweekl flgh fr newrlen  cncun n beween  ep vgeek',
#  ' jeblue rw hr nere wn n jnur jblu leekne hp c znujp bv',
#  ' ercnr e becue  gh n be  urgen fr u bu  rell  fr e ',
#  ' urw nw n hl fr hr n h  rculu',
#  ' uhwer wh  he u n flgh l u ',
#  ' urw bu u gu wche e n n nfr e f he chhe',
#  ' jeblue ell e p p cnfre flgh wll nw c e ch nl rpr hur befre  flgh rpff nuppr',
#  ' une beer ju keep cnnecn fr r  fw h br n en nue pen unl ge ff he plne h ju lne n hur le flgh',
#  ' urw n  enn he fc h  flgh w ele becue ur cpuer were wn',
#  ' vrgnerc jezzeglz wul hve been rugh rp bu luckl we were n vrgnerc flgh weher',
#  ' une wll hve  r nb n enver ngh r wll hve  cncelle flgh fher n rp ll nex er hx fr rng ',
#  ' urw he cpn urne ff he e bel gn  peple cn ge up n wlk run h n g ',
#  ' uhwer re peple here ',
#  ' uhwer u re kllng e lw ele fr neg  f ugh',
#  ' urw g rnng ',
#  ' urw e  lne   hul n ke nher hur  g n rve w ure wul hve h  ',
#  ' une gh pbl hve he wr ervce n he plne ',
#  ' une plee en e he lnk el  frll cplen rene n lc n e f he be cuer ervce ever pxex',
#  ' uhwer hnk fr he re  chcg kw hp c cppgfn ',
#  ' une wh bu he pr cuer ervce  checkn  kn kc h  ',
#  ' uhwer n hl fr hur n hen u hung up cncelle flghle flgh runnng u f cre fr ur k wh re rppe  he ',
#  ' urw  u rn  bg n phll l  n rn e n phll h  hnk fr he bullh ',
#  ' uhwer ju nnunce nn p flgh  ll fr clubu well nex e gne be u ll hve le e rpr hpn ',
#  ' ercnr l n  flgh u flhplne hpengeck hp c zk uxgnw',
#  ' urw nw n hl fr n hur  frurng upec u hve re perr ce n n  lke h ncleen weher ',
#  ' ercnr urw ve re  be unernng n le u hnle he un bu gue w wrng bu h',
#  ' une n plne  newrk nw w checke n  rebecc lev  bg  uner her ne  ',
#  ' une u re errble ',
#  ' une cuerervce fl lng e fler wchng rlne frure',
#  ' une bee n ll egree f elf nere we ke h rue everl e er p wul he  be n h un ',
#  ' urw flgh wr experence we ve ever h n flgh regreng penng her r le cr hernlngerhnhell',
#  ' une w n lkng fr he fre  be reurne n he cpnn flgh n unern wh n nl fee w necer ',
#  ' jeblue wll r h hnk f ll ele fl wll ju  he l fhne eh rrw rnng ',
#  ' urw nher hur gne p he  wh re nw n he erul hp c fupf ur',
#  ' une   n wfe ll en hve her luggge whch w pre b p n   be n  w fle nuber c fl',
#  ' ercnr rell n even wrh f repne h  begnnng f cl e ler  he wrl h  n urw re uele',
#  ' ercnr cncn re u nw flng  r fr jfk r  h fw r huge ',
#  ' urw huchnj e e he flgh n g  wrku n  ',
#  ' uhwer n hve n ',
#  ' une hnk fr he repl he bx  n ne n  n ng ne  w e   bg ',
#  ' une e n luk zb  gue  he bg never e he plne   ',
#  ' ercnr g cre f her cuer f nhng hppen  hen ke u el fr geng e bck  nc crew u ercnr',
#  ' jeblue lve u be jebe',
#  ' urw h  g  be he wr ervce ve ever een wh n rlne cncelle flghle flgh rue eplee currenl flgh ele',
#  ' ercnr hnk fr cncelle flghle flgh hen ele flgh n n ellng u re e wrk re n hel wrcuerervce',
#  ' jeblue we e  fe n un hnk u fr he fe rvel ',
#  ' une  been fve   ju kng u  clrf ur plc n cr e n wn  hve  ke h hgher up ',
#  ' une cb re  fw fr lve g e  bg rebure ',
#  ' urw  u hve n el ',
#  ' une rgh nw  rpc r n n per belze lne u he r ll ue  elece p ppne hck hp c kkejnrw ',
#  ' jeblue r he ',
#  ' ercnr wh  pu ff b  he fc h n ge upervr h re  ce b n cunce wh u ',
#  ' urw ercnr u hul prner fferen hel n phl he clrn  prvng  be ver ffcul p n cuer frenl',
#  ' jeblue cn ge e re leg r ngh ',
#  ' ercnr jn u ll en up ng ur cnnecn plee ee ur fw gen fr nce npe hn ken ff e ll ',
#  ' vrgnerc currenl n nue f beng n hl wh cu ervce  nee   nhng   lp chl   reervn ',
#  ' une hun fn f jeehbl re kng u  gve her ur u effr  ge her fe flgh wh her bggge n ',
#  ' une efne pprece ub he wr jr rlne n he u c n uch feebck ',
#  ' une well   jhn hughe brh bu wll ck he plne p hl ff n rn p uble ge wrker re ng well ',
#  ' une  gung n uncncnble he reen ve receve ngh ',
#  ' urw re le he  n her el we were ele ue  weher when he k w cler n he c we were eprng ',
#  ' une n frenl ke fr u  hr weher el n f fllwe b hr echncl el whle ng n plne nfun',
#  ' une erul  n wf n hr flgh fr cle f u re he nl rlne whu wf ',
#  ' urw en phx preve lck f cncern b hr le flgh flgh n wreckng hvc n cuer rvel ugrk nruh',
#  ' ercnr ju ppne wh he flgh bkng prble prce n  fee   geher n re crwe flgh n pree  fr ',
#  ' jeblue l eergenc ex e n h  huge wn ',
#  ' uhwer n urw hve cncelle flghle flgh fer p  ue  wner r rveler urge  cnc crrer fr nf ',
#  ' uhwer gve e cke  ln wul  nhng nhng ',
#  ' une prrfb ne hnx',
#  ' ercnr ju ww regn ju l e cn fle r reque l bg een unl fnh  rvel  unl ge  c rgg',
#  ' ercnr  n cl h  flgh w cncelle flghle fer ng n he plne fr ver n hur nhppcuer levng',
#  ' jeblue when wll he e be up n runnng ',
#  ' ercnr flgh l eclre e f eergenc quwkng ',
#  ' une  hnel runng  fuckng lfe rgh nw never gn ',
#  ' urw unfrunel pence wn ge e   b h leve  p w n hl wchng ll flgh fll up ',
#  ' uhwer h cn u plee ell e wh  flgh fr chcg   were cncelle flghle hnk ',
#  ' une len lern p  h reve ur pq requreen   nulng h',
#  ' urw nlnnc wh wll be  wh  be wh  uck fl',
#  ' jeblue f u hve well prce flgh  hu we cul be be fren vncenzlnn',
#  ' une quck repne fferng nce bu lck f fllw hrugh n rell he ervce w expecng',
#  ' jeblue flgh bkng prble flgh fr c v fr eer weeken re ffcul bu ene well wh u gu bg fn here ',
#  ' ercnr hw  u n  nennce n  whle   fr w  frzen lne fun fer  bre ce n fl c',
#  ' uhwer  wfe nee help he  rne n chcg n cn ge u unl n he wn fn her bg becue vlue  hgh',
#  ' uhwer n plgze  ehng bu  wr en nhng cn wrk e ',
#  ' jeblue fer pplng  new g he lef  bg n he grun rher hn lng n he cnveer bel h  wlk bck r',
#  ' uhwer e plee',
#  ' uhwer ver pr cuer ervce hru u ech f  cxl flgh hul ve flew el',
#  ' une n hve e  ke  we clhe u bck  he rpr n wn gng  p fr nher cb    ',
#  ' ercnr fce pl cnn beleve he l hr hr f leep n n n n n wh u cn  ',
#  ' urw h bggge l l ngh n cll fr u rw n n bg n nb nwerng phne bcuerrvce wherebg',
#  ' jeblue wh re he chnce f cull flng u f chrlen  cl rn weher n he uh f ll plce ',
#  ' une h ne nervew w he l pern wh e h en ',
#  ' une l ur  ge nr hwe ep e',
#  ' ercnr w flng fr f luerle fl  ele w n he unl he n he n wn  hnr  flgh ',
#  ' uhwer hnk u brngbckheluvru  recflgh',
#  ' jeblue wh w flgh frce  reurn  n when here w lfuncn wh n ln n he cunle r rp urrunng ch ',
#  ' ercnr wn  pek  hun beng h  n n bcene reque ',
#  ' ercnr hve been rng  pek wh n gen he whle  bu  cncelle flghle flgh wh cn  ',
#  ' uhwer gre flgh n gre vew hp c uf xj ',
#  ' uhwer e we  fle repr n were ree rher ruel  w bggge cl nw we w   ge ur luggge ',
#  ' ercnr  here w cn ge recr f ll he flgh ve ken wh u ',
#  ' jeblue f here  prceng errr he wh  u en u full flgh cke n cnfrn fluhwe',
#  ' uhwer ver frure w e vl nlne fr pref l flgh unble  bk nlne l he e urng g hr phne hl',
#  ' urw geng re hnk',
#  ' jeblue re burger whch w g bu expenve were le  beleve h f n he u  chep bun here ',
#  ' uhwer en u  cnf nuber eer ',
#  ' une l bg cncelle flghle flgh elh cll cener pr une ff pre hn n ree u ne  ',
#  ' jeblue wh  he ren fr he el',
#  ' urw hpe ge he pprun  jn he e wh h jb penng ',
#  ' uhwer wee ff  he check n ek he h pper rplne rce fr w gf cr  keep ppl enerne urng el',
#  ' uhwer  n u w fr e ',
#  ' ercnr re u kng u n hnk ve ne h ve clle zen f e p  ell e  cll bck p hng up ',
#  ' urw e knw he nur prceure n bggge hnk fr helpng wh bu he pble cnnecn h re h ',
#  ' une plee cner leng fler wh n verhe bn e br eplne fr fer fr cl ke ene ',
#  ' une w l  w ue  be n u whch fle rec  ubln  wh   g  lnn h  cplee hble ',
#  ' une u ju re  chrge fr flgh when re  ke chnge ver he phne n nclung chnge fee wf ',
#  ' jeblue n wn  ee crz hve lre ke wce ',
#  ' une eellevw e he nee  cpln n wer fr he refun r   u pple ',
#  ' une u gu uck el  ge u f er n n even hve cure  le e knw unerlne',
#  ' knw u hve l f bggge bu wn u  knw rell enje beng ne u jeblue jebe',
#  ' urw he ju  bu rell hw runk e ene hve  be befre u p ervng he',
#  ' uhwer wne  hnk he gre effr f je cknne n buf he  rue pr urng jr el he w wnng  re',
#  ' uhwer h  u knw wh wn  lre ele unl p ngh hnk ',
#  ' ercnr wh wul even cner cnnung ur pn prgr when receve n perk r cnnue b cuer ervce enele',
#  ' ercnr hnk u',
#  ' urw ell he  ge n h plee ',
#  ' urw flgh  n levng  becue we hven even begun  br e plee upe ur webe p',
#  ' une  unfrenl crew fl h he k n  nw wng n u pr  beer fvrfn ue  gen errr n ck',
#  ' ercnr nh n ll n exec plnu eber cr wh gve ',
#  ' jeblue w upe flgh  nw pbl ele b re hn hr pwer f pve hnkng peple ',
#  ' ercnr hnk u fr he cnfrn ',
#  ' uhwer  u n r  ge cuer  her enn n help  ge n nher rlne f u h n flgh fr  ',
#  ' ercnr rue ge gen b  r lg ju nw ee  hve eper e e check n bg h f ne he zer ',
#  ' jeblue he u bve ll cercl lke he legr ne',
#  ' jeblue ec  be cler  n hve   n ur lvel ernl ju nee  be here hur prr  brng hnk ',
#  ' jeblue pprece he pee repne bu he lnger u el he re ncnvenence u pu n ur cuer plee nx chnge fee ',
#  ' uhwer gl  w fnll relve   b cn ge free vucher  g wh ne  cn hve fren rvel nex e ',
#  ' urw wre experence cl  c verl b l crr n luggge cncelle flghle cnnecng flgh  nc flel',
#  ' une plee upl he rch n en enernen lng n ur webe ',
#  ' urw he fc h u re kng cuer p  che e n r  cnvnce he ung pchlgcl rck wh clr',
#  ' une hnk gn fr ur cncern wll cnc cuer cre upn ur reurn fr url ',
#  ' une h e rne n ex n hen hng up n e when  rng  fgure u hw  ge he cl ',
#  ' jeblue up we knw n ur ful ju n el n fr ver n hur bu  lw ur ff  gre ',
#  ' urw hnk fr hwng nere  greenvlle c ',
#  ' urw wner f h er  cnere ge n brech f cnrc lwu lwerup',
#  ' une where re ur luggge wh grup n ver luggge re l',
#  ' urw we hul hve been gven he pn  ge ff he plne n  n  fr e lnger hn ur cull flgh ',
#  ' uhwer cn w hnk fr he repne ',
#  ' urw hubn re  ue ven p cpnn fr fr eergenc rnferre p pu n hl fr ver w hur gve up ppne',
#  ' uhwer cn u plee ke ene f he cpnn pr hw  we e  up ',
#  ' une wh en  ugher bke wh  gl eber le ge n he upgre l fr her flgh rrw ',
#  ' une flle u  he rpr  pr f lng  e lnger ',
#  ' ercnr wh cn   fr l f peple bu  br her h plne f ver lng  when he fr were unervceble',
#  ' uhwer hppl flgh w n ele when cckp v blew  fur r l n hnk cp hp c qezxvh',
#  ' une plee ge e ff h plne u ',
#  ' ercnr hnk u we g n fferen flgh  chcg ',
#  ' uhwer gn nher re w eplee h prne u brng pe efcenc n rnng bvul',
#  ' urw wh e ur reervn  u f nc en n hl cuer ervce n n wn n e wh  up',
#  ' une hve been wng  fr  lr bg fr n rpr hur w fr e hrrble ',
#  ' jeblue hen h gen ene reve  l luggge g ever her rpr he jb gen plel hnle ',
#  ' uhwer hnk u ',
#  ' uhwer ju en  wh cnfrn nuber n penger ne n w c g ch',
#  ' uhwer ennrgn gnergn cvenger hun veg be re hp c vhgkzw',
#  ' une ll uck n unern wh u hve w cu ervce gen fr lng lne  hun nernnl ge uneuck',
#  ' une leerhp cun lne  l ngh eplne  nue f h w wng fr he jew nexcuble',
#  ' ercnr ugh up u n fw n luggge hen cncelle flgh ur flgh re e  rrvl nw ue ',
#  ' ercnr urw f h  hw ur erger  gng  g u fl huge prbl c n fw r cxl rrn fl n cl ',
#  ' une hnk ',
#  ' ercnr nher  nher grevnce wh h rlne n cuer ervce',
#  ' ercnr u e cheule r n keep  lwle flgh',
#  ' une chrh c nee g bk uggen ',
#  ' urw been n hl wh fr n wng  e n p n pprece  wherehecuerervce hp c ph fnj',
#  ' jeblue e ur he rpr n cun n he bge e  b ccun  flgh bu ve ken h er ',
#  ' jeblue keep geng beer n wer n he plne ',
#  ' ercnr le u cul  wul be  refun e he ne w cke h  bu nce u weren ble  cce hnk u ',
#  ' ercnr rberwer  en chrge n fee  chnge wr cke  lng  he rgn enn p wr pe ren he e',
#  ' urw g nf bu  lre gne up fr ll pn nne f whch un lke he pple  he ng el ',
#  ' urw w evenull gven flgh  eph bu nl fer w ken ff  rgnl flgh bc w checke n   fher',
#  ' uhwer lvng he new plne n he lghng nl wh wnw were lrger hp c uj cjg',
#  ' jeblue ur eplee chrle cve  he ge   wen bve n ben  help r  help e fn  gle hugh hul knw',
#  ' une keep he flgh chep n erl n e n u re g flew ercnr n cncelle flghle  flgh e l nh une g ',
#  ' ercnr hnk fnll g hrugh h fernn ',
#  ' uhwer pp upe wh pbk uppr hp c wrwqrublp v ubergz',
#  ' ercnr weher w n nvlve ',
#  ' ercnr  rvel fr rrw w cncelle flghle n hen upl rebke fr rrw cn ge hrugh  reervn ',
#  ' urw n phne hl fr n rng  pek  n gen cn chnge reervn nlne gh bcuerexperence',
#  ' urw erul hve hre  cncern fur e lre  n vl geeeeezzzzz frure fler',
#  ' une wh he u f flgh bg hun ',
#  ' une here re  le f u n u  r wng  eplne  cch u  cl n chnce f wng  l ecn fr u ',
#  ' uhwer p n funcnng bhr n frl full flgh hpe everne n fr new rk cn hl  e nclue ',
#  ' jeblue wh  u hve ever chnnel bu bcnewrk hw re kgnzle n uppe  wch cnl bu free flf  wee ',
#  ' vrgnerc ll f grup w l here w n re r n he bn when g n he plne w r fr  le bg n  rw ',
#  ' jeblue  rculu h ju g he n w uppe  ln hur g bc  hell re',
#  ' jeblue u  e up l ngh bu  gvng u ecn chnce  ju b weeng n rlne kng he  fl h he ',
#  ' urw flgh  crrn  ng llen ff plne r lef  ge wr cuer ervce en ee  be nne cncern ',
#  ' ercnr fllw e bck  cn  u gu',
#  ' uhwer wre  ur cuer uppr n n re cncelle flghe flgh bu hven her bck n e wh up hnk ',
#  ' ercnr hnk',
#  ' urw h webe e n gve crrec nf   bg w n  w n ke we he enre e g he run run fr ',
#  ' ercnr el be lng rp le flgh ngh p queue  bggge cl n w ernl n g hugh p fr  ne ',
#  ' urw  n hrne f le',
#  ' uhwer n chnce he flgh ju k cn cun fr en gne up wh w wf n he r ',
#  ' uhwer  rng  chnge cke fr rvel n n h cnn be chnge nlne nw fer hn wng n hl nhur',
#  ' une hnk u uch pprecn fr ur help ',
#  ' une be u wn hnur he lke ne e',
#  ' une nher wful experence n vcr  he check n ek n l cul n hve been re rue n cnecenng ',
#  ' uhwer here   cnf neq  flgh w ele fr hur whle  fren we fr e n her b plee fllw up ',
#  ' jeblue he ch fr w n  wul lve  fn h n erler ne wh ll f pble he n fll',
#  ' ercnr e  b u n fllw e  cn  u',
#  ' une hnk u fr leng e wn  luggge  ll n enver bu  n phl nevergn flngwhu ppne lcuer',
#  ' urw cncelle flghle ur rgnl flgh  rub nw n he w he we were l we n hve e never flng urw gn',
#  ' uhwer  b  geng h e ur reervn cnn fcn h preven u fr chngng  nlne fuure',
#  ' urw npe he ju nnunce we re hee bck  he ge ',
#  ' ercnr rell cn here hugh  n gen n  wrre bu  reervn cn u help e u ',
#  ' une u fr r rrve n gen  cnfun we en  n fr b u eplee rj w rue n unhelpful ',
#  ' une nlne ncheckng ble n he neherln  ',
#  ' ercnr gre flgh experence gn f jfk re   cnen hgh qul n legc rlne keep  up gu ',
#  ' jeblue ur flee n fleek hp c pr ebc ll wu ',
#  ' jeblue b fr he wr rlne n er f ervce  jfk ',
#  ' wh w flng urw jeblue cncelle flghle ur flgh rrw n never nfe u flu rpff',
#  ' une npe ll ng  he ge ',
#  ' urw ccrng  wp c ee  be recverng ncel fr eer nw  wh re u cncelle flghlng flgh u here ',
#  ' urw  enjng  flgh  fr u re ng gre jb  been ugh  hnk fr kng  flgh cfrble ',
#  ' vrgnerc vrgnlnc g ercnr cn u help urprnce n nee f e help n u hp c zer',
#  ' une hw cn u n pu  bg n plne  ele flgh wng n lne  lk  ene bu  bg u hul er ',
#  ' uhwer crew n flgh  wee ell he en h wee n be he wll gve e free wf cnhurkng',
#  ' une hven bke e  kng befre bk',
#  ' jeblue cn brng  g n br ',
#  ' urw we rebke g cnflcng nf b bggge n exr plne bere n hn n cpe rl club fr hr w ',
#  ' ercnr ele flgh x hur e nernnl cnnecn exr ngh n hel n ll hve  p fr lb urfbrbg',
#  ' urw ercnr we re n u  flgh we rrve  c  wng n ur ge fr px n hr nw n upe ',
#  ' uhwer pnpll  n e b  flgh  jcknvlle ge e u f here ',
#  ' une ju re  lg n n w l l lg n n currenl vlble',
#  ' ercnr  we ge cl cun n ur wf wll be flng ur rlne  pprx  ',
#  ' uhwer hnk fr ng rgh flgh fr clubu  kln ',
#  ' jeblue ur flee n fleek hp c uk z l ',
#  ' uhwer  bg re n he w  chcg whu e help w cnfre fr flgh n l here n r n  crewe ',
#  ' jeblue ce ble  ppee penger n wll ree werbur republcn ercn hp c ur un g',
#  ' urw hnk fr cllng e bu  rerece flgh  hpern',
#  ' urw ercnr uggen been n hl hr fr flgh h  nw bu  p eprure elng n weher nee chnge',
#  ' ercnr wul u lke n nl el f  ue rpr flgh gen ne r re u hpp h ue lp ervce ',
#  ' jeblue un g ',
#  ' uhwer cn u ulne he plce fr bh cenr ',
#  ' jeblue rw crprn nq jblu reche n new hgh rnge reewe repr hp c pkqul',
#  ' une blckle e n png exr r hvng  reurn cke nullfe n n frncc rpr errble ervce fr rep c',
#  ' une he pl rgn bk he rgn l h wven h urerng w fr he phlppne  url hp c fvelcgz',
#  ' uhwer wh bu fr u h cn ge  he e he re plng fr he hun n ennrgn cke lef even ju ne',
#  ' vrgnerc u nk flgh cncelle flghe fr pp  jfk n n nfcn r bl  rebk ppne expece beer',
#  ' urw n wr n wheher r n flgh fr ele  chrle wll hve cnnecn hel r ',
#  ' ercnr he grup f nr chlren were brken up n grup e ll n  el h uch beer cuer ervce ',
#  ' jeblue ur flee n fleek hp c uhuklv ',
#  ' ercnr refun',
#  ' urw wh cn he ge gen n flgh prve n upe erul h  rculu hw lng peple hve been wng',
#  ' ercnr  b ervce n  rpr ',
#  ' urw n bher fllwng up we bke wh el el unern cu rv prve lunch el p upgre e ',
#  ' ercnr hnk  ur enn n flgh fr vng cnnec flgh hel rn wh k n flgh epre pr ervce  ',
#  ' urw hvelrh wh bu upgre ',
#  ' uhwer we were rebke n he u f w e rnk cupn cul help ',
#  ' ercnr nee ene  help e u',
#  ' ercnr ve been n lne fr ver hlf hur rng  ee repreenve nw gh even  he nex flgh  unccepble',
#  ' vrgnerc rng bu here  w fr nue cn bk he e cke hrugh venr fx ur e',
#  ' urw h  nw ge gen ece n  el wh upgre l n ju bup up whever  cle ',
#  ' urw well epenng n he plc wll ke he eernn   whch rlne  elece  rvel ',
#  ' urw wh n u rerue b  jx v c hrugh cl ne frcng n verngh c pengerle',
#  ' jeblue fr rlne  ue pplep n flgh rlne',
#  ' urw eh u gu ju l e  cll he webe h bke fr bke n ur webe unccepble',
#  ' uhwer flgh bn ru h he  excellen crew ',
#  ' une prve je wul hve been cl  e n wrk ll r gn',
#  ' ercnr wh wul bher wng  e cllng he when he re gunn  nhng',
#  ' uhwer hw n her n knw u re ppng nn p flgh  l n fr  hrfr c  f prl ',
#  ' jeblue hve re flgh h  lve  reee fr e pn bu he re lle ver er l  here hrcl l ',
#  ' jeblue plee prve e ur rec el fr e  expln ',
#  ' uhwer fnll g e he bnnw',
#  ' une h n even n plg',
#  ' une he h cre prr e wh her crrer n n ue kren w rue unrne n unhelpful l pke',
#  ' une cncelle flgh fl fr ewr n crew ell wfe p r l  ge  n  cch rcn  z g cuerervce  e ',
#  ' une he hr wheelchr  brken hp c vk pxqv ',
#  ' uhwer e ver uch  w lkng frwr  ung ur rlne fr fuure flgh bu never gn ',
#  ' une errfc n hnk lkng frwr  beng bck n u rrw h gre flgh up  vncuver ',
#  ' ercnr eh rebke fr rrw rnng bu exreel ppne   weng ',
#  ' urw beleve u bu n ll erune wh n ccepble e hul hve h expene n  ne h wn  ful ',
#  ' jeblue ur rlne hul hve beer e  nfr ur clen when her flgh re cncelle flghle l n we hve cheule ',
#  ' urw hnk ',
#  ' uhwer hne hul lw be he plc',
#  ' urw ub h  p we ll beng hel cpve n he grun  c lle cuncn fr up frn wul nce ',
#  ' ercnr  u hve n flgh wh le fl eng fr l  px run he e f rch ',
#  ' ercnr f b ner he ge u en ng n he plne fr l hur hen eh ',
#  ' ercnr bke  n u rw e n ee cncelle flgh lnk ',
#  ' une br cuer n plne wh n pl he nl hng h expee w  e n lne  bk new flgh ce n nw ',
#  ' ercnr  nw  nce cnce cuer reln urf fl bggger hp c c hrqq',
#  ' uhwer nee ur help bu n ne wll pck up he phne ',
#  ' urw bu w he re bke lng wh ll her hel nerb w en nw  he hel nger belef ',
#  'hnk une fr wrng bck   u cn reurn he bg u l p clen up he fece prnkle n ur bhr  uch  k ',
#  ' jeblue nw when cll  ll  he wrehue n gh be gng u ngh',
#  ' jeblue  ju ng chnge cn be zng lke  ',
#  ' vrgnerc wh u flew u f ln n ',
#  ' une l chl re he  lx fr hun flngrer hp c uwx kv ',
#  ' une wul pprece n nwer n wh we weren lere flgh h been cncelle flghe unl plne lne hwerepec',
#  ' urw ercnr re png nceenl nwrrlne',
#  ' une erul n n he plne  bh n nw n n bggge n ll n bg wrrlneever',
#  ' ercnr hnk fr he cll n  cncelle flghle flgh n flgh bkng prble e fr ue n g weher cue e leve erl',
#  ' uhwer nce h here re epre bun fr gur n cul uc n h pc e bn hul ke ne f h ',
#  ' uhwer hx p g rch wegr flgh  nnc en rpr hel flgh even ve e bu elec cuerfr ',
#  ' urw ke f h w p n he    nw bu e he her flgh nhng  h plc r n ',
#  ' jeblue beer fn w  ge e  puer rc rrw rnng bee chrgng u hree e n ch wh we rgnll p',
#  ' jeblue wul g  l veg   grgeu n g here ever er n fl wh u gu veg  grgeu p  uch   here ',
#  ' une hnk fr kng ure he her he ege ',
#  ' ercnr hnk hve ele he hw lng hul expec fr repne ',
#  ' urw verl ll plne wh exr bggge n hen h  ke he ff pr execun nue el ',
#  ' ercnr cncelle flgh  flgh en en n el ex r cll hen pu e n w erler flgh gh  nw hnk  ',
#  ' uhwer hnk hnk hnk fr cng hrugh fr u ncerel n hnk  wul hppen l w hnku',
#  ' urw hnk u bu n unern wh wll u  wh  feebck ',
#  ' jeblue lve he ervce fr he ff  newrk  g ervce ge lng w pprece ur precn nj p ',
#  ' une ju wn  cnc ene wh quen p n be pu n hl fr nue n rer  be hung up n r en  he pe lne',
#  ' une l blncng e pprenl wn ewe jr pc n ll une rlne flgh w h cberck ',
#  ' jeblue n plee p ',
#  ' ercnr  v ju  u knw reervn e h hr cllbck e',
#  ' urw ju cncelle flgh ever flgh hve wh n u ',
#  ' une  bg  prperl nge flgh e here  uch hng  beng n e r  le prepre wh ge when we ln ',
#  ' urw hve been wng n n rplne fr l f hur  ke ff beween flgh  h uull en hppen ',
#  ' ercnr flle u bggge cl ver he phne l ngh check he u  cver he rep cnfue rkn fr lk ',
#  ' ercnr lne f peple  rebk   nw vrul hl n rebk lne ju hng up urng cll bck hp c upz ef l',
#  ' urw rne  bw fer w vern n cu ervce n rnpr upe here errble cuer ervce ',
#  ' ercnr n  hel nw hnk u ',
#  ' urw w ju n hl wh u ll fr w hur n hen g hung up n h  g ',
#  ' urw h he  uele p rue eplee ever  phlelph rpr never gn wll fl wh he ',
#  ' une gre  her hnku  uch grel pprece ur reple feel uch re ele nw ',
#  ' une n nl hur el uble bke e n prke  wrng ge ncpeence   fne been wng fr ver hr',
#  ' urw help  fllng u f ne f ur plne',
#  ' w b ee n cnjuncn  new hur w  fr bu hvng  wn n bugh b f e ve ele e jeblue',
#  ' ercnr wh  cnnull geng pu n hl b pnfull nexperence peple when cllng ur plnu ek ',
#  ' une wll hnk u ',
#  ' une cn nne ure e h he rcrf cng  enver h lef  prevu enn flgh ',
#  ' uhwer pre ce gr kell  herf reng f h bw be eplee cbblre hp c  uq z',
#  ' uhwer  kng re ce rue wh her ennrgn cvenger hun u cn wn chnce  ee gne rgn g ',
#  ' vrgnerc hrnerck ele bun wfe g e he uffle fr v he  keeper hll hp c jlblnr',
#  ' urw plee fllw e  cn  u bu ehng',
#  ' urw n knw ve re  cll fr cnfrn bu cll ren gng hru cn u le e knw ',
#  ' uhwer lk lke n februr we wll pen ur cheule fr le hrugh cber knw wh e h wll be ',
#  ' vrgnerc u wll ch  ercnrlne u cl ',
#  ' ercnr rr wh equpen hve he penger been llwe  reurn  he plne ',
#  ' une plee  be preer plnu',
#  ' urw h lnk  brken bu f  he nlne bggge lcr lre re  n  gve e n ueful nfrn ',
#  ' ercnr hve ele everl e hn wre leer wen  rpr clle plee fx h r bc newbre plee help ',
#  ' une nnrcr gre pprece  ',
#  ' ercnr rvel week el cncelle flghln f u wn  lern re bu he erger pre el  cnnecr n chcg ece',
#  ' jeblue n c fr he weeken  en rnng cp hnk fr enng ll  ger  fl lk lke h rp  we nhpp',
#  ' une zng flng ver le n unerlne p llnce l er ll g jle u f u neelewhere',
#  ' jeblue ur flee n fleek hp c bbhlzgh ',
#  ' uhwer ju g  bck bu n g wen bu hr   bu pprece he uppr vucher fr eenl ',
#  ' jeblue ffer h e n cffee  he ge u gu ke e wner wh hve ever flwn n her rlne ',
#  ' ercnr wh nw ce frec fw u p we  wh  chnge plc n reervn we hl we rnng n leew ',
#  ' ercnr h que n preve l f fee ',
#  ' uhwer  ll g hnk ',
#  ' jeblue pr u prnce h fr cnnue f rbun ecl upple p rphn cre flngfrwr hp c fn qxb k',
#  ' urw hne quen hw  w cke fr chrle ur hub  lx n bgge c n u l ',
#  ' ercnr lerll ju ppe llwng peple  w n lne fr cuer ervce ncreble fr wr  n cuer ervce ',
#  ' uhwer  u hve n nf bu when ennrgn wnner wll be nnunce e p  be fren re hpng  wn hnk ',
#  ' uhwer  u pck he wnner fr he ennrgn erle flghr bejul whunlvee',
#  ' une h  be he l e fl ur rlne ',
#  ' une wh e e check n pen fr flgh n u fr ncheer  newrk  ',
#  ' urw  rng  ge   wheelchr n n ne  nwerng  ulle we hve re  cll bck n ulple e',
#  ' une n rrvng w hur le flgh n cl nw ng n he rc whle he ve plne fr he ge unhpp cuer ',
#  ' uhwer cul u be hk fuukeu wh e gne rgn cke ngh he hugeeeee fn p wul rell lve  g',
#  ' jeblue ppne wh he e cnnecn fr rc  lc n n rebureen even h fren wh  pl   w ue  c',
#  ' une hnx fr he nf',
#  ' une n fr e  n nher u flgh ge wn h w hel n fr cnx px ',
#  ' vrgnerc e vrgn erc fl rec fr ele  nc r bn ',
#  ' jeblue wn  gve wr hnk  ur crew  lgn rpr fr ll geng e  he c re fer cncelle flghln h rnng ',
#  ' vrgnerc  ure l f ur n jfk lhr flgh g l fer hn ph wh rng lwn ',
#  ' une wrre he cl weher r nw wul el u h rnng bu n  w he pl llwng',
#  ' une unerlne n he h keep n cng hp c zhfw unefl unewhv',
#  ' ercnr  u knw h uce  he ecn leng cue f eh ng een ',
#  ' vrgnerc hve n ebe bge n pche uperr  he ne u re currenl ung hp c fq xelbn',
#  ' uhwer ur nbr wf   b  kng e nue  en h wee wrkng  ff he ble ppne',
#  ' ercnr k ur new cllegue urw hw he hnle u n feb expec  be e whle gn check cpln nbx ',
#  ' urw hpe  l pke  he bggge e he weren ure wh c  bg w n ',
#  ' urw weher en excue pr cuer ervce lck f nf fr ff r he fc ff hven urne up',
#  ' urw une w brken rplne w  le flghr n  rne fer funerl n ng u n  l eeer f cllege ',
#  ' jeblue hw lng g cn rp hve ken plce fr e  ll ge cre f n ppl  rueblue when bke ',
#  ' ercnr n  e u cul n be re wrng hp c nxzhbb',
#  ' une n r we n fer crew eber lef befre ge e ce flgh enn rccll  g luck n wlke w ',
#  ' urw plee ecure he fre helf n bune cl n rplne hp c zl bvexcj',
#  ' jeblue rr fr  unernng f he er bu wh e h excl en ',
#  ' uhwer hw bu when here re cncelle flghln u ju hve lnk  rebk lke u  fr nl r ue ',
#  ' jeblue hnk fr hvng u hng u  p rpr frever   rell been n wee experence',
#  ' ercnr he flgh  he wrng  cnfr uxln eprure n hul be fr peple',
#  ' jeblue lk lke her nflble cr e g lef n he plne  gue he ll be bck ee vehee',
#  ' jeblue rw h new nh hgh  jblu wkrb new hp c xvbjczl',
#  ' une currenl crng wne  k rrw bu prll n ju b rn fulfll h re',
#  ' urw nee  el cuer ervce fr help n quen cn u plee prve he el re ',
#  ' une u hul ell h  he ff  lx hen bre grup  he ver en f he queue  gl eber hnk fr nhng ',
#  ' urw hlekhern ver n hur n hl  fr',
#  ' ercnr g cre f her cuer f nhng hppen  hen ke u el fr geng e bck  nc crew u ercnr',
#  ' une lve beng l u wul ue refun when u culn ge u u f he w f hurrcne  hve  ene',
#  ' une   b u h h nher unfreeeble pernl ue n  reurn flgh ',
#  ' ercnr g  bg h rnng hnk ',
#  ' vrgnerc f nl u gu h flgh fr ch ',
#  ' une h wul be gre',
#  ' une hnk ge gen exrrnre eu fng fr helpng e ge re bke u f be n hpefull he  nc ee ngh ',
#  ' une chnge  l ne fr  legeplu cc n he e n n hur b u h e n hl fr n hen  p n chnge e',
#  ' uhwer ke ge enver nernnl fnc cuer ervce helpng e n new fler hx fr zng ff ',
#  ' une flgh ele n ne reebere  urn he he n flgh levng r erul ',
#  ' jeblue hnk fr he hr ge chnge hp c ufbr xe',
#  ' ercnr  upgre n  nex flgh ',
#  ' uhwer h   nl n ln ',
#  ' ercnr  hrrenu ervce ever n ff w plne been n phl fr hr nw cpn cn ge flgh nf  prn wf',
#  ' uhwer l preferre en l flgh cncelle flghle n prr  brng be pn w ue fernn erul epc fl ',
#  ' une n recv n  ple n bu  e  upe ur n flgh v pckge hp c lug fvw',
#  ' une nlnerc  n n wr fr unerlne cuerervce b pr gu ',
#  ' urw eh knw h bu nw ll hve  pen l llr re n  cke nce he prce h gne up ver he week',
#  ' une ve fle he cl bu hve n w f cllng fr upe  here nher w   h ',
#  ' uhwer n h  rebk  flgh elf n  bu  br n bh ',
#  ' une plee ee  ',
#  ' uhwer hnk fr kng cre f e  chele rcke he cuer ervce ge hu',
#  ' uhwer well  w fun whle  le n hpp bu he chnge  reeeng rewr pn wn be ll nre ',
#  ' urw hur n nue ju wn  knw  ll n he queue ',
#  ' urw wr experence f ll e wll never ever ever rvel wh u gn ever',
#  'elz p chee n ercnr wh rhnu p  w lvel flgh bu we ll be bck l ',
#  ' une bugh cke wh prce h w publhe b ke n nw g n el h nce une cncelle flghle  cke wh ',
#  ' jeblue f ur cnfrng  e h he re wn g wn gn lk lke cn fl jeblue h e run cn ffr h prce',
#  ' jeblue  n he  wn wh  le he w wrkng  ge ',
#  ' urw u gu l  luggge',
#  ' urw pe frure hur g fer beng ke  ge ff he fr plne  n fr n hur ',
#  ' ercnr nw unern ',
#  ' uhwer been elng wh ulple ffce fr he l  uve cpleel l e  cuer unle  bg  bck  e ',
#  ' uhwer e bu w hpng  v he cke fference un  brh cure fluhwe lveuhwe b',
#  ' ercnr we hve been rebke ue  weher bu nee  chnge ur reervn n fl n he h ne f he r ',
#  ' urw pen re n he r p rnprn hen  he whle flgh',
#  ' jeblue ce wegh prf fler chrncleherl regrn hp c n eghgn',
#  ' uhwer hnk fr he repne w ble  ge  un relve n fn f her nure  ',
#  ' une hul n ell cke fr lverrw n hp c nhxhc bk h errble ervce n u ff cnn rech lver',
#  ' une cnce eer n w l h here nhng he cn  he uggee el fr e cpenn cu ervce ',
#  ' ercnr b nwerng  f  he cn u en hngng up n ever cll ',
#  ' jeblue h h ll lk n pr wh ercnr rl club n w u cn le u cuple pe ',
#  ' urw he n n lne fr e bugh x be n ur cnfre flgh wh g  cnfrn f u chnge  nw ',
#  ' vrgnerc flgh fr b g l rrw w cncelle flghle n nfcn w e re hur wll u rebk n nher rlne ',
#  ' ercnr  en nwer e plee',
#  ' urw n pree wh ur cuer ervce everne h been unhelpful n ncrebl rue ',
#  ' jeblue w ju  lle ver nh g jeblue u gu re gre hnk fr everhng ',
#  ' urw h wng  ge  bg f flgh el plu he hr f el h n he w u never flng u gn ',
#  ' vrgnerc we re n flgh veg  bn  checke n nlne bu ur bg cun n reger cn fx h ehw ',
#  ' urw fr cl n nck bke w cere  rnk nl n preflgh rnk r chngng  rnk ervce n fer ke ff',
#  ' ercnr  h ehng he crew n he curren leg cn reque f he ge e n he nex leg ',
#  ' urw e  ',
#  ' jeblue ellhenern he hghlgh f beng ele freecncer',
#  ' urw cn re enugh hw wful he gen w fr flgh knew ppl fr ele flgh were n w n n n cpn ',
#  ' uhwer h  rvel  vnnh g nce gn n n rlne n luv when u gng  fl e  vnnh pleeeee ',
#  ' ercnr wul lke  lk  ene plee fllw ',
#  ' une ll wng',
#  ' une u re cuer ervce  unbelevbl b bl ve been n he phne fr well ver hr ngh hung up n b r ppl ',
#  ' urw hur hw  chnge  flgh h w cncelle flghle ',
#  ' ercnr erul here ren n rep vlble  ke phne cll even fr plnu ',
#  ' ercnr brng  fnc eerkng bck  e ',
#  ' une nee help wh ng bg ',
#  ' ercnr l  bq fr n w f gre ervce  ll ng everl cncelle flghln',
#  ' ercnr el jeblue cn u help prrlne  n he wrng uck n flr  he nee  lern fr rel rlne ',
#  ' une rr he une wn ge  ee  fl unl hur',
#  ' ercnr u  h l e  en ke week  repl  n el ',
#  ' une nex e wll n vluneer  le u ge check  bg fr pce nce u bvul cn elver  n el nner ',
#  ' urw ne f weeng ur cuer plgzng wh n u pck up ur phne',
#  ' jeblue ll ken cre f her hen he rppe cll n he l hlf hur w lve jeblue',
#  ' uhwer wh h ju e   lke n ju culn fn h hnk u ',
#  ' une  u expec  cncelle flgh flgh u f enrpr rrw rnng gven he r ',
#  ' une   been  n u ve ffere n repne  ue pr reen b ge gen  he nr nw ',
#  ' une  u l e  g knwng wh he ue w nl fr e  g here n fn u h u wn fx  ',
#  ' urw been n hl fr ver n hur nw ',
#  ' jeblue bg huu  he crew n b g jfk p jfk g rc p ge crew  b p jfk lng  f el e beer b he ',
#  ' uhwer wh  n receve rnk cupn wh pn bu ll  fren  ',
#  ' jeblue hvng ruble gnng n  rueblue  epe rgh creenl geng we re n ble  gn u n g ',
#  ' uhwer lnk en wrk',
#  ' urw brv hnlng p  phx  ele le flghr cncelle flghle e urpre h b whch w ren fr rp never gn',
#  ' urw hw  ge recep fr chnge fee when rgnll bke wh le ',
#  ' urw u refuel we ve  fr  lng pl nnunce where he ruck  lk ver here  he lef cul nnunceen ',
#  ' ercnr re flgh levng ll rgh nw n u rng  fgure u hw ele flgh  gng  be',
#  ' uhwer hnk fr lnkng  pbk gh be l new bu h   fr flgh ',
#  ' une levng n hnk ',
#  ' jeblue hul be nervu bu un  flgh blre  bn n uggen n wh cn  nee  be n bn b n ',
#  ' ercnr fr hr bng hel hg   bc  ref  ge e bg bg fn  hen ref  fx k he cncel   fl',
#  ' une rlne u kng bgge l h rnng fr n  whngn n ll n rce bervce',
#  ' uhwer flgh l  lg cncelle flghle n uggen hw  ge he ',
#  ' une here  n reference nuber ur gen l e  ju rve  he rpr becue cn rech nne here  elver ',
#  ' uhwer fr  rvel ee bz cl n ge w re l u ne  vlble hw  knw hw n ne re vlble ',
#  ' une lkng frwr  flng wh u gu  well ',
#  ' une  u hve n flgh wh le fl eng fr l  px run he e f rch ',
#  ' ercnr hung up n nw n e rng  cl crz',
#  ' vrgnerc whle her rlne weren cncelle flghng flgh n b n helpng her cuer ge he vrgn w ng g luck ',
#  ' jeblue h ke e hpp hpe hee ren ep pre ',
#  ' urw flgh u f cl h rnng  nwng here hul he u  he rpr ',
#  ' vrgnerc ve e fr rrw  ',
#  ' urw ucce e flgh plee hnk he crew f gre e recver',
#  ' urw e  hnk u he  gre jb urnng he flgh n jn ',
#  ' urw he plne crew h been  prfenl n cureu  he ge gen were fluere ',
#  ' uhwer hnk fr ur nce u gu rck ',
#  ' jeblue even hugh h flgh n hve uch neee h beverge u n er he lnng w uper h hppwee',
#  ' une jh hnk  uch fr rechng u w ble  ge nce fer wng fr nue ',
#  ' une uull n ue wh expre ur f f pve ne nlne  w enjble ',
#  ' ercnr  u fl gn flgh  ru ng wng n flgh enn ur lgc re n g',
#  ' ercnr gre hnk fllwe ',
#  ' uhwer h ver unplen experence ver he phne wh ne f ur gen re cncelle flghle flgh hve he ne p gen  ',
#  ' ercnr b weher  unernble bu ur wn pl  h ver peple clle u n h zer bg re n he plne ',
#  ' urw jrexcl excl hw ve been cnnece e ',
#  ' ercnr wh hppen when u cbne p chef p he beu f n guel e llene  le flgh f blg hp c rrcre ',
#  ' uhwer h hnk  u hve n exc lnk  h pecfc pge n ur e u cn hre r   uner flgh u hx ',
#  ' ercnr pprece  ',
#  ' une rvelng wh ung k che ur rgnl flgh fr ren ',
#  ' uhwer hnk fr enng  k  he ennrgn cncer veg gnergn  wee hp c b  z',
#  ' urw rr we re n phll hul ve l u h ',
#  ' une hw n erh cul u cle he une club n ln wh jr fl  n rpr f h ze',
#  ' urw wh   pble  chnge bu preferre e v ur pp ',
#  ' uhwer hur rr n ge  h well crew he weeken n z rgh e he hel n prble ',
#  ' une  pree wh ur uper f repl  cgje',
#  ' uhwer hree cheer  ur enver ff n knw f we wll ge u bu he re keepng u lng hp c rx ',
#  ' ercnr hpefull u gu re wllng  cver  lvel cr renl n lvng chrge lve beng here fr w exr  ',
#  ' uhwer zng   b w hnk u  ver uch h  he ren we fl u uhwe',
#  'r jeblue ur flee n fleek hp c wezuf',
#  ' urw  en ke   repn  n lre pen ce ',
#  ' urw nue n hl fr reervn ',
#  ' une cn we ge n free upgre becue ll he prble we ve h ur reervn  kwlkr ',
#  ' urw  unble  check n fr flgh b c n hven her f flgh w cncelle flghe recheule n upe ',
#  ' urw nw n hl wh cuer cre wner f ene wll pck up he phne befre p ',
#  ' urw rul pne when ur flgh  ele n gng   cnnecn h we re expece  rebk ur wn flgh ',
#  ' urw  he wr ll hven lef everne ng cnnecn ',
#  ' jeblue u lre cncelle flghle he ne u  c',
#  ' une nl hng cnfung e  wh l prr brng  lege plu cr eber ',
#  ' ercnr hee re e wee ph hnk fr hrng ',
#  ' urw e   well fve hur n hl flk cn u plee ell e f h  pcl rng  be unernng here ',
#  ' uhwer en el  cuer reln n wll be cllng rrw ',
#  ' jeblue pken  rep nce  llwe  check  bg n hrugh he  checkpn gurnee wll be lkng  ene ',
#  ' ercnr her bck    w pu n flgh rrw  rrvng he  p enng  hve  ke n  ff wrk ',
#  ' ercnr  u knw h uce  he ecn leng cue f eh ng een ',
#  ' une unfrunel ll n he rc  fl hre n efnel ng  re fr flpx gnnbelngngh',
#  ' urw cncelle flghle he l pr f cke n  cnfue fr he el receve wheher vlue ren  here ene cn k ',
#  ' ercnr hnk u he re prceng  refun ',
#  ' ercnr fr he p hur cll vlue   hgh h n ne cn ke  cll  cncelle flgh  nerr urengwrng ',
#  ' urw flgh  hwng n e nlne n ble  check n clle p l w cncelle flghle pu n hl ver n hr g help ',
#  ' urw ve been n hl  chnge e n cke fr ver hur cn ene plee  e unccepble ',
#  ' ercnr   he rpr rgh nw n ur peple n knw hw  rec n help e wh h un ver frure ',
#  ' une rllnce hw cn bk rewr rvel n ugu everhng  blcke u ',
#  ' jeblue ke ke knwng u u wll fx h ',
#  ' urw vncevew here re gnfcn nuber f flk n cnnecng  few nue hl wul ke n hpp',
#  ' r jeblue ur flee n fleek hp c rnzk k',
#  ' uhwer hell w wh  ur pc fr prnerhp wh nnprf rgnzn n bw re ',
#  ' jeblue flgh wn  bk w ne  wen  purche nex  p prce uble  nqurng n chnce   g wn ',
#  ' une hw cn n hve ge re r ge gen fr gng n hur w',
#  ' vrgnerc  flgh n  w w uppe  ke ff nue g webe ll hw n e n n flgh hnk ',
#  ' une hw bu chngng rn en nn p n  fr   le flgh rnng r erl fernn ',
#  ' ercnr k f ene e  lk fr  nw  fer   wll be l frever   ver ll e ',
#  ' uhwer currenl rebke hru ll bu her he re expecng n ce r gh rnenc',
#  ' jeblue cn we ge hne upe n eprure f fle been n plne wh nfn chlren',
#  ' ercnr wh  k ge n nee  fl wh  nernll whn he u hnk fr cnfrng',
#  ' une beng r llnce hr fnl hehrwrpr n n zng wner rnng vgeek hp c wxehz',
#  ' ercnr excepnl cuer ervce fr   plce e w wng fr e  checkn fllwe b h flgh hnk u ',
#  ' une h  he lne n enver  rebk ue  weher ue  beer hp c ccexq',
#  ' urw webe wn le e chnge nlne even hugh rlne ue rvel vr nw n hl fr nue help ',
#  ' jeblue wh he ee w  ge cke recep cn ge ne  check n r cn ge ne nlne hnk ',
#  ' urw h  gng  ke up  n hur n k ur n k h  runng everhng ',
#  ' ercnr e bu u  nge  le w f ur bg hrrenu rlne ',
#  ' une hnk  kren lbur  h fr zng cuer ervce fun  ugher bg l n u e her  ',
#  ' une hnk u ',
#  ' ercnr e he n he nex flgh',
#  ' ercnr lw lve penng he upgre el ',
#  ' jeblue  gen fnc n lefl nce wrk n he enu xnnprle lberc blr jeeer hp c zf wjgxz',
#  ' vrgnerc e h en u n hve plc fr ere luggge ',
#  ' urw when  ge upervr w ke fr h uperr ne repne receve w he ce f ercnrlne erger',
#  ' uhwer  en ',
#  ' uhwer r new jb rrw p u cncelle flgh  flgh bw lx n u rell cn ge e n nher flgh  ',
#  ' une  rher pen w  n he bck e f vlkwgen hn w hur n ur plne grunle whcluer',
#  ' ercnr hnk week f wng  re hn enugh e fr u  cnc e h  wh u le cuer',
#  ' une brken luggge n l ce f f pnng fr u lhr h wh cn el bu h ',
#  ' uhwer rger wlc ',
#  ' une never h flgh ele n hur ue  n unblnce l n re el  fllxrpr gre jb  ',
#  ' uhwer cn u plee fllw  cn  hx ',
#  ' urw ve been n hl nce p nee  recheule  cncelle flghle flgh fr rnng eprure rrw plee help ',
#  ' une k hnk u',
#  ' une rell fucke   up hl  lx hr n el becue f fwre e cnnecn geng he hr le flghr n upgre nhn',
#  ' ercnr fwrpr h fw g eh cl everwhere ',
#  ' une  bung  wn e n leg f nl rp cr e requre f n hen llwe cn chl ll   fer keff ',
#  ' uhwer l  ue fr lee un eve n ee  le fr ce h cn re bk fl  c  ',
#  ' ercnr fcuk u h ervce u g n fn ',
#  ' ercnr nue flgh fr kc n hen ke u w nue cue he ge n ep epcfl prplnnng',
#  ' une he been recheule fr  bu wh he frg cl beng pble ren fr nennce  cul be he e ue ',
#  ' jeblue bw rbn he  pekng  nex nh uchber vn u he ugh  gve hu u  h wer e u rck',
#  ' urw rw flgh  f u re lkng fr pecfc cn run  he ep fr he w u f u nee ',
#  ' une h  epre w wng n nbun plne eer fr hree hur n  never rrve h   verngh gn ',
#  ' nnvulur we hnk   re  hve u nbr enj ur flgh ',
#  ' jeblue erl l nh v expe here n exr le ne n nl che   l ne',
#  ' une rng  rech h fr he nuber  l he hve h n nbe n gve h el vucher fr penl  nbe ',
#  ' jeblue hnk hve  elece lre ',
#  ' vrgnerc nce  ee u expnng n ex bu n frge bu u here n neg wul lve  ee re flgh u f here ',
#  ' uhwer hve u cnere ng he we ll cll u bck when we hve ene free feure  ur uppr lne ',
#  ' une well hnk fr n chrgng e fr wchng  w cncelle flghle flgh nw h w pre nce llkngeprhugh',
#  ' urw h  he l e ue ur rlne pre h ',
#  ' ercnr cke gen ervcng  le peple n lne wng fr n hur n hlf n ur phne hng up n peple ',
#  ' une   even legl fr u gu  vere flgh h u cn hnr ',
#  ' ercnr h  fren   flgh  fw g g ke w cncelle flghe ue  weher n w u cn help here wh re her pn ',
#  ' uhwer bel ue been rugh  fr he wr pr  rvelng wh nh l n hvng  w ue n egree',
#  ' une where  ur luggge',
#  ' urw u en p  be n veg b nw f  been llwe n  rgnl flgh ',
#  ' uhwer re u nnuncng n re wnner  he ennrgn gnergn hw velurlve n uh h weeken luck',
#  ' uhwer ll here w pe up n wnwn wng fr ll n  w ',
#  ' une pre wn flgh   fr ewr nnul bewff rp nw ',
#  ' uhwer wul lve  g  he ln hw ',
#  ' uhwer  erble n ur rln  veg nnp rgh nw hw bg u gue be fr  requre e  n bw ',
#  ' une hve her ne brng p w n here  hnk he gh rell nee h n e ',
#  ' jeblue ur flee n fleek hp c crfrwpc x ',
#  ' urw ll hnk  u we h  wch  ercn hp c l brxfn ',
#  ' ercnr gre hnk fllwe ',
#  'hnk u une une n r h  beuful plce    lnger hve u been re bke f n le e knw n ',
#  ' urw ene e nb bc f checke bg n cvg  phl  h  ke ele hr le flghr excep l bg n cvg',
#  ' urw wn wve fee ue  nepune cn ue cre  png fee culn ge  enn  ue her c wvehefee',
#  ' vrgnerc e nerl ever e fl vx h er wr wn g w ',
#  ' une k hnk ',
#  ' vrgnerc weher el g nex few week jfk b c',
#  ' une u enver  un ll n he grun ',
#  ' ercnr clle he ep lne n hur le flghr w clle bck  n hl fr ver hur  u rw n hen cu ff',
#  ' uhwer ll hve  rp b nex e v ',
#  ' uhwer ve been n hl l n hur luv ll bu jung hp c fbhjhl',
#  ' urw nw n blck hle f ur phne e',
#  ' vrgnerc hul ue h n her nex rlne cercl ll hp c pxexljb',
#  ' urw flngurcuer ne b ne',
#  ' uhwer hx nge  fgure  u b rng ff cnfrn  bke ju nnng  n rel vlble ',
#  ' uhwer wn  fle frl cpln gn grunle eplee lgur wh rune lple peple rvel pln eer',
#  ' urw ll ncerel regre ven le g hng cng  n en ',
#  ' une wh  check n nlne f ll hve  w n lne fr n hur  check n  cuner fucknle n ',
#  ' une rell nee  ge  c geher rell ppne n ur chnge f flgh ele flgh ec ',
#  ' urw h  n lg bu  luggge  n cl hve been l  ce bck rrw  cllec  u gu wn  cver  x fre ',
#  ' urw p fr  cke n ppl n he h n  ll  penng  h nrl ju wn he ne u f  ccun ',
#  ' urw hnk u  uch  been ver reful ',
#  ' ercnr h en re  ue  n hl fr n  pek wh n gen ',
#  ' ercnr w pu n hl fr hr hen g cll bck  p nl  w n hl fr nher hur ',
#  ' uhwer flng uh b uhwe fr jc  n  hp c kjkuvj c',
#  ' ercnr  unernng  he were ble n  fr n her flgh bu che n  fr h ne ',
#  ' ercnr hnk u  uch ',
#  ' ercnr nee  cpln   bu he el fr fel en llw enugh chrcer fr  cpln hve rel el re ',
#  ' jeblue u re ll he be',
#  ' ercnr hnk u  l e w lce  r n  beng reurne  e ',
#  ' jeblue wng  hpn n plne re hn n hur nce lnng c f n ge plee ge u ff h plne ',
#  ' une  flgh nuber enver  l veg n un feb cncelle flghe ',
#  ' urw u re he be fllw e plee ',
#  ' ercnr c e ver llr becue flgh w cncelle flghle n culn even gve e f cp fl jeblue el he ke',
#  ' une re h cnn fgure u where  g  ge  ',
#  ' urw ve clle  relve  ven le ue fr week  n vl plee ve p ',
#  ' ercnr u re jupng he gun n cncelle flghng flgh h cul ve e  befre he nw nw re cncelle flghln  rculu ',
#  ' jeblue ce pl ng ren fn wll ree pughkeepe jurnl hp c frhuxb ',
#  ' une wh  ur pln  reuce el ',
#  ' ercnr rbcll e wh nher cncelle flghn n hen when n ccep he chnge  wn le e cnnec  n gen ju ww ',
#  ' ercnr he flgh n fw uck  ge wh n ge gen plne full f peple ng cnnecn ',
#  ' uhwer wll be wrng n bu he ervce v el  cpn l rnpr well ver clen nhl v w ',
#  ' urw ll hee plne ng here n n ne gng he urwfl hp c jn k qgv',
#  ' uhwer  cheule  ce bck rrw fnll bu n knw w hn flwn u f fl nhvlle e bu el h',
#  ' une hnk weher  unernble bu when ever ngle ec flgh  ele becue f nbun n flgh  crz',
#  ' uhwer ng rec flgh fr clubu  kln bnlgn hp c vcz xh v pchler',
#  ' ercnr hnk u fr he repne when bk ve re   nuber n  u rw nuber n ech e  en pck  up',
#  ' une flgh  newrk uck n he runw bu    cnnecn n he re ju rr fr  ncnvenence ',
#  ' urw culn be re hnkful  ur rf n c crew n he grun n n he r  fr help wh ck k n l bg ',
#  ' jeblue pr frenl wee n help rve ccunbl hpe r he ke ne ',
#  ' ercnr ju e u',
#  ' vrgnerc hw ce u n hve n phne pp ll ung n kng e we pper ',
#  ' une u re he wr rlne n he wrl fr ur crp webe  ur wrhle pp  ur le flgh flgh u uck ju hu wn ',
#  ' urw wh  wh ll he cncelle flghln  pb we hve px  c h hve been en  fferen lne beween l n we help ',
#  ' ercnr fl ercn becue f fl bu evere weher excue  cn cll  ke chnge wh hve cpuer f cn f',
#  ' uhwer wh n wee flgh ll n vrgn erc refue bc f  chl penu llerg bu gu n hnk ',
#  ' une k hve h pre ure h  befre  bu wll w n ee wh hppen ',
#  ' vrgnerc rell e pre pprun fr en whu h pr here hp c wpg grezp',
#  ' ercnr h en rell nwer  quen be f prve re el u cn gve e clrfcn ',
#  ' une   cl ur cuer l e he n cre eher   expece',
#  ' urw e bu cll  ur   erge f vnge ven le ech e  cll bck le flghr eenugh',
#  ' une hnk everhng k nw ',
#  ' urw hnk ',
#  ' une prve vucher fr ne f  cuer n wll wee bu u ll  lng ernebune',
#  ' ercnr  rng  wch  flgh    currenl n    n rn hen  help e ',
#  ' ercnr k he  ff fr wrk n rve hur run rp  recue  ugher n her uen fr lgur hnk ',
#  ' feel cpleel chee une re ur cen  cuer ervce v webe n ef  n ge ervce uggee here ',
#  ' une n we ll hve n her nhng fr nne  une r he ererpr',
#  ' une wh wul pern ke hur n hur f w e ju  ell le',
#  ' uhwer plge re whever plee ju elver he bg lke u  u wul feel lke eplee re lng  e ',
#  ' uhwer been n hl fr hr cn ge rpr flgh c cunr bckr help pl uhwer bn',
#  ' ercnr fwrpr lenng  ll he flgh kng ff ver  hue n kckng elf fr flgh bkng prble n  flgh rrw ce ',
#  ' ercnr been wng n hl fr re hn n hur',
#  ' uhwer ce ung veg bn  help cnnec  peple hp c gkuf qh vn bune rkeng cnuerrkeng',
#  ' jeblue hnk ll   ',
#  ' vrgnerc nher perfec flgh hw ce n ur plne he un vr cn  wn her crrer ke u re he ',
#  ' jeblue  fl ele ',
#  ' une hl hgh pee nerne bn pee  une club   re nnel f hnk',
#  ' uhwer cn wee hrugh he weeken b weher bu cle wn cuer reln cener  prce refun fr cncelle flghe flgh ',
#  ' ercnr fur hur le flghr n we re fnll flng u  b e  even',
#  ' uhwer wh n chrgng n n n ',
#  ' uhwer le bggge  g n ll h n e r nere n fnng  ll e fr new jb n h bg unccepble ',
#  ' jeblue hh n nee  plgze ll be flgh bkng prble ner hn le flghr lve jeblue',
#  ' urw  chnge fee reque fr nh g fer ne hur n phne wh ur e l  bcklg wful ',
#  ' une ne f ur wrker refue  gve e her ne  reference fr  ne her ne p lnguge w ver unprfenl ',
#  ' urw h cncelle flgh  rp  l bc weher uhwer w e bu u r  kng e p  ue he cre never gn',
#  ' urw cn ge n upe n flgh  c ',
#  ' ercnr nh ju hrrble nng pn ue f club luckl nuel n he rl cn ke bl r ',
#  ' une ju checkng n gn wh  he u f ur cl   gng n nh wh n enn  h we re ver upe ',
#  ' urw wh he e gnen plc wh le u che e nl  chnge  n u w week le flghr ',
#  ' une u cncelle flgh  flgh w n lne  ge rebke when   he frn u ke e g  nher ge n le  plce ',
#  ' uhwer  ju wnerng when re u gng  pen up fre fr nveber ',
#  ' une he  belw klle ff n neque e ju elee  reurn fr hun  nrw huler hruggng  ll u  ',
#  ' urw nhng lke bck  bck ele flgh le hpe h ne n hur lke he l e ',
#  ' vrgnerc g  ll e hnk ',
#  ' ercnr  nn exen n wll ke h  fr  neee wh he behn crpre lg prve nuber cf uele eur',
#  ' une lkng bck never her fr nne h  cll n frnkl g nr p ll hnk bu  ',
#  ' urw e ever ne f hee n ever flgh  lke h here nee  be re velcr r ehng',
#  ' uhwer nce wrk n he upe ',
#  ' une lw hpp  r  lfe wh  new wfe wh hr rvel el ue  nenece n  wul pper ncpeence',
#  ' une fle ele bg repr n ur  flgh w cncelle flghle n never wen nwhere ',
#  ' une hnk u ',
#  ' uhwer  brh  februr h whch  he e f he gne rgn n flgh cncer bw',
#  ' uhwer u gu re  zng fr enng peple  ee gne rgn ennrgn ',
#  ' une re cllng  bu n phn w en we  pn nw',
#  ' jeblue wh  he buffl flgh  le flgh ',
#  ' urw e flgh rue cr n flgh ll ue n nwer n wer help e u wh r pnwl u re  nl hpe ',
#  ' uhwer wer  cn  ene unle he fllw e cn uhwer fllw  wer hnk u ',
#  ' ercnr  n ju frurng  w p fr hw  we ge refun ',
#  ' une cch nerr n u lke lke  w lvge fr he n unuble ve n pwer p lfeve n he flr u ',
#  ' ercnr  ur webe wn hven been ble  check n   flgh ll rnng ',
#  ' ercnr n wrre even hugh w lkng bu e gnen ',
#  ' jeblue wh g wh he nflgh wf ',
#  ' uhwer cn beleve hw n png cuer u lef hgh n r wh n ren fr flgh cncelle flghln n u f bl ww ',
#  ' une n we re brng bu wh cn ur gen n he phne kng cre f rveller lnk reervn ',
#  ' ercnr  ll wng fr h cll bck rne n n ne  lk ',
#  ' une re peple wul cch her flgh f ur enn h re help ',
#  ' jeblue h penll reful un n reflgh bkng prble flgh whch he ffue n helpe ke wee ',
#  ' ercnr n even wre b he e u repne   wee k w flgh ver fve hur n h w he qucke repne ',
#  ' ercnr  flgh cncelle flghe r n n wr fr he grun ff ',
#  ' une n n  fr flgh w ele n hur n  rrvng   enn hr le flgh ',
#  ' ercnr here  w hur w',
#  ' ercnr wh w  flgh fr   ll n recheule  ue ',
#  ' urw e nne cull wrk  he ven le epren hp c bgjfne',
#  ' uhwer eh he re ewhere hpefull geng he bck  ju frure weeng ',
#  ' une puhng fve hur n  e  wrh nhng  u reflgh bkng prble n n pn unfrunel ',
#  ' urw  flgh w bu lef  phne n he plne r he hule ',
#  ' vrgnerc cpleel wee experence l nh b l nnp hnk fr uch n wee flgh n epr e vbejblue',
#  ' jeblue lkng cl',
#  ' uhwer hnk fr geng e he fr enver ngh epe he nw ',
#  ' jeblue flgh epr  fnll rrve jfk wh n pgr  p h  lng flgh k bu hp c kfkjf zg',
#  ' une flure n unerlne',
#  ' ercnr cncelle flghle f  flgh fr nennce cuer ervce ek  ep cn ge hel  le hp c pbkcrbxu',
#  ' uhwer hnk ju en  wh h nf ',
#  ' une fferen eprure rrvl upe fr u n hr plee ',
#  ' urw hr flgh el n el when we ln  h even rel lfe ge e ff h plne wnn g he heel clck ',
#  ' vrgnerc rell wh u fl u f frg frgrpr he fre re zng',
#  ' une cn w plln hp c lll eh',
#  ' urw nburne well f u rell n lke he hen he wul be n n rplne furw ',
#  ' uhwer when e he new cheule pen h ke u p ',
#  ' jeblue hell cn u ell e f u currenl fl  hw hnk ',
#  ' ercnr hw cn ge u gu  repn   wee n  rell  feelng  be gnre ',
#  ' une wul never fl une rlne gn ',
#  ' uhwer peej h  fl el c g ch fr c we cln rech w  rerue w cncelle flghln vucher wl help ',
#  ' ercnr ve been n he lne wng fr nue gn ',
#  'he une u ve upgre e n hur nernnl flgh frgve u hnk u ',
#  ' urw   ur prcce  gve  cl e  u r eplee befre gvng he  chrn cuer ng n cch ',
#  ' uhwer k unern el ne w bu bh w n nne flgh',
#  ' uhwer bg hnk  ur e fl eerg e  cke experence w excellen  e flng wh ll n  l ',
#  ' ercnr n  ge beer her penger rebke rec n her rlne wherehelve whbeff ',
#  ' uhwer never g cncelle flghln ex fr h rnng eher buhlegue r nuber  cll wekervce',
#  ' ercnr  e wh f he beng hung up n he her ne  fnll en e  he cll bck nfcn fxuruff',
#  ' ercnr wh wn u fn  luggge whu blng everne ele ',
#  ' urw ju hpe h pl h g  ff',
#  ' urw hnk en l fer w verbll cue u chrge exr fr bg p hen l n feel lke elng wh  ',
#  ' ercnr flgh cncelle flghe  rng  ge  chcg wh re e n junr gnn  flng flgh rvel',
#  ' une eplee l ee hpp when elver errble cuer ervce ',
#  ' une gve e rec nuber cn cll regrng  l bggge eel ',
#  ' une hnk fr he repl w h bu  n prculrl helpful  hungr vegern n flng he pecfc flgh hrug ',
#  ' urw bck n lne  ernl becue phne gu culn help ne pern n frn f e n w gn hp c hqh fvk',
#  ' une n lun ',
#  ' uhwer n flgh  hrl  h le rue ',
#  ' vrgnerc e f  bff',
#  ' vrgnerc chrchrc ur nce eer when cncelle flghle ur flgh w  gve u hel hlne he n u ',
#  ' uhwer ju wne uhwe  knw h n hnk he re  gre  ue  nre nhng  lk n ',
#  ' uhwer ve been n hl fr hur  recheule  cncelle flghle flgh fr he rnng wh gve nee help nw',
#  ' une cuerervce  ulle rpr cul n be wre ge he b weher bu h  wful ',
#  ' vrgnerc bg lve grue pwer hp c gr kncpf wern cr vpwgbg vlnhllw hp c bbg hn',
#  ' uhwer wh nuber cn we ue  ll fr ue he u hx',
#  ' ercnr el rerue f  bg n   cur hw cn ee f he e  n he flgh ',
#  ' urw  wn weher h rnng we vere bck  b ue  echncl ue  fr l ne f  ',
#  ' uhwer gnergn beuc well e wee ju bre n wll be lenng n  w he ',
#  ' une  he c wen n fr bu nue befre reurnng  he jve eer preurecker herp',
#  ' jeblue clle jb e evere u vg ur w e hul n be lnger hn n we lnger hn n n n nwer ',
#  ' une ewr lx u  e rre brken cver fer keff flgh full f fle repr wh  ch wh fr prl refun ',
#  ' uhwer hve flgh u f brngh rrw ngh cn recheule  fr n erler flgh becue f he expece nw ',
#  ' jeblue ferrleh lve jeblue pee wer cuer ervce ',
#  ' ercnr hnk u ',
#  ' une eerve  g bnkrup ju ele n ubun flgh wh n nf n he cnnecng flgh h we re gng  ',
#  ' urw prve he be ervce fr e  hnk u  uch ',
#  ' urw wn n cecre bb ',
#  ' ercnr ll wng n bg fr flgh eer fr cl penger n hpp wh ur ervce ',
#  ' uhwer wh cn cnc bu requeng chr nn hnku',
#  ' une flgh  hr ele  fr c f le flgh crew nw we re lerll wng whle he hve nner cc  hne ge gen ',
#  ' uhwer geekel  u knw when he l chnce  ',
#  ' jeblue ur flee n fleek hp c cxxv lp ',
#  ' urw w rebke bu ucke bg e crpp lver cuer ervce ver ub pr ',
#  ' uhwer hur le flgh bu e   f be u cn help e ge n n erler flgh n un ',
#  ' urw hnk fr kng  flgh ff he br n n prvng n upe bu  flgh whch  nue le flgh ',
#  ' uhwer   gng  be he  cn feel  hnk ll fr ur uppr hrughu we re cng he nhvlle cv',
#  ' une cul u ell e f h bg wul be ccepe  pernl e cn brng ne crr n bg plu h hp c czplhl',
#  ' vrgnerc hubn n rere hree rnk v  creen n he never ce wee ',
#  ' une f w ll le he flgh  frurng ',
#  ' une npe  n u h w uppe  leve  bu re ll  he ge pprenl we re bu  pull bck n e ce ',
#  ' jeblue hnk  bernr fr kng e  re hrugh pge  fn nf  upervr fel  n h hwe prevu c',
#  ' urw ur ervce  phl  bl n hur n he runw wng fr ge n nfrn nwhere e  cnnecn bl ',
#  ' uhwer rlne fl wh bu hven een nhng lke h e ',
#  ' une gre hnk u ll en  nw ',
#  ' ercnr ur cll e  fuckng jke',
#  ' uhwer n n n nwer  wfe n bb nee  ge n h flgh he rrve hr prr plee help vene crk',
#  ' une hnx  uch u fllwe hrugh n ele e cke vucher unerlne he  cre',
#  ' une  n cpn h vlue  cuer p fer reng wee  he  n he nl ne wh feel h w lbune',
#  ' une ge chnge w el even he crew hnk he rlne uck',
#  ' ercnr hnk ',
#  ' urw gre flgh wh n el hnk u ',
#  ' uhwer we hve been uck n ju fr everl hur n n ne  nwerng here rell ugh  luv w n repne  b ',
#  ' urw ur cuer ervce  cl  errble  flgh w ele fr jfk fr hur ge  cl  hrr cuer ervce ',
#  ' uhwer cn u fllw e  cn en u he nf ',
#  ' une wll le  bg bu wn gve e free prezel fru',
#  ' une en purchng cke wh une cr gve e prr brng ',
#  ' jeblue   lw ',
#  ' ercnr n u re n u re rng  bk e p when nee rrve bu u re ll ellng e n he   rng rvel',
#  ' une rbcnc ee nfrn n ur brng prce hp c gbw ugfn kp ge grup p ju n ren n ',
#  ' uhwer flgh fur hur n he plne n he grun  bw ',
#  ' urw nw u hve ver peple n lne h  up wh he heck ',
#  ' vrgnerc nl hng ee n pbk  vrgn ble exc hw  negre ',
#  ' une u re he wr wll v u lke he plgue ',
#  ' jeblue ur flee n fleek hp c xx qcjll brnngbe freberg ',
#  ' uhwer l bg n flgh  veg nw  el p gng  ll lve ge enn  ee f cn crne  ge   lve',
#  ' urw ercnr burne l f e n cell nue wrkng hrugh h flgh ue hpefull we fl he n he rnng ',
#  ' uhwer he prble  plge n help reul er n  prvng pble  fn nne wh  neree n h ',
#  ' ercnr wng n hur nw fr pl   here pl n he hue  fw ',
#  ' urw run w f beng he wr rlne ever ',
#  ' jeblue uner bu cul g n pu elf n he nb l hur prr   flgh ',
#  ' uhwer lx u re frgven  lve cuer   f u never lef ll h wh u re be ',
#  ' urw refue  cpene penger when ncnvenence n wuln even rebk e n nher rlne ppne',
#  ' ercnr  ke pn f cnfun  wheher cn ke h chnge even hugh he nl flgh bkng prble w n u rw el ',
#  ' jeblue klejuh  en er wh u rece e   he prncple f he er when ge checke he rller  w',
#  ' urw he plne  n  hvng echncl ue wh cn ge ff n ge n new flgh nw hve e  cnnecng flgh',
#  ' ercnr  hw  we ge e pern ',
#  'ju n ce u neee cnfrn h n fleek  e p gne r jeblue ur flee n fleek hp c  x j',
#  ' jeblue exr pee lne cle n p wh gve ',
#  ' jeblue wee hnk ll gve cll le flghr  pprece he help ',
#  ' urw    cll befre cnnecng ge ng nce bu weher weher b  clle fr  befre wefe',
#  ' ercnr hvng ruble geng rebke',
#  ' une cbn crew were huge ffener   cnvernl cluer blckng exng penger',
#  ' ercnr nee  ge her h geher cuner peple p ve lne peple nee  cch her flgh hp c qfxebx',
#  ' vrgnerc erul wul p flgh fr e h n hve h plng  rell he nl b hng bu flng v',
#  ' ercnr urw   f u hve cpln u hul v ur cuer ervce ek ee lne peple eep ',
#  'wh en ercnr prve en fr lgue wh  he fer h rve h ecn wrcuerervceever',
#  ' ercnr lk lke we re bu  ge gng fnll ',
#  ' urw hnk fr kng e check  bg when he pce w ep n  he flgh enn fr he r lk hp c rx h ',
#  ' une fucke up hen ve  cke n kep  ne n even n plg wll never fl wh ur rlne gn unerlne',
#  ' ercnr w l  flgh p w cncelle flghle bu n ee  hve n e e chnge ve been wng fr cll',
#  ' urw hnk fr kng  cnnecn geng rebke ng h  n erble  re    fr nhng ',
#  ' ercnr ne hpe u cn ffer ehng ',
#  ' urw wul lve  f u cul ge  wfe he ee n he h been uck n rln n nw uck n phll fr  lng',
#  ' ercnr hnk',
#  ' jeblue re  g  newrl fr he runne prncehlf hp c q ',
#  ' une e knw h he quen  wh  h ll he ce fl',
#  ' ercnr hnk u  h  hw lw r  vcn hp c zkc uzu ',
#  ' uhwer rel ncere plg ke   gl  knw flng l  re prn hn e never flng w gn bervce',
#  ' une ecn e flng n hun n n wng fr luggge  bggge pcl ll wng ',
#  ' une h been ufferng enel ever nce h erge hpefull ll never hve  fl une ever gn ',
#  ' jeblue wh re here  n el  nrh e ce ',
#  'bu n ee  une',
#  ' une  he wr rlne n he wrl ',
#  ' ercnr  ge ur ge gen re urnng png cuer w n fvr f nn rev',
#  ' une wh n preferre ecur lne nre   pre check n pull n  lverrw prner flgh plnu ple',
#  ' urw rpr nw revl eh keep up he g wrk flk h  where cen bece hp c jj xg',
#  ' une enrpr une n nw enver hp c kjux',
#  ' une  nwbr b bg nclue n he nr checke bggge nex  he nwbr bg ',
#  ' ercnr rpr n exr ngh fr hel n n nce hve her f nhng fr ur ebrrng rlne ng h u wll',
#  ' une  cnfue fer ur ulle rpr gen rece u  g  ur webe fer el nhng wrk hp c cprhe gk',
#  ' une gn k wh cn cll  ge h fxe weeng e b quen  ll nl ke hng wre phne nuber plee ',
#  ' ercnr zng  wch chefer wh rvel wh celeb ll ver he wrl hw he uh f erc wh n  fl wh ',
#  ' une he be e hul be fr png cuer n we hul ge  br fr bcuerervce',
#  ' uhwer hw  ge prr eng fer u lre p fr he flgh',
#  ' vrgnerc he n v fr kng peple pen ne n rne ce when her rlne re lnng  jfk wh wll rebure e ',
#  ' ercnr knw ur plc ju kng fr lle knne ue  exenung crcunce ',
#  ' une lghl beer crew pen lng e erchng fr beer lue wul hve helpe  le px n n wh ll he hrp rp ',
#  ' une kur n he crew n u were zng  he e  n brh wh her knne hpe  fl wh he gn n ',
#  ' urw n hpp pp le flghl l e flew wuln le e check n h e checke n wen n le flghr  never checke n',
#  ' une wh bu peple rng  ge n flgh',
#  ' une here n ren  hul ke   repn ',
#  ' une  here n el re cn rech  lng fr  ',
#  ' jeblue wh wul u hre gu wh en cre bu he fe f chlren n reel ccepble hp c lkfh hhw ',
#  ' urw frurng  n flgh he chnge rlne hnk u phl urw eplee p une fr help geng e bck  h ',
#  ' uhwer plee cn hve he l cke fr e n  be fren  ennrgn hp c eqq nfzh',
#  ' jeblue berz n un ge c ',
#  ' jeblue rw ck rng lwere b ver nc jblu k fnncl new hp c qw ebeevg',
#  ' uhwer hnk u ee nex wene n fll ve e e penu',
#  ' uhwer l  luggge  brh wh   fn  luggge ',
#  ' jeblue  n repr he upe nf n knw hw  rech he whu uper lng w n hl  ur n nuber ',
#  ' uhwer  flng u f cun rrw  en cn chnge  flgh ue  he rvel vr ',
#  ' vrgnerc cn check n r  bg ur webe n wrkng ve re bh ekp n ble hp c vqp ',
#  ' ercnr hnk bu h reul n ng he cnference  enng re here pn  bk erler r f n receve refun ',
#  ' une e we re n ewr n  w crrece bu ju he fc he  w beugh up fr u  hre r  unexpcble',
#  ' une hnk fr levng ur er l n h wn rw flgh lx ',
#  ' ercnr uppe  rrve   enn ngh ercn rebk e fr wene where  ng unl hen ',
#  ' une ur ervce nee wrk check u h buh rpr cuer ervce lne l n unegnune hp c zgv',
#  ' une flgh ju cncelle flghle h  rculu',
#  ' ercnr u cxl bh  flgh  fr fw  cll  nce hen re e lke rh n he phne n ffer n cpenn wh ',
#  ' urw hnk u ',
#  ' jeblue n rell hve flgh  cch  p n veg  prng n  he flgh ',
#  ' urw hee  nc fr cl funn  her ll phne rng  nce n hen he enre plne grn h hppene wce re ',
#  ' une u f cur when flgh  rrnge re pl nfe here re l f pl hven rrve e nnunceen ',
#  ' uhwer w fnc h he be flgh ervce ve ever h ',
#  ' ercnr hw lng e  ke  ge cre    ccun rvele n jn p nl ne leg repre ke fr cre n repne ',
#  ' une wh rell gre p flerng r bu u u hul be ver pru hp c br qcxk v prchuegu ',
#  ' une  fferng  rerue  f flgh  lx gh be gegrph cl e ',
#  ' une w flgh u f hun',
#  ' urw n wrre w ble  re ephenrrck enre bk whle hlng hegclrnger',
#  ' ercnr n wrr u wn el  ne gn',
#  ' urw when u ve g  ge here we ve g excue urwfl',
#  ' jeblue ll wng fr bg fr flgh  lne n hur g ',
#  ' jeblue erul wh  gng n hp c h wbu',
#  ' jeblue wul fl  whngn c  ee he cul cnun n he eclrn f nepenence n hnr f u nv fren ',
#  ' uhwer rell pprece u ll bh cercl h re  urng be bkfnegre',
#  ' uhwer wll be cllng ene n n n cuer reln ver ppne n hw w ree b cuer ervce ',
#  ' urw nw h rne  n  whu upng n f he eprure br n nce he cncelle flghle he flgh here w n ',
#  ' uhwer  prn  ccep her fr wh he re wver',
#  ' urw fr repne n  n hnk',
#  ' jeblue lve flng wh bu hve quen wh  ne f ur plne clle n je',
#  ' une nhng e jj ',
#  ' une une cupn  ke up fr brken enernen e n hur flgh erul rculune lerncuerervce',
#  ' jeblue n ke eher w  en ke he flgh le ele ',
#  ' une  funn h  brng p  prr becue clerl  n prr  h rlne',
#  ' uhwer en even hve gluen free penu wh e ',
#  ' ercnr cngugn ju ke ure he reeber  l he bg n he plne he cncelle flgh he flgh when he frge ',
#  ' urw flgh uw rrve  flp fllwng flgh fr phlrpr hp c lwzgg',
#  ' vrgnerc  here pecl nce f rvel lne k n nfn prr brng ',
#  ' urw hell we re ng wrl recr ep n he un f bll pn pen n cllecn plee cul u help wh pen ',
#  ' ercnr plee  e',
#  ' urw ne ',
#  ' uhwer en',
#  ' uhwer hw cn ge cke fr feb gne rgn hw ',
#  ' une hnk u',
#  ' uhwer nher gre flgh p crew l veg chcg hnk ',
#  ' une fr wrele w epc fl gree pgg u re he wr ',
#  ' ercnr e ur ervce n guc uck ur ge gen puhe penger n h been rue  everne nce we g here ',
#  ' urw hur el ph  ur rlne  b n geng wre flh fr ercn  erge u re ur cuer lke crp',
#  ' jeblue lve ur flgh bu here lw e el unfrunel',
#  ' jeblue ce ble  ppee penger n wll ree werbur republcn ercn hp c vpnqx',
#  ' uhwer cnnue  prve  be he be rlne ',
#  ' uhwer l lw h rffc bu h  nne cn be he nl ne wh h ue n flgh ',
#  ' ercnr ncnvenen  uch cnvenen wr ',
#  ' urw nce jn hve been n flgh wh he repec n cl fl  p n feb  c ju ke herb quen',
#  ' ercnr hnk w hur  g nflgh hen hel hng n here wh ll he fw rvel el  e ',
#  ' ercnr he f erve n  w vle n gr he enre cbn  n e her el urve he flgh crew nher gr u',
#  ' urw we cn help u we n pu peple up n hel when u  flgh  gn plc ',
#  ' uhwer  n plne fr hr n hen we fnll k ff ',
#  ' une hve flwn wh u e n he l  u f flgh hve been ele huge ke n  pr n fl une',
#  ' uhwer  new rec flgh fr clubu  kln p bn rng ugu ch k b',
#  ' urw hur n hl h w fr le hn nue uele cr lke  e n pu e bck n hl fr he l nue ',
#  ' uhwer  nee help wh  flgh cheule hh',
#  ' urw hr w p rell b exp phlrpr luggge wn rrve e  rell hve g bck l rpr pck up when rrve ',
#  ' jeblue cn vew e elecn chnge e fr flgh rrw cn u lk n h ',
#  ' jeblue wh cn   lnlve ur brnnce hp c bzwgp ve wecgeher n lve',
#  ' uhwer re bccle h he lb crer free r bke re ucll ech w he fq pge n ver cler  e ',
#  ' une we re rng  g  fr w fr kng cllegelnn  pble fr chr  wul u help u jlbrek rg',
#  ' une ge  relee penger  br her eplnng peplen brge whle nex flgh br hp c hff h',
#  ' ercnr ng  he ge n flgh fr n hur ue  bre beng wn wh bckup pln  n plce f bre cnn be fxe ',
#  ' uhwer wll u plee r fferng ervce u f rflgh n hevller  her rpr hve  rve hr  ue u',
#  ' urw u wn gve u hel r f cn u  le uggen pn fr kng   he er c hve cke  ',
#  ' urw h  he wr cuer ervce hve ever h rebke  ue bu e vlble n n wf cnc e ',
#  ' uhwer re chg nlne pp n wrk ll n hl fer fr hubb  rve  rpr  ke chnge cuner fl',
#  ' ercnr urw nee  cncelle flgh flgh bke erler ngh re u ble    ver wer ',
#  ' uhwer lw when fl w llrreber',
#  ' ercnr une geng u  where we nee  be h  n ccepble n  enn cncelle flghng eeng nervew fr  clen',
#  ' une hnk fr n leng e wch flgh bc h checke bg hen cncelle flghng  flgh frcng e  ke nher hr le flghr ',
#  ' ercnr cn u cnnec e  pern whu hvng  w hur n hl ll hven been ble  relve he prble ',
#  ' uhwer f u lve  ee re grl ge npre bu becng pl r ur free lbuquerque even hp c rfxlv kgh',
#  ' urw n hpp wfe h b rp wul lke  be full cpene fr bh flgh',
#  ' urw cncelle flghle flgh pern lne n ne gen helpng  rebk u cul ve hne h ne beer hp c b vu',
#  ' jeblue ju l  bune enj ur prf',
#  ' urw gre ju clle ur fuckng phne nuber n he hung up n e',
#  ' urw ve been n hl fr n ju rng  chnge  reervn ',
#  ' ercnr cncelle flghle  flgh n nf e n cn nl rebk b phne bu cn ge hrugh  n gen epc fl ',
#  ' ercnr hnk',
#  ' une kep e wchng he fe ve fr he fr e n frever nce jb ',
#  ' uhwer cul u ell e f n upgre re vlble n flgh u f l rrw rnng ',
#  ' une  ll rng  ge hng wrke u n u hve e  repn bck ',
#  ' uhwer b enugh h here  n e gne he eng  n ex e n le flgh enn reve h fr here',
#  ' ercnr k hnk h we lng enugh fr ge  fw ',
#  ' ercnr eclffr n  jfk u r f hve  gue hng u   ll rpr  whever ',
#  ' une hw cn u n knw fer w hur f u ng n he plne wh n bg ff le he plne wegh ',
#  ' jeblue check  plee ',
#  ' jeblue wh wuln u ju cre  rgh   ccun ne f hvng epre gn n h ee pre rculu ',
#  ' jeblue elee h wee becue ne f ur wnerful eplee wpe n  help fh rere u re ne f he g ne ',
#  ' urw phze re weher ue bu when e ge ugh cll n re flk ver w hur n hl fr nue fx fl',
#  ' urw cn n cluch n enng e  chrle hen he h ercnr excep fr wne  rel hnkjeu hnke',
#  ' uhwer flgh bkng prble ll  le flgh uer rvel  he u cun rec flgh pper ',
#  ...]

# %%
sentiment_Test = dataTest['airline_sentiment']
sentiment_Test = np.array(list(map(lambda x:1 if x== "positive" else (0 if x == "negative" else 2), sentiment_Test)))
print(type(sentiment_Test))
# Out:
# <class 'numpy.ndarray'>

# %%
word_tokenizer.fit_on_texts(unseen_processed)
X_test = word_tokenizer.texts_to_sequences(unseen_processed)
X_test
# Out:
# [[12, 61, 189],
#  [11, 72, 36, 330, 1, 37, 799, 4, 285, 7, 125, 94, 1, 153, 2, 21, 667],
#  [17, 21, 110, 24, 13, 49, 9, 3, 82],
#  [8,
#   26,
#   103,
#   45,
#   15,
#   340,
#   100,
#   1181,
#   9,
#   8,
#   9,
#   24,
#   249,
#   1502,
#   2,
#   2191,
#   223,
#   6,
#   6,
#   46],
#  [11, 2, 86, 57, 4, 563, 80, 304, 1, 1559, 1920],
#  [12, 1392, 138, 7, 6, 824, 245, 23, 5, 7152, 78, 3, 95],
#  [8, 3412, 250, 40, 38, 91, 107, 50, 302, 52, 3, 37, 1248, 223, 103, 79, 8],
#  [16,
#   3,
#   61,
#   18,
#   14,
#   22,
#   346,
#   3,
#   111,
#   6,
#   170,
#   14,
#   55,
#   13,
#   2609,
#   4,
#   59,
#   45,
#   58,
#   4],
#  [12,
#   1,
#   2,
#   36,
#   150,
#   7,
#   1,
#   174,
#   4,
#   9,
#   1,
#   44,
#   167,
#   164,
#   1,
#   1347,
#   1,
#   1,
#   88,
#   5,
#   94],
#  [17, 7, 5, 43, 25, 679, 1, 31, 7],
#  [8, 29, 2467, 7, 5, 2769, 1073, 1, 439, 181, 714],
#  [17, 155, 64, 1145, 47, 1, 1309, 977, 2813, 32, 22, 7153, 1214],
#  [12, 4, 104, 244, 1, 27, 2315, 5, 3, 19, 112, 5, 4],
#  [11, 35, 1, 57, 5, 64, 1, 6, 289],
#  [16, 9, 2, 3, 1, 7, 23, 3],
#  [11, 19, 3, 82, 559, 4, 1, 1, 1374, 4, 10, 2, 7154],
#  [17,
#   160,
#   4,
#   25,
#   25,
#   473,
#   7,
#   50,
#   35,
#   22,
#   4,
#   271,
#   85,
#   88,
#   33,
#   154,
#   7,
#   1071,
#   7155],
#  [8,
#   162,
#   39,
#   177,
#   166,
#   5,
#   29,
#   171,
#   6,
#   173,
#   1,
#   54,
#   92,
#   149,
#   227,
#   18,
#   70,
#   2,
#   55,
#   6,
#   39,
#   105,
#   1,
#   33,
#   31,
#   7],
#  [11, 1, 134, 2, 434, 6, 7, 13, 58, 104, 14, 379, 123, 47],
#  [69, 2564, 65, 26, 45, 1269, 114, 19, 1310, 30, 123, 1, 69, 7, 108],
#  [8,
#   50,
#   26,
#   29,
#   325,
#   1,
#   311,
#   94,
#   29,
#   50,
#   26,
#   36,
#   7,
#   1141,
#   1,
#   114,
#   20,
#   138,
#   119,
#   239,
#   5,
#   87],
#  [11,
#   2,
#   223,
#   753,
#   70,
#   2,
#   4,
#   1389,
#   79,
#   118,
#   24,
#   18,
#   53,
#   1,
#   1104,
#   194,
#   6,
#   1,
#   28],
#  [16, 15, 118, 41],
#  [16, 3, 15, 956, 4, 188, 58, 5, 1900, 10, 547],
#  [11, 28, 170],
#  [11, 4, 105, 97, 1, 48, 125, 33, 28, 1, 381, 13, 163, 65, 26, 6],
#  [8, 244, 813, 26, 2, 86, 38, 1, 2, 55],
#  [8,
#   62,
#   54,
#   4,
#   2,
#   349,
#   37,
#   2144,
#   1512,
#   853,
#   1,
#   678,
#   1,
#   4,
#   10,
#   2,
#   27,
#   40,
#   38,
#   91,
#   7156],
#  [16, 21, 5, 2, 15, 297, 2190, 32, 22, 7157],
#  [8, 9, 19, 2, 136, 40, 38, 502, 365, 726, 6],
#  [16,
#   1,
#   57,
#   5,
#   33,
#   1,
#   95,
#   3,
#   276,
#   53,
#   36,
#   71,
#   7,
#   518,
#   3,
#   10,
#   98,
#   5,
#   14,
#   75,
#   9,
#   15,
#   511,
#   2],
#  [11, 3, 251, 46, 1, 389, 23, 1, 251, 4, 1, 389, 6, 21, 5, 2, 1301],
#  [16,
#   39,
#   639,
#   307,
#   25,
#   7,
#   20,
#   5,
#   859,
#   178,
#   138,
#   4,
#   334,
#   27,
#   3,
#   20,
#   26,
#   31,
#   4,
#   88,
#   1225],
#  [12, 23, 1, 7, 3, 3413, 3414, 32, 22, 2068, 3415],
#  [11,
#   35,
#   1,
#   57,
#   5,
#   1,
#   33,
#   388,
#   2413,
#   3,
#   26,
#   15,
#   1211,
#   90,
#   1,
#   1,
#   77,
#   6,
#   1723,
#   108],
#  [12, 11, 59, 15, 27, 1428, 1, 31, 3, 384, 2, 161, 19, 299, 13, 315, 19, 6],
#  [8, 1, 55, 335, 35, 13, 224, 1, 7158, 7159, 46, 390, 51, 34],
#  [8, 3, 15, 247],
#  [8, 485, 49, 126, 4, 353, 659, 66, 340],
#  [8,
#   1231,
#   1,
#   20,
#   883,
#   10,
#   435,
#   1145,
#   30,
#   48,
#   6,
#   144,
#   553,
#   4,
#   119,
#   25,
#   65,
#   2,
#   27,
#   1,
#   6,
#   161],
#  [11, 7, 86, 142, 30, 59, 91, 6, 1, 7, 7160, 577, 51, 29, 31, 127, 7161],
#  [8,
#   13,
#   1,
#   206,
#   5,
#   2,
#   327,
#   27,
#   999,
#   1,
#   2,
#   470,
#   7,
#   1,
#   241,
#   9,
#   1,
#   85,
#   199,
#   13,
#   1765],
#  [17, 50, 29, 6, 21, 10, 20, 58, 49, 50, 39, 2, 23, 7162, 322, 109, 170],
#  [11, 125, 33, 334, 25, 2, 9, 15, 35, 1, 2, 319, 32, 22, 7163, 14],
#  [8,
#   1,
#   295,
#   20,
#   54,
#   26,
#   51,
#   130,
#   238,
#   13,
#   190,
#   43,
#   25,
#   1,
#   27,
#   1,
#   13,
#   264,
#   133,
#   22,
#   49],
#  [12,
#   112,
#   1,
#   106,
#   530,
#   10,
#   145,
#   6,
#   1352,
#   10,
#   73,
#   4,
#   496,
#   2,
#   415,
#   6,
#   1,
#   11,
#   15,
#   668],
#  [12, 7164, 15, 3, 35, 101, 29, 5, 156, 29, 6, 171, 29, 516],
#  [11, 7165, 4, 4, 2, 7, 1, 28, 7166, 1],
#  [16, 1, 26, 1],
#  [8, 21, 5, 2, 331, 2, 1820, 1, 34, 1, 1, 67, 34, 13, 4, 46],
#  [8, 4, 1, 3231, 7167, 299, 2, 46, 103, 4, 2, 55],
#  [12,
#   28,
#   98,
#   10,
#   51,
#   40,
#   10,
#   115,
#   302,
#   95,
#   48,
#   3,
#   37,
#   5,
#   137,
#   4,
#   68,
#   235,
#   129,
#   3,
#   12],
#  [17, 93, 3, 27, 1929],
#  [11,
#   6,
#   28,
#   27,
#   2,
#   86,
#   38,
#   59,
#   91,
#   414,
#   9,
#   1,
#   66,
#   36,
#   71,
#   7,
#   144,
#   220,
#   458,
#   7,
#   58],
#  [12, 21, 5, 36, 71, 7, 95, 58, 7, 1, 1, 355, 3, 15, 4, 128, 15, 1, 164, 1420],
#  [17, 30, 4, 305, 1, 161, 21, 3, 5, 2, 305, 135],
#  [8,
#   45,
#   710,
#   39,
#   132,
#   3,
#   2472,
#   14,
#   309,
#   1,
#   127,
#   4,
#   1,
#   47,
#   26,
#   48,
#   6,
#   1072,
#   53],
#  [8, 623, 15, 171, 5, 93, 28, 4, 46, 701],
#  [11, 3, 26, 1, 37],
#  [8,
#   141,
#   35,
#   3225,
#   29,
#   1,
#   1,
#   539,
#   1808,
#   105,
#   3,
#   2,
#   29,
#   20,
#   42,
#   1473,
#   25,
#   243,
#   1362,
#   32,
#   22,
#   7168],
#  [17, 29, 2],
#  [12, 9, 187, 70, 43, 2, 434, 6, 1, 18, 456, 6, 15, 90, 43, 1, 1054, 9, 3],
#  [11,
#   12,
#   3,
#   97,
#   751,
#   290,
#   164,
#   1,
#   214,
#   2,
#   7169,
#   812,
#   27,
#   56,
#   961,
#   25,
#   1,
#   40,
#   566],
#  [17, 24, 18, 4, 15, 374, 29, 94],
#  [12,
#   603,
#   3,
#   20,
#   54,
#   53,
#   67,
#   14,
#   166,
#   62,
#   78,
#   14,
#   171,
#   80,
#   5,
#   74,
#   585,
#   100,
#   442,
#   70,
#   4,
#   20],
#  [69, 458, 1, 92, 10, 153, 1, 57, 9, 257, 38, 61, 115, 833, 446, 140],
#  [8,
#   202,
#   167,
#   10,
#   2169,
#   15,
#   132,
#   3,
#   124,
#   51,
#   14,
#   3,
#   836,
#   18,
#   51,
#   305,
#   7,
#   9,
#   51,
#   147,
#   1],
#  [8, 1248, 184, 552, 2, 86, 665, 66, 1, 2, 3, 22, 1, 110, 628],
#  [8,
#   178,
#   1334,
#   7170,
#   464,
#   19,
#   50,
#   418,
#   2,
#   55,
#   25,
#   57,
#   70,
#   1,
#   251,
#   25,
#   781,
#   18,
#   947,
#   15,
#   67,
#   178],
#  [8, 892, 1, 7171, 2, 776, 59, 229, 94],
#  [11,
#   15,
#   31,
#   2,
#   1,
#   51,
#   37,
#   30,
#   123,
#   58,
#   42,
#   108,
#   60,
#   2,
#   75,
#   13,
#   601,
#   1,
#   2,
#   22,
#   30,
#   123,
#   749],
#  [8,
#   1,
#   566,
#   48,
#   5,
#   3,
#   64,
#   108,
#   37,
#   1,
#   10,
#   658,
#   43,
#   64,
#   329,
#   37,
#   205,
#   67,
#   1,
#   55,
#   3373],
#  [8, 319, 1, 179, 1, 64, 7, 5, 266, 10, 3, 15, 2, 85, 66, 237, 179],
#  [11,
#   54,
#   359,
#   1554,
#   372,
#   10,
#   595,
#   43,
#   64,
#   31,
#   7,
#   7,
#   1,
#   7172,
#   3305,
#   1,
#   40,
#   135,
#   7173,
#   7174],
#  [12, 39, 243, 9, 2, 7, 195, 107, 228, 1, 199, 346, 1, 15, 2104, 7, 1, 703, 5],
#  [17, 23, 844, 303, 4, 1, 6, 516, 47],
#  [16, 1, 11, 26, 36, 71, 7, 72, 25, 42, 386, 29, 453, 2489, 261, 739, 5, 185],
#  [16, 124, 4, 83, 245, 65, 115, 115],
#  [8, 7175, 34, 907],
#  [12,
#   39,
#   371,
#   858,
#   39,
#   23,
#   4,
#   24,
#   264,
#   29,
#   396,
#   23,
#   46,
#   414,
#   227,
#   1149,
#   135,
#   227,
#   18,
#   22,
#   7176],
#  [12, 1, 73, 6, 7, 13, 36, 71, 72, 67, 1, 2, 55, 5, 56, 1, 33, 7177, 323],
#  [17, 60, 50, 2, 4, 27, 53, 1, 518],
#  [12, 7, 23, 7178, 4, 10, 844, 7179],
#  [8, 1127, 862, 712, 370, 141, 35, 103, 79],
#  [11, 573, 814, 47, 18, 4, 43, 6, 222, 25, 13, 1, 57, 659, 20, 7, 281, 53],
#  [16, 6, 24, 3, 62, 160, 4, 9, 7, 5, 297, 123, 36, 71, 21],
#  [8, 557, 599, 25, 6, 1096, 14, 1270, 1701, 2036, 6],
#  [11, 7180, 9, 50, 27, 9, 27, 9, 121, 49],
#  [17, 10, 3, 26, 178, 228, 7, 524, 30, 122, 27, 27, 260, 2449],
#  [8, 410, 145, 615, 74, 19, 372, 10, 200, 152, 1, 112, 2, 38, 13, 1063],
#  [17,
#   7,
#   195,
#   107,
#   7,
#   5,
#   22,
#   120,
#   5,
#   217,
#   525,
#   15,
#   961,
#   19,
#   102,
#   178,
#   9,
#   3,
#   82,
#   46,
#   167,
#   41],
#  [12, 52, 3, 1, 402, 1, 205, 5, 13, 1013, 105, 208, 72, 385, 90, 1, 49, 22],
#  [16,
#   295,
#   61,
#   44,
#   2,
#   278,
#   1,
#   297,
#   1,
#   24,
#   18,
#   3,
#   227,
#   1,
#   2,
#   47,
#   167,
#   51,
#   46,
#   104,
#   472,
#   481],
#  [16, 1, 827, 293, 19, 86, 54, 115, 24, 128, 4],
#  [17,
#   72,
#   3346,
#   111,
#   28,
#   2,
#   174,
#   46,
#   1,
#   2,
#   292,
#   462,
#   100,
#   126,
#   1,
#   2,
#   3028,
#   1389,
#   6,
#   1104,
#   68,
#   29],
#  [16, 4, 62],
#  [16, 56, 136, 40, 38, 391, 3, 328, 10, 1064, 7, 97, 59, 444, 37],
#  [8, 1, 26, 4, 48, 30, 522, 3, 68, 2, 88, 1, 47, 99, 25, 5, 125, 623],
#  [12, 949, 117, 268, 392, 2, 23, 64, 64, 10, 425, 1, 1, 1, 1, 1, 9, 3, 24],
#  [11,
#   6,
#   147,
#   23,
#   23,
#   94,
#   1,
#   63,
#   5,
#   3,
#   155,
#   1,
#   1,
#   46,
#   1,
#   325,
#   565,
#   76,
#   7181,
#   7182],
#  [17,
#   9,
#   15,
#   2,
#   280,
#   10,
#   306,
#   101,
#   3,
#   10,
#   1278,
#   73,
#   251,
#   108,
#   1,
#   2,
#   436,
#   10,
#   20,
#   265],
#  [8, 6, 34, 978, 13, 2, 23, 212, 9, 4, 6, 54],
#  [8, 23, 14, 18, 352, 933, 181, 4],
#  [12, 13, 101, 5, 10, 1015, 49, 58, 13, 1, 2, 227, 2, 1, 2, 1, 47, 837, 7],
#  [16, 21, 3, 7183, 7184],
#  [17,
#   9,
#   13,
#   7,
#   519,
#   337,
#   1,
#   60,
#   41,
#   13,
#   1603,
#   9,
#   1,
#   245,
#   1,
#   2,
#   7185,
#   29,
#   114,
#   3410,
#   271],
#  [12, 47, 249, 202, 153, 6, 1, 1, 2707, 396],
#  [12, 26, 45, 87, 249, 9, 1, 80, 2, 205, 19, 36, 71, 7, 9, 24],
#  [16, 96, 7, 1, 96, 673, 32, 22, 2019, 7186],
#  [16,
#   4,
#   30,
#   264,
#   465,
#   1,
#   123,
#   300,
#   462,
#   2379,
#   13,
#   147,
#   73,
#   35,
#   30,
#   13,
#   18,
#   14,
#   130],
#  [12, 41, 13, 24, 18, 489, 10, 20, 2, 7, 59, 442, 9, 3],
#  [17, 10, 41, 2542, 358, 2, 9, 3, 54, 3, 267, 7, 83, 1, 338, 2537],
#  [16,
#   56,
#   340,
#   13,
#   4,
#   543,
#   158,
#   5,
#   1763,
#   23,
#   7,
#   562,
#   165,
#   158,
#   23,
#   2,
#   4,
#   364,
#   28,
#   64,
#   76,
#   57],
#  [11, 137, 15, 21],
#  [17,
#   15,
#   3416,
#   238,
#   13,
#   28,
#   19,
#   830,
#   123,
#   31,
#   392,
#   6,
#   10,
#   1,
#   2,
#   3,
#   821,
#   899,
#   41],
#  [16, 54, 3, 626, 133, 217],
#  [8, 23, 46, 36, 71, 7, 1807, 63, 632, 136, 8, 70, 190, 100, 1, 300, 3, 34],
#  [17, 9, 2, 176, 5, 2, 37],
#  [11, 196, 18, 2, 1115, 603, 2, 4, 9, 6, 232, 577],
#  [16,
#   139,
#   70,
#   2,
#   113,
#   1,
#   320,
#   2,
#   6,
#   483,
#   613,
#   1124,
#   5,
#   13,
#   708,
#   127,
#   177,
#   413,
#   7187,
#   364,
#   37],
#  [16, 1, 3, 13, 5, 4],
#  [12,
#   15,
#   3,
#   132,
#   3,
#   1,
#   21,
#   59,
#   34,
#   6,
#   59,
#   198,
#   1218,
#   10,
#   4,
#   25,
#   160,
#   4,
#   63,
#   68,
#   25,
#   157,
#   53],
#  [11, 4, 89, 2, 1126, 1160, 1, 147, 21, 5, 463, 9, 19, 2, 298, 166, 6, 15, 6],
#  [8, 62, 841, 488, 353, 9, 1, 592, 186, 4, 173, 707, 5, 72, 5, 73, 48, 102],
#  [8, 13, 23, 13, 42, 27, 1, 3, 238, 264, 275, 2245, 9, 28, 826, 6, 549, 7188],
#  [8, 3, 39, 15, 230, 5, 7, 60, 15, 48, 81, 56, 2, 76, 1, 1134, 81, 199, 179],
#  [17, 1, 47, 78, 563, 26, 172, 48, 344],
#  [8, 7189, 4, 2, 61, 284, 1, 211, 5, 2, 189, 29, 3, 677],
#  [8, 3, 82, 121, 37, 18, 3, 10, 119, 1, 1, 106, 26, 433, 31, 4, 89, 432],
#  [89, 3, 26, 23, 10, 147, 19, 47, 3, 89, 112, 1426, 153, 34, 3, 17, 1929],
#  [11, 2, 39, 19, 112, 52, 1033, 4, 102, 26, 27, 154, 3, 25, 1189, 2],
#  [16,
#   375,
#   21,
#   2,
#   96,
#   836,
#   10,
#   341,
#   7190,
#   1,
#   932,
#   2,
#   144,
#   136,
#   364,
#   665,
#   37,
#   2,
#   13,
#   1625,
#   15],
#  [16, 6, 3, 89, 9, 47, 172, 58, 227, 25, 94, 21],
#  [12,
#   9,
#   65,
#   106,
#   841,
#   1529,
#   14,
#   116,
#   588,
#   60,
#   229,
#   1,
#   1219,
#   29,
#   501,
#   43,
#   40,
#   38,
#   2511],
#  [12, 21, 3],
#  [11, 160, 2, 18, 1, 6, 62],
#  [11, 7, 1, 323, 104, 30, 255, 106, 7191, 173, 4, 62, 151, 14, 183, 25],
#  [8,
#   1444,
#   129,
#   49,
#   6,
#   2,
#   75,
#   1,
#   35,
#   84,
#   1,
#   3,
#   136,
#   162,
#   7192,
#   42,
#   80,
#   358,
#   1,
#   418],
#  [12, 236, 1, 20, 1, 1159, 526, 287, 127, 9, 124],
#  [17, 13, 151, 7, 35, 813, 58, 43, 15, 100, 64, 661, 10, 1037, 916, 118],
#  [12, 21, 3, 5, 2, 338],
#  [16, 3, 1, 29, 18, 40, 51, 134, 1, 44, 18, 1, 125, 66, 10, 3, 6, 1, 7, 5],
#  [12,
#   144,
#   18,
#   80,
#   43,
#   29,
#   318,
#   39,
#   35,
#   78,
#   26,
#   7193,
#   4,
#   4,
#   113,
#   1,
#   46,
#   6,
#   10,
#   34,
#   2,
#   492],
#  [17, 2, 3, 842, 20, 851, 77, 2, 980, 34],
#  [17, 369, 27, 601, 1, 26, 1, 14, 782, 362, 39, 61, 27, 41, 33, 429, 146, 21],
#  [17,
#   184,
#   2,
#   791,
#   145,
#   19,
#   2,
#   366,
#   3,
#   37,
#   2,
#   15,
#   523,
#   3,
#   187,
#   1,
#   14,
#   40,
#   62,
#   1340,
#   81,
#   199],
#  [16,
#   233,
#   13,
#   219,
#   405,
#   43,
#   24,
#   18,
#   207,
#   203,
#   28,
#   9,
#   34,
#   24,
#   26,
#   260,
#   135,
#   138,
#   4],
#  [11, 250, 142, 73, 22, 1828, 43, 23, 407, 1, 130, 36, 71, 285, 7, 235, 1797],
#  [8, 62, 2543, 2, 568, 1, 54, 653, 126, 1, 14, 183],
#  [11,
#   2,
#   434,
#   6,
#   3,
#   15,
#   132,
#   40,
#   25,
#   482,
#   4,
#   1,
#   29,
#   1887,
#   2,
#   301,
#   7194,
#   357,
#   9,
#   1581],
#  [8, 21, 79, 5, 14, 595, 50, 261, 40, 98, 1351, 14, 337, 5, 1008],
#  [8, 6, 4, 278, 1, 303, 1, 95, 157, 53, 1, 4, 60, 87, 395, 3, 52, 18, 2, 73],
#  [17, 53, 30, 89, 1, 14, 449, 39, 1, 37, 1, 5, 56, 1, 33, 19, 188, 14, 70, 96],
#  [11, 21, 5, 605, 1145, 1667, 22],
#  [11, 386, 10, 6, 119, 1513, 18, 1, 2717, 10, 1545, 2267, 7195],
#  [8, 169, 15, 14, 130, 9, 412, 1, 56, 130, 15, 23],
#  [11,
#   30,
#   97,
#   26,
#   45,
#   378,
#   2,
#   116,
#   18,
#   70,
#   2,
#   55,
#   1,
#   1,
#   5,
#   4,
#   366,
#   100,
#   14,
#   306,
#   7],
#  [16, 24, 13, 21, 5, 2, 145],
#  [11,
#   540,
#   15,
#   42,
#   513,
#   25,
#   470,
#   5,
#   5,
#   844,
#   1060,
#   25,
#   187,
#   1,
#   57,
#   5,
#   56,
#   13,
#   33,
#   124,
#   53,
#   243],
#  [16, 24, 3, 62, 48, 102, 10, 2, 470, 136, 52, 30, 4, 53],
#  [8, 9, 54, 550, 168, 9, 233, 287, 31, 18, 1, 2, 197, 23, 5, 51, 7, 109],
#  [8, 835, 3, 2, 88, 136, 10, 126, 4, 366],
#  [12,
#   9,
#   24,
#   5,
#   23,
#   10,
#   118,
#   19,
#   173,
#   51,
#   6,
#   55,
#   10,
#   56,
#   126,
#   60,
#   2,
#   5,
#   123,
#   7196],
#  [16,
#   1601,
#   7,
#   13,
#   1,
#   58,
#   60,
#   2934,
#   120,
#   2162,
#   555,
#   29,
#   23,
#   1,
#   21,
#   457,
#   32,
#   22,
#   7197],
#  [8, 62, 18, 4, 70, 6, 55, 3],
#  [12, 21, 3, 30, 28, 1, 290, 7, 297],
#  [16, 79, 125, 15, 13, 220, 6, 1481, 3, 146, 252, 7198, 1, 170, 1021],
#  [11, 9, 4, 14, 140, 3, 10, 235, 54, 1, 57, 40, 38, 1, 1, 47, 1, 4, 9, 53],
#  [8, 26, 45, 84, 5, 556, 46, 5, 1, 88, 33, 13, 5, 4, 304],
#  [17, 95, 6, 80, 102, 1096, 23, 130, 28, 91, 51, 88, 2, 232, 80, 3002, 384],
#  [16, 21, 3],
#  [16, 39, 54, 9, 338, 133, 1, 143, 34, 1, 13, 22, 28, 271],
#  [16, 308, 440, 1262, 202, 286, 27, 15, 32, 22, 2571],
#  [8,
#   20,
#   121,
#   1,
#   241,
#   9,
#   3,
#   26,
#   13,
#   257,
#   38,
#   80,
#   5,
#   126,
#   105,
#   202,
#   398,
#   18,
#   1176],
#  [8, 3417, 354, 105, 23, 94, 707, 92, 10, 6, 13, 84, 5, 2, 891, 1417],
#  [12, 547, 53, 3, 1, 171, 1, 130, 95, 36, 7, 14, 7, 15, 4, 544, 35, 42],
#  [12,
#   11,
#   10,
#   6,
#   52,
#   14,
#   672,
#   99,
#   28,
#   3,
#   49,
#   516,
#   7199,
#   22,
#   1,
#   171,
#   29,
#   1064,
#   3068,
#   49,
#   1,
#   73],
#  [8, 21],
#  [12, 125, 125, 3418, 9, 6, 66, 1, 40, 38],
#  [12, 3, 4, 269, 29, 1, 177, 2507, 7],
#  [8, 7200, 22, 61, 28, 165, 711],
#  [11, 45, 1, 57, 9, 5, 1, 84, 4, 1, 25, 1, 184, 7201, 32, 22, 427, 7202],
#  [17, 4, 14, 2, 88, 1, 354, 1, 2, 1360, 4, 43, 312, 7, 19, 59, 442, 6, 119],
#  [17, 177, 137, 162, 1, 211, 1, 2, 55],
#  [12,
#   31,
#   3,
#   122,
#   65,
#   27,
#   189,
#   4,
#   2,
#   34,
#   13,
#   83,
#   6,
#   19,
#   74,
#   3,
#   695,
#   148,
#   383,
#   21,
#   3],
#  [12,
#   3200,
#   54,
#   230,
#   1,
#   199,
#   81,
#   86,
#   83,
#   126,
#   2,
#   467,
#   134,
#   25,
#   86,
#   252,
#   176,
#   2,
#   4],
#  [11,
#   28,
#   185,
#   19,
#   172,
#   334,
#   53,
#   5,
#   20,
#   116,
#   175,
#   10,
#   238,
#   161,
#   77,
#   2,
#   677,
#   2,
#   67,
#   37],
#  [11,
#   13,
#   882,
#   378,
#   7,
#   948,
#   19,
#   85,
#   72,
#   13,
#   442,
#   70,
#   521,
#   7,
#   279,
#   13,
#   224,
#   1,
#   1141],
#  [16, 815, 2, 111, 55, 1, 2, 1686, 85, 9, 622, 123, 2209, 32, 22, 2012, 7203],
#  [17,
#   14,
#   220,
#   350,
#   1094,
#   2,
#   18,
#   314,
#   842,
#   1,
#   454,
#   44,
#   29,
#   44,
#   4,
#   167,
#   2057,
#   193,
#   97,
#   89],
#  [8,
#   177,
#   2,
#   7,
#   821,
#   1,
#   246,
#   1,
#   4,
#   1,
#   3,
#   15,
#   28,
#   444,
#   12,
#   1,
#   36,
#   71,
#   7,
#   4,
#   23,
#   236,
#   8,
#   28],
#  [12, 21, 219, 28, 152, 6, 589],
#  [16, 218, 151, 9, 624, 484, 32, 22, 7204, 120, 7205],
#  [12, 108, 13, 1, 1406],
#  [12, 135, 5, 109, 13, 36, 71, 1, 95, 2543, 201, 5, 109, 24, 18, 152, 140],
#  [11, 1, 76, 57, 5, 1, 87, 249, 1, 80, 24, 81, 140, 158, 244, 7206],
#  [11, 319, 26, 272, 595, 555, 4, 172, 1, 543, 7207, 340, 353],
#  [8, 9, 2, 3, 10, 7, 46, 202],
#  [8,
#   41,
#   15,
#   31,
#   10,
#   3,
#   1,
#   3,
#   29,
#   84,
#   707,
#   445,
#   3,
#   73,
#   1,
#   280,
#   10,
#   84,
#   23,
#   258,
#   5,
#   3],
#  [16,
#   25,
#   1,
#   1985,
#   1036,
#   1,
#   1184,
#   267,
#   7,
#   196,
#   296,
#   1,
#   5,
#   111,
#   503,
#   24,
#   57,
#   4,
#   802],
#  [17,
#   9,
#   3,
#   26,
#   91,
#   1216,
#   19,
#   2269,
#   52,
#   15,
#   7208,
#   1,
#   240,
#   347,
#   3210,
#   19,
#   207,
#   934,
#   139],
#  [69,
#   20,
#   10,
#   412,
#   13,
#   23,
#   41,
#   13,
#   1,
#   15,
#   29,
#   1,
#   2,
#   186,
#   60,
#   28,
#   1,
#   2,
#   55,
#   13,
#   29,
#   5,
#   31,
#   46,
#   1,
#   155],
#  [17, 289, 6, 39, 28, 2, 1, 13, 240, 245, 33, 28, 279, 397, 15],
#  [17,
#   3,
#   4,
#   53,
#   23,
#   94,
#   19,
#   535,
#   3,
#   258,
#   280,
#   39,
#   43,
#   774,
#   1,
#   66,
#   132,
#   2,
#   49,
#   6,
#   2],
#  [11,
#   7,
#   1027,
#   67,
#   3370,
#   70,
#   55,
#   29,
#   174,
#   18,
#   86,
#   40,
#   38,
#   54,
#   78,
#   27,
#   175,
#   595],
#  [12, 200, 4, 68, 24, 3, 82],
#  [16,
#   250,
#   14,
#   40,
#   484,
#   1,
#   1,
#   15,
#   36,
#   150,
#   7,
#   19,
#   255,
#   51,
#   68,
#   1,
#   4,
#   9,
#   53,
#   21],
#  [12, 21],
#  [11,
#   6,
#   183,
#   4,
#   1,
#   124,
#   477,
#   185,
#   46,
#   13,
#   1,
#   13,
#   1,
#   48,
#   30,
#   2,
#   452,
#   4,
#   28,
#   2,
#   194,
#   194,
#   5],
#  [12,
#   37,
#   27,
#   126,
#   114,
#   31,
#   7,
#   94,
#   25,
#   1023,
#   147,
#   73,
#   1,
#   13,
#   362,
#   1,
#   28,
#   193,
#   25,
#   5,
#   34],
#  [11, 1, 3402, 10, 31],
#  [16, 1, 280, 2, 7, 39, 75, 24, 354, 5, 54, 334, 53, 9, 13, 179, 1, 2, 29],
#  [16,
#   87,
#   81,
#   83,
#   5,
#   135,
#   1,
#   1,
#   6,
#   268,
#   27,
#   81,
#   158,
#   35,
#   72,
#   100,
#   84,
#   1,
#   57,
#   7209],
#  [8, 21, 3, 110, 2481, 5, 14, 44],
#  [8, 27, 3, 47, 7210, 2, 77, 34, 4],
#  [8,
#   125,
#   376,
#   142,
#   1,
#   7211,
#   2,
#   113,
#   1,
#   320,
#   1,
#   23,
#   122,
#   1,
#   26,
#   45,
#   15,
#   144,
#   1,
#   2951],
#  [16,
#   41,
#   626,
#   7212,
#   7,
#   13,
#   58,
#   5,
#   33,
#   205,
#   260,
#   30,
#   5,
#   4,
#   1,
#   51,
#   43,
#   62,
#   200,
#   53],
#  [17, 2, 271, 5, 13, 1, 65, 93, 167, 6, 1, 274, 34, 9, 20, 10, 298, 2, 1, 281],
#  [12, 4, 43, 3, 1, 200, 4, 24, 3],
#  [8, 21, 3, 5, 488, 4, 47, 130, 20, 1, 311, 19, 1, 214, 635, 7213, 243, 7214],
#  [11,
#   36,
#   71,
#   14,
#   521,
#   7,
#   1630,
#   35,
#   1,
#   2,
#   13,
#   2,
#   30,
#   123,
#   23,
#   30,
#   1,
#   26,
#   4,
#   103,
#   101,
#   11,
#   79],
#  [16, 43, 137, 6, 4, 14, 140, 268, 1448, 6, 1429, 3, 5, 531, 158, 469],
#  [11, 585, 2, 39, 639, 30, 15, 273, 68, 2, 18],
#  [12, 112, 24, 41, 193, 1, 80, 1, 500, 19, 140, 24, 3, 44, 4, 3],
#  [8,
#   3,
#   5,
#   29,
#   213,
#   1,
#   80,
#   1449,
#   30,
#   54,
#   1,
#   5,
#   43,
#   3,
#   220,
#   1772,
#   13,
#   144,
#   1,
#   692],
#  [8, 158, 7215, 148, 1, 2, 7216],
#  [12, 96, 7, 142, 79, 10, 156, 15, 849, 481, 968, 1, 3401, 66, 177, 53, 82],
#  [17, 14, 191, 1, 192, 32, 22, 136, 7217, 20, 1304],
#  [17, 43, 5, 2, 86, 66, 1, 119, 10, 38, 156],
#  [9, 13, 101, 11, 17, 36, 71, 14, 7, 109, 1, 103, 783, 3, 2195, 1071],
#  [8, 585, 20, 67, 2, 18],
#  [11,
#   1109,
#   2061,
#   22,
#   78,
#   27,
#   3208,
#   1553,
#   5,
#   217,
#   35,
#   9,
#   15,
#   3,
#   36,
#   845,
#   7,
#   3,
#   41],
#  [11, 1757, 7, 5, 3, 15, 67, 96, 232, 45, 547, 21, 5, 132, 7, 1312],
#  [69, 1175, 28, 12, 24, 3, 44, 2953, 1, 61, 10, 4, 44, 1, 3, 32, 22, 492],
#  [8,
#   52,
#   24,
#   3,
#   1,
#   187,
#   46,
#   1,
#   55,
#   58,
#   7,
#   84,
#   1,
#   105,
#   131,
#   102,
#   19,
#   46,
#   3,
#   97,
#   119],
#  [16,
#   129,
#   1,
#   7,
#   139,
#   160,
#   2,
#   54,
#   6,
#   139,
#   1,
#   27,
#   2,
#   50,
#   124,
#   4,
#   207,
#   179,
#   7218],
#  [8, 255, 168, 4, 132, 154, 165],
#  [17, 24, 146, 28, 1, 173],
#  [11,
#   30,
#   201,
#   28,
#   1672,
#   185,
#   43,
#   147,
#   1,
#   262,
#   55,
#   3048,
#   1,
#   100,
#   1,
#   1917,
#   593,
#   404,
#   5,
#   64,
#   13],
#  [12,
#   58,
#   7,
#   215,
#   33,
#   4,
#   398,
#   166,
#   262,
#   94,
#   1,
#   164,
#   1,
#   20,
#   26,
#   25,
#   5,
#   926,
#   7219],
#  [11,
#   12,
#   30,
#   15,
#   1,
#   3,
#   7,
#   30,
#   213,
#   22,
#   84,
#   1,
#   14,
#   18,
#   5,
#   529,
#   1,
#   64,
#   35,
#   1,
#   151],
#  [16, 7220, 1, 4, 43, 7, 1336, 18, 4, 3, 10, 41],
#  [8, 39, 15, 318, 1, 1, 13, 23, 23, 318, 1, 1, 458, 234],
#  [12, 30, 18, 73, 354, 1, 14, 179, 50, 27, 101, 14, 66, 2384],
#  [16, 21, 5, 67, 141, 7, 5, 859, 1631],
#  [17, 14, 191, 1, 192, 32, 22, 719, 420, 23],
#  [16,
#   46,
#   15,
#   1,
#   2,
#   13,
#   297,
#   237,
#   4,
#   44,
#   13,
#   473,
#   5,
#   7,
#   1,
#   23,
#   41,
#   1,
#   29,
#   1,
#   693],
#  [17, 90, 148, 787, 143, 1, 50, 300, 1195, 1196, 321, 32, 22, 14, 161, 28],
#  [11, 21, 5, 313, 4, 19, 1973, 7, 7221],
#  [11, 12, 711, 45, 1, 57, 64, 5, 7, 6, 35, 19, 25, 254, 403, 1, 108, 61, 81],
#  [12,
#   65,
#   3,
#   77,
#   1,
#   85,
#   37,
#   10,
#   42,
#   88,
#   7,
#   80,
#   34,
#   29,
#   15,
#   3,
#   277,
#   6,
#   42,
#   833,
#   38],
#  [17, 161, 28],
#  [16, 24, 3, 7222, 2, 265, 5, 288, 2310],
#  [17, 155, 1416, 1785, 977, 1177, 1, 111, 481, 1232, 7223, 465, 32, 22, 7224],
#  [8,
#   7225,
#   4,
#   1,
#   361,
#   262,
#   29,
#   231,
#   337,
#   83,
#   7226,
#   1,
#   1,
#   1243,
#   88,
#   247,
#   38,
#   5,
#   209,
#   22],
#  [8,
#   2,
#   117,
#   467,
#   165,
#   2,
#   467,
#   23,
#   6,
#   2402,
#   6,
#   2403,
#   13,
#   5,
#   2,
#   1811,
#   1008,
#   32,
#   22,
#   7227],
#  [16,
#   9,
#   19,
#   5,
#   3,
#   6,
#   24,
#   18,
#   2,
#   4,
#   2,
#   15,
#   1001,
#   5,
#   2,
#   202,
#   1,
#   308,
#   83,
#   174,
#   106,
#   39,
#   34],
#  [69,
#   3,
#   1018,
#   7,
#   36,
#   150,
#   5,
#   218,
#   156,
#   1,
#   1,
#   571,
#   29,
#   406,
#   216,
#   243,
#   691,
#   162],
#  [11, 1, 86, 1, 1246, 29, 1, 7, 5, 58, 350, 50, 26, 166, 164, 29],
#  [12,
#   2,
#   412,
#   10,
#   352,
#   798,
#   123,
#   345,
#   53,
#   1,
#   412,
#   4,
#   20,
#   1,
#   37,
#   6,
#   110,
#   162,
#   40,
#   38],
#  [17, 14, 191, 1, 192, 32, 22, 7228],
#  [12, 189],
#  [11,
#   9,
#   24,
#   2,
#   18,
#   80,
#   1,
#   7,
#   253,
#   1,
#   151,
#   319,
#   6,
#   289,
#   52,
#   126,
#   118,
#   26,
#   45,
#   84],
#  [12, 43, 38, 1, 88],
#  [11,
#   1,
#   769,
#   508,
#   53,
#   30,
#   168,
#   9,
#   37,
#   37,
#   241,
#   257,
#   1534,
#   253,
#   1741,
#   37,
#   25,
#   197,
#   4],
#  [12, 21, 14, 134, 1, 7, 5, 494, 437, 7, 164, 251, 9, 75, 1, 7, 720, 136, 38],
#  [11, 7229, 9, 19, 197],
#  [16, 30, 123, 201, 1, 2, 3, 10, 13, 4, 479, 1080, 122, 44],
#  [12, 61, 102, 44, 4, 3],
#  [12,
#   59,
#   45,
#   1,
#   105,
#   5,
#   56,
#   336,
#   33,
#   87,
#   78,
#   716,
#   35,
#   244,
#   106,
#   2,
#   138,
#   7,
#   291],
#  [69, 87, 19, 41, 13, 5, 92, 24, 165, 2, 4, 83, 152, 7230, 256, 14, 4],
#  [11, 6, 35, 18, 80, 734, 1, 37, 9, 197, 23, 1, 39, 1453, 53, 811, 266],
#  [11, 178, 3223, 1, 2, 309, 50, 48, 2, 7231, 238, 66, 1473, 135],
#  [11, 9, 1, 3, 735, 43, 1039, 120, 22, 152, 73, 34, 1230, 1, 597, 22, 7232],
#  [17, 5, 66, 42, 3251, 1, 7, 66],
#  [11, 322, 3, 82, 39, 23, 4, 63, 2, 183, 6, 168, 5, 168, 1, 14, 183, 291],
#  [16, 7, 186, 360, 6, 2, 618, 129],
#  [8, 253, 341, 65, 26, 45, 73, 4, 1, 128, 20, 29, 79],
#  [12, 9, 65, 769, 84, 4, 313, 2, 60, 2, 15, 2763, 115],
#  [16, 52, 1, 51, 1, 89, 3, 15, 2085, 307, 25, 7, 23, 1, 5, 1578, 22, 10, 541],
#  [17,
#   26,
#   15,
#   7,
#   6,
#   93,
#   807,
#   5,
#   4,
#   116,
#   19,
#   2,
#   15,
#   332,
#   56,
#   119,
#   23,
#   41,
#   2701,
#   23],
#  [17, 62, 253, 4, 14, 275, 37, 5, 4, 517],
#  [16, 219, 28, 4, 2, 7233],
#  [8, 6, 1, 106, 1, 426],
#  [8,
#   2,
#   6,
#   98,
#   429,
#   4,
#   9,
#   51,
#   739,
#   1,
#   1,
#   42,
#   1289,
#   13,
#   144,
#   7234,
#   1,
#   692,
#   23,
#   576],
#  [8,
#   36,
#   7,
#   49,
#   5,
#   259,
#   1,
#   129,
#   160,
#   295,
#   25,
#   29,
#   23,
#   18,
#   1,
#   445,
#   1388,
#   420,
#   28,
#   485,
#   4],
#  [8, 2, 64, 921, 345, 32, 22, 7235, 7236],
#  [16, 4, 56, 110, 13, 206, 417, 301, 14, 66, 5, 469, 7, 19, 103, 79],
#  [8, 2094, 1, 21, 206, 417, 153, 68, 1, 3, 109, 6, 96, 7, 53, 7237],
#  [12, 322, 201, 5, 109, 170, 19, 558, 243, 927],
#  [11,
#   392,
#   3,
#   19,
#   1,
#   20,
#   2755,
#   9,
#   1,
#   698,
#   4,
#   97,
#   26,
#   6,
#   1541,
#   1,
#   34,
#   6,
#   47,
#   449],
#  [17,
#   14,
#   66,
#   97,
#   26,
#   162,
#   4,
#   1374,
#   14,
#   606,
#   60,
#   51,
#   7,
#   15,
#   36,
#   71,
#   23,
#   1,
#   30,
#   26,
#   269],
#  [11, 21],
#  [16, 631, 97, 188, 27, 2, 309],
#  [11,
#   552,
#   6,
#   25,
#   30,
#   20,
#   153,
#   164,
#   2432,
#   1,
#   2,
#   292,
#   22,
#   332,
#   419,
#   5,
#   53,
#   476,
#   65,
#   74],
#  [12, 3, 26, 1, 7, 9, 31, 49, 493, 5, 23, 529, 194, 2, 4, 10, 568],
#  [12, 10, 43, 545, 2, 18, 3, 54, 67, 1, 2, 55, 5, 23, 33, 95, 322],
#  [12, 168, 1, 3, 155, 4, 1, 78, 36, 7, 349],
#  [8,
#   173,
#   40,
#   1,
#   55,
#   9,
#   1,
#   117,
#   2,
#   85,
#   157,
#   6,
#   1527,
#   13,
#   4,
#   1,
#   105,
#   165,
#   111,
#   7,
#   90,
#   1,
#   35],
#  [12, 35, 74, 880, 40, 532, 2599, 49, 7238, 32, 22, 22, 7239],
#  [16, 61, 14, 44, 19, 1, 34, 50, 382, 53, 2, 76],
#  [11,
#   19,
#   13,
#   2,
#   15,
#   168,
#   126,
#   9,
#   20,
#   51,
#   164,
#   1593,
#   13,
#   54,
#   35,
#   2,
#   164,
#   746,
#   2745],
#  [21,
#   8,
#   5,
#   315,
#   68,
#   3,
#   24,
#   337,
#   2,
#   46,
#   3,
#   23,
#   25,
#   606,
#   53,
#   2,
#   2576,
#   2577,
#   1,
#   14,
#   1036,
#   110,
#   75],
#  [17, 35, 60, 63, 20, 2, 3333, 1, 244, 27, 99, 3, 94],
#  [17, 39, 67, 81, 24, 27, 263, 77],
#  [69, 9, 3, 444, 3, 10, 245, 1],
#  [8, 23, 446, 15, 2, 182, 5, 202, 7240, 32, 22, 7241, 2266],
#  [8,
#   65,
#   184,
#   1,
#   204,
#   1,
#   9,
#   30,
#   695,
#   1726,
#   7,
#   6,
#   45,
#   36,
#   150,
#   227,
#   55,
#   105,
#   7242],
#  [11, 12, 15, 361, 7243, 7244],
#  [8, 319, 1, 1, 2, 55, 288, 1, 35, 1, 1, 147, 1, 20, 1, 46, 1255],
#  [12,
#   21,
#   5,
#   2,
#   63,
#   1,
#   36,
#   71,
#   7,
#   1,
#   7,
#   195,
#   107,
#   4,
#   5,
#   42,
#   1,
#   28,
#   108,
#   317,
#   4,
#   222,
#   246],
#  [16,
#   74,
#   6,
#   41,
#   15,
#   720,
#   899,
#   5,
#   962,
#   1,
#   122,
#   649,
#   1,
#   6,
#   683,
#   4,
#   186,
#   97,
#   48,
#   34,
#   10,
#   6],
#  [16,
#   239,
#   25,
#   28,
#   568,
#   7245,
#   7,
#   7246,
#   54,
#   88,
#   164,
#   7,
#   106,
#   59,
#   4,
#   19,
#   647,
#   7247],
#  [11, 48, 10, 6, 13, 25, 1, 2, 35, 19, 4, 2, 51, 7, 115, 6, 309, 29, 1],
#  [17,
#   162,
#   167,
#   13,
#   18,
#   4,
#   1156,
#   210,
#   109,
#   170,
#   1231,
#   721,
#   3,
#   342,
#   4,
#   1,
#   271,
#   9,
#   30,
#   966,
#   25],
#  [17,
#   65,
#   28,
#   23,
#   286,
#   1896,
#   1,
#   28,
#   41,
#   91,
#   119,
#   1,
#   49,
#   9,
#   3,
#   82,
#   286,
#   1896,
#   25,
#   110,
#   41],
#  [8, 21, 5, 132, 163, 2, 51, 2, 283],
#  [12, 21, 26, 58, 2, 52, 126, 97, 409, 5, 145],
#  [11, 1828, 20, 55, 9, 262, 147, 1, 95, 6, 48, 2, 70, 136, 2690, 92, 37],
#  [12,
#   36,
#   7,
#   7,
#   54,
#   54,
#   1,
#   37,
#   303,
#   29,
#   63,
#   95,
#   187,
#   4,
#   1,
#   13,
#   274,
#   7,
#   244,
#   35,
#   21],
#  [16, 21, 21, 21, 5, 282, 152, 5, 3, 1322, 1, 21, 65, 302, 23, 13, 888],
#  [11, 21, 3, 19, 1, 241, 9, 50, 3, 9, 628],
#  [17, 93, 2, 38, 5, 2, 70, 335, 28, 38, 18, 126, 13, 184, 14, 2063, 1082, 25],
#  [8,
#   39,
#   47,
#   261,
#   102,
#   9,
#   294,
#   25,
#   1,
#   27,
#   187,
#   1,
#   57,
#   5,
#   92,
#   1,
#   528,
#   27,
#   276,
#   53,
#   1,
#   29,
#   54,
#   2,
#   252,
#   105],
#  [8, 23, 7248, 4, 495, 47, 3228, 665, 683, 1, 20, 8, 66, 7, 13, 6, 7249],
#  [17, 1, 62, 25],
#  [12, 120, 39, 3, 89, 140, 4, 6, 64, 772, 4],
#  [11, 39, 36, 7, 91, 7, 26, 9, 1, 3],
#  [8,
#   46,
#   1029,
#   759,
#   7,
#   4,
#   41,
#   110,
#   157,
#   153,
#   1,
#   4,
#   29,
#   31,
#   936,
#   9,
#   18,
#   60,
#   30,
#   245],
#  [11, 26, 45, 84, 1, 1, 613, 5, 23, 10, 33, 48, 70, 439, 7, 6, 778, 54, 302],
#  [12,
#   835,
#   3,
#   147,
#   73,
#   56,
#   2,
#   76,
#   23,
#   94,
#   113,
#   2,
#   3,
#   610,
#   2,
#   209,
#   1084,
#   3287,
#   5,
#   131],
#  [12,
#   105,
#   10,
#   118,
#   216,
#   35,
#   7250,
#   57,
#   1,
#   216,
#   105,
#   39,
#   157,
#   53,
#   364,
#   63,
#   68,
#   32,
#   22,
#   7251,
#   1114,
#   23],
#  [11, 278, 310, 72, 13, 1098, 1, 257, 38, 1, 1614, 151, 41, 247, 40, 38],
#  [12, 1, 164, 35, 21, 3],
#  [11, 13, 39, 1, 57, 9, 3, 20, 5, 13, 33, 1, 95, 28, 276, 53, 1, 6, 28],
#  [11, 6, 2, 668, 25, 144, 220, 91, 718, 88, 103, 79, 50, 49, 9, 2],
#  [8, 96, 51, 888, 110, 7252, 184, 14, 1583, 351, 110, 15, 58, 35],
#  [8,
#   1,
#   85,
#   33,
#   37,
#   781,
#   168,
#   4,
#   1,
#   1510,
#   315,
#   18,
#   869,
#   455,
#   45,
#   84,
#   5,
#   56,
#   64],
#  [11, 44, 1200, 3, 10, 34, 10, 14, 55],
#  [13,
#   43,
#   78,
#   1,
#   7253,
#   111,
#   33,
#   13,
#   5,
#   19,
#   231,
#   47,
#   1,
#   431,
#   43,
#   10,
#   4,
#   59,
#   58,
#   4,
#   17],
#  [12, 9, 2049, 137, 187, 1, 57, 43, 2975, 2976, 118, 60, 313, 14, 526, 320],
#  [8, 50, 21, 3],
#  [8, 24, 175, 163, 4, 6, 2, 537, 282, 311, 6, 174, 874, 134, 7],
#  [16,
#   190,
#   90,
#   600,
#   1580,
#   7254,
#   644,
#   10,
#   6,
#   310,
#   27,
#   220,
#   7255,
#   32,
#   22,
#   3307,
#   420],
#  [16,
#   132,
#   15,
#   90,
#   144,
#   9,
#   51,
#   308,
#   1262,
#   202,
#   3,
#   24,
#   47,
#   280,
#   78,
#   334,
#   467,
#   28],
#  [69, 7256, 58, 899, 295, 28, 4, 2, 2430, 5, 120, 2, 7257, 1192, 32, 22, 7258],
#  [11, 62, 200, 4, 24, 3, 19, 293],
#  [11, 1, 89, 59, 15, 63, 5, 338, 19, 63, 176, 99, 391, 24, 3, 31, 4, 89],
#  [16,
#   131,
#   77,
#   1,
#   998,
#   30,
#   50,
#   149,
#   14,
#   269,
#   5,
#   31,
#   152,
#   1413,
#   89,
#   9,
#   4,
#   6,
#   50,
#   27],
#  [69, 3, 50, 271, 596, 3, 73],
#  [12, 221, 9, 741, 26, 2, 143, 45, 536, 337, 2, 55],
#  [8, 62, 27, 687, 526],
#  [11,
#   6,
#   349,
#   345,
#   19,
#   10,
#   2,
#   158,
#   147,
#   1000,
#   172,
#   15,
#   1,
#   124,
#   4,
#   1,
#   1354,
#   394],
#  [12,
#   26,
#   58,
#   553,
#   4,
#   100,
#   250,
#   542,
#   314,
#   88,
#   198,
#   62,
#   256,
#   6,
#   29,
#   279,
#   7259,
#   62,
#   44],
#  [8, 1840, 96, 184],
#  [12,
#   135,
#   159,
#   37,
#   36,
#   330,
#   10,
#   3,
#   47,
#   599,
#   15,
#   19,
#   2,
#   672,
#   190,
#   37,
#   1700,
#   1,
#   297,
#   734],
#  [17,
#   1,
#   22,
#   5,
#   2,
#   525,
#   54,
#   170,
#   457,
#   21,
#   5,
#   438,
#   20,
#   1004,
#   49,
#   131,
#   77,
#   6,
#   114,
#   30,
#   965],
#  [8,
#   263,
#   101,
#   56,
#   31,
#   1,
#   432,
#   25,
#   1224,
#   23,
#   119,
#   20,
#   28,
#   7260,
#   3,
#   10,
#   3,
#   7261],
#  [17, 14, 191, 1, 192, 32, 22, 7262],
#  [16, 39, 28, 68, 19, 1, 28, 314, 19, 64, 19, 184, 2, 484, 203, 5, 3180],
#  [17, 316, 6, 4, 1, 831, 2, 18, 3, 82, 48, 4, 386, 9, 26, 91, 510, 1, 51, 66],
#  [12,
#   9,
#   35,
#   90,
#   1671,
#   171,
#   3,
#   25,
#   30,
#   9,
#   81,
#   309,
#   1,
#   140,
#   30,
#   57,
#   30,
#   170,
#   1,
#   7263],
#  [12, 6, 820, 1, 1554, 23, 10, 199],
#  [16, 20, 28, 21],
#  [17,
#   136,
#   3,
#   2083,
#   6,
#   5,
#   501,
#   10,
#   2491,
#   1201,
#   3407,
#   25,
#   7264,
#   98,
#   1030,
#   32,
#   22,
#   167,
#   7265,
#   75],
#  [11, 631, 294, 52, 13, 83, 5, 350, 14, 1375, 182, 1, 923, 22, 1, 3, 23],
#  [12, 609, 39, 748, 871, 118, 13, 1, 105, 5, 40, 38, 1083, 5, 86, 1, 40, 38],
#  [16,
#   3,
#   26,
#   1,
#   185,
#   19,
#   60,
#   308,
#   991,
#   50,
#   27,
#   639,
#   4,
#   25,
#   27,
#   260,
#   15,
#   400,
#   47,
#   21],
#  [16, 3, 382, 2, 991, 5, 2, 308, 2487, 180, 7266, 7267],
#  [8, 6, 27, 2, 23, 4, 49, 14, 66],
#  [8, 9, 4, 4, 113, 1, 149, 5, 7, 1, 3, 5, 1681, 335],
#  [11, 87, 18, 921, 1, 1, 34, 565, 767, 30, 26, 15, 63, 68, 1, 554, 4],
#  [8,
#   1,
#   638,
#   13,
#   33,
#   31,
#   7,
#   1,
#   73,
#   35,
#   67,
#   1,
#   2,
#   210,
#   205,
#   2,
#   59,
#   55,
#   5,
#   2,
#   18,
#   705,
#   40],
#  [16,
#   122,
#   3,
#   27,
#   1003,
#   7268,
#   9,
#   4,
#   334,
#   467,
#   83,
#   94,
#   2,
#   7269,
#   167,
#   25,
#   65,
#   112,
#   93,
#   28],
#  [17,
#   243,
#   9,
#   2,
#   4,
#   166,
#   5,
#   210,
#   678,
#   1,
#   1,
#   1122,
#   106,
#   6,
#   260,
#   9,
#   117,
#   13,
#   42,
#   22],
#  [8, 907, 5, 2, 185],
#  [8, 1, 5, 4, 1, 125, 3, 7, 18, 47, 6, 13, 164, 1, 5, 1606, 529],
#  [69, 4, 581, 702, 49, 275, 5, 58, 235, 29, 186],
#  [17,
#   47,
#   124,
#   86,
#   21,
#   14,
#   129,
#   755,
#   88,
#   5,
#   20,
#   137,
#   4,
#   2,
#   22,
#   15,
#   72,
#   36,
#   330,
#   6,
#   170],
#  [69, 163, 23, 10, 14, 1, 156, 912, 7, 28, 23, 72, 100, 427, 9, 87, 2148],
#  [8, 500, 2, 73, 108, 29, 35, 65, 37, 3, 6, 170, 19, 1, 13, 2, 117, 871],
#  [8, 432, 1, 2, 6, 177, 1, 282, 32, 22, 7270, 1233, 7271],
#  [12, 3, 89, 6, 586, 2, 258, 488, 317, 10, 322, 67, 414],
#  [69,
#   26,
#   1,
#   1652,
#   1360,
#   1,
#   1866,
#   1361,
#   2,
#   34,
#   3,
#   15,
#   458,
#   301,
#   32,
#   22,
#   1479,
#   1867],
#  [16, 14, 675, 179, 43, 132, 4, 92, 54, 6, 139, 226, 70, 2, 148, 243],
#  [12,
#   75,
#   14,
#   111,
#   1623,
#   11,
#   52,
#   2,
#   384,
#   3,
#   1,
#   505,
#   409,
#   27,
#   4,
#   205,
#   79,
#   113,
#   284,
#   2335],
#  [11, 196, 23, 576, 2, 147, 4, 2, 695, 163, 9, 22, 46, 13, 1],
#  [11,
#   108,
#   54,
#   580,
#   136,
#   40,
#   38,
#   372,
#   10,
#   185,
#   5,
#   70,
#   29,
#   2,
#   434,
#   70,
#   255,
#   753,
#   53],
#  [11,
#   8,
#   13,
#   345,
#   613,
#   13,
#   31,
#   180,
#   1,
#   278,
#   72,
#   666,
#   1,
#   67,
#   3,
#   1,
#   23,
#   7272,
#   10,
#   1424],
#  [17,
#   52,
#   126,
#   28,
#   24,
#   114,
#   26,
#   442,
#   265,
#   5,
#   4,
#   20,
#   18,
#   98,
#   10,
#   1,
#   413,
#   838,
#   60,
#   168],
#  [12, 1, 4, 3, 122, 1, 27, 15, 315, 32, 22, 7273],
#  [8,
#   1,
#   29,
#   30,
#   1,
#   72,
#   129,
#   287,
#   174,
#   154,
#   18,
#   4,
#   90,
#   7,
#   134,
#   7274,
#   28,
#   443,
#   1,
#   1239,
#   13],
#  [11, 62, 1303, 2, 327, 3359, 1, 225, 73, 1, 613, 32, 22, 3105, 7275],
#  [17, 221, 5, 1428, 10, 2, 119, 19, 9, 4, 6, 840, 54],
#  [16, 52, 19, 60, 41, 15, 36, 330, 3, 39, 26, 349, 216, 77, 3, 5, 85, 29, 42],
#  [17, 21, 5, 231, 3, 157, 3, 25, 88, 809, 112, 45, 1, 139, 142],
#  [12, 2, 7, 2, 315, 598, 7276, 254, 1, 97, 27, 5, 118],
#  [17,
#   131,
#   77,
#   51,
#   7277,
#   127,
#   4,
#   28,
#   174,
#   1,
#   2,
#   55,
#   299,
#   2,
#   20,
#   27,
#   68,
#   78,
#   7278],
#  [17, 155, 6, 111, 236, 481, 977, 3419, 111, 32, 22, 7279],
#  [8, 458, 1014, 375, 75, 109, 19, 7280, 1, 39, 43, 251, 7281, 6, 15],
#  [11, 61, 37, 40, 38, 5, 44, 1, 294, 24, 3, 62, 253, 2, 37, 15],
#  [8,
#   3,
#   97,
#   160,
#   6,
#   2,
#   70,
#   182,
#   95,
#   385,
#   412,
#   2,
#   56,
#   54,
#   10,
#   2,
#   1023,
#   233,
#   287,
#   21,
#   5,
#   115],
#  [11, 7282, 56, 1, 33, 1, 57, 5],
#  [12,
#   28,
#   98,
#   10,
#   51,
#   40,
#   10,
#   115,
#   302,
#   95,
#   48,
#   3,
#   37,
#   5,
#   137,
#   4,
#   68,
#   235,
#   129,
#   3,
#   12],
#  [8,
#   93,
#   153,
#   23,
#   3,
#   65,
#   42,
#   189,
#   60,
#   3,
#   242,
#   18,
#   3,
#   3,
#   10,
#   2,
#   13,
#   10,
#   7283,
#   26,
#   102],
#  [8, 43, 3, 6, 6, 125, 7284, 630, 42, 1, 337, 7],
#  [12, 28, 46, 6, 170, 21],
#  [69, 10, 85, 3, 82, 6, 7, 5, 271],
#  [8, 6, 65, 27, 96],
#  [8,
#   21,
#   18,
#   80,
#   7285,
#   1187,
#   7286,
#   5,
#   463,
#   4,
#   18,
#   15,
#   168,
#   3,
#   10,
#   27,
#   1,
#   461,
#   2,
#   235,
#   78,
#   94],
#  [8,
#   81,
#   23,
#   34,
#   5,
#   847,
#   448,
#   1,
#   2,
#   4,
#   1,
#   1,
#   33,
#   43,
#   3,
#   6,
#   4,
#   1,
#   57,
#   5,
#   1,
#   95,
#   25,
#   1,
#   81,
#   4],
#  [16, 48, 18, 311, 398, 652, 40, 38, 463, 4, 1, 111, 353, 239, 5, 263, 70],
#  [8, 7, 58, 1, 34, 2328, 551, 2, 2, 1, 7, 323, 29, 319],
#  [17, 21, 5, 2, 64, 18, 81, 32, 22, 7287, 2054],
#  [12, 197, 1, 138, 7],
#  [16, 6, 85, 1, 245],
#  [12,
#   1256,
#   38,
#   91,
#   1,
#   70,
#   13,
#   55,
#   45,
#   1,
#   214,
#   5,
#   64,
#   35,
#   223,
#   24,
#   18,
#   7,
#   185,
#   387,
#   179],
#  [16,
#   23,
#   789,
#   54,
#   23,
#   7,
#   36,
#   71,
#   1,
#   429,
#   146,
#   27,
#   116,
#   13,
#   42,
#   589,
#   319,
#   1324,
#   49],
#  [8, 1, 1286, 1, 486, 1, 19, 4, 151, 14, 1, 7, 120, 1514, 32, 22, 7288, 7289],
#  [8, 7290, 1, 1, 86, 5, 432, 485, 43, 136, 82],
#  [11,
#   322,
#   89,
#   6,
#   19,
#   35,
#   20,
#   26,
#   149,
#   23,
#   671,
#   15,
#   1,
#   83,
#   74,
#   2,
#   228,
#   6,
#   334,
#   53,
#   56,
#   2,
#   159],
#  [8, 59, 264, 2, 73, 19, 26, 1, 13, 10, 313, 5, 151, 41, 125, 13, 6],
#  [16, 1, 6, 216, 7, 435, 1, 19, 173, 1, 288],
#  [8, 62, 78],
#  [16, 21, 5, 132, 98, 10, 4, 7291, 2075, 2, 40, 38, 18, 524],
#  [16,
#   178,
#   13,
#   208,
#   205,
#   31,
#   1,
#   277,
#   19,
#   2,
#   81,
#   7292,
#   612,
#   116,
#   47,
#   27,
#   20,
#   614],
#  [11, 33, 1, 92, 39, 47, 89, 20, 1, 2, 1023],
#  [11, 86, 142, 10, 20, 4, 50, 103, 91, 91, 135, 9, 3, 79, 91],
#  [2535, 25, 1318, 1, 12, 9, 7293, 25, 13, 782, 7, 19, 30, 20, 27, 68, 23],
#  [8,
#   431,
#   83,
#   9,
#   228,
#   6,
#   13,
#   7294,
#   43,
#   48,
#   1,
#   35,
#   28,
#   1,
#   37,
#   6,
#   74,
#   8,
#   36,
#   71,
#   83,
#   9],
#  [17,
#   10,
#   14,
#   1837,
#   4,
#   6,
#   2,
#   15,
#   47,
#   28,
#   47,
#   79,
#   131,
#   77,
#   24,
#   49,
#   17,
#   6,
#   4,
#   194,
#   24,
#   946,
#   6,
#   228],
#  [17, 1, 2, 47, 9, 31, 2, 13, 226, 18],
#  [11, 3, 82, 23, 130],
#  [11, 252, 340, 33, 28, 72, 153, 48, 18, 70, 2, 5, 55, 1, 5, 1, 33],
#  [12, 35, 241],
#  [16, 45, 403, 9, 554, 617, 5, 2, 23, 3360, 509, 23, 4, 40, 1069, 46, 68, 4],
#  [16, 4, 19, 13, 400, 120, 2, 83, 737, 161, 464, 433, 2537, 7295, 43],
#  [12,
#   30,
#   26,
#   45,
#   201,
#   42,
#   108,
#   19,
#   61,
#   81,
#   14,
#   140,
#   1,
#   49,
#   1,
#   2,
#   6,
#   34,
#   10,
#   2,
#   29],
#  [11, 149, 15, 1, 2, 29, 25, 1297, 95, 2, 205, 7],
#  [17, 90, 914, 706, 353, 3371, 2126, 32, 22, 1, 7296],
#  [16, 21, 5, 2, 145, 13, 148, 18, 161, 405, 1, 167, 10, 51, 1575],
#  [8,
#   97,
#   1,
#   160,
#   83,
#   5,
#   1844,
#   1,
#   32,
#   22,
#   7297,
#   165,
#   6,
#   247,
#   38,
#   1,
#   3,
#   70,
#   268,
#   424,
#   367],
#  [8, 880, 217, 1, 13, 23, 6, 41, 115, 2, 24, 2, 1454, 37, 5, 4, 514, 257, 38],
#  [12, 43, 565, 10, 2, 24, 3, 54, 740, 53, 1, 91, 63],
#  [17, 6, 6, 20, 131, 1, 136, 9, 12, 593, 404, 1, 13, 3, 24, 31, 3, 868, 252],
#  [11,
#   2,
#   1,
#   1,
#   105,
#   5,
#   4,
#   431,
#   215,
#   27,
#   1,
#   14,
#   473,
#   7,
#   9,
#   28,
#   338,
#   10,
#   3,
#   81,
#   35],
#  [69,
#   7,
#   5,
#   43,
#   28,
#   23,
#   109,
#   13,
#   36,
#   71,
#   1,
#   571,
#   13,
#   4,
#   15,
#   33,
#   50,
#   3,
#   216,
#   1,
#   125,
#   66],
#  [12, 54, 204, 4, 62],
#  [11, 1, 703, 9, 14, 40, 38, 296, 6, 45, 692, 1, 908, 144],
#  [17, 13, 39, 332, 56, 236, 28, 17, 3, 82, 15, 96, 21, 5, 399],
#  [11,
#   6,
#   84,
#   18,
#   46,
#   10,
#   7,
#   37,
#   380,
#   2,
#   64,
#   10,
#   37,
#   6,
#   1,
#   2,
#   13,
#   3,
#   103,
#   101,
#   3,
#   79],
#  [69,
#   30,
#   15,
#   1,
#   7,
#   286,
#   186,
#   224,
#   1,
#   158,
#   19,
#   14,
#   46,
#   354,
#   1,
#   1556,
#   24,
#   256,
#   6,
#   1087],
#  [11,
#   5,
#   73,
#   1,
#   633,
#   168,
#   13,
#   1789,
#   479,
#   85,
#   1,
#   3354,
#   479,
#   29,
#   531,
#   479,
#   38,
#   1,
#   72,
#   48,
#   70],
#  [12, 6, 293, 2, 129, 1, 2, 727, 374, 24, 396, 10, 2, 18, 4, 1, 2, 138, 374],
#  [11, 4],
#  [17, 2373, 2, 1850, 10, 153, 58, 7298],
#  [11,
#   24,
#   15,
#   339,
#   52,
#   376,
#   2,
#   80,
#   13,
#   5,
#   7,
#   582,
#   413,
#   5,
#   58,
#   7,
#   123,
#   1,
#   13,
#   1,
#   1,
#   1,
#   223],
#  [16,
#   6,
#   135,
#   1628,
#   28,
#   74,
#   79,
#   1,
#   1,
#   66,
#   1,
#   504,
#   60,
#   3,
#   99,
#   49,
#   4,
#   1628,
#   2218],
#  [12, 65, 77, 131, 102, 62, 200],
#  [8, 20, 84],
#  [8,
#   3,
#   15,
#   40,
#   38,
#   3297,
#   43,
#   406,
#   59,
#   45,
#   1,
#   2,
#   76,
#   5,
#   178,
#   56,
#   64,
#   94,
#   276,
#   53,
#   1,
#   43,
#   29,
#   413],
#  [11, 33, 52, 81, 7, 6, 13, 36, 71],
#  [12, 319, 41, 176, 1, 209, 234, 48, 76, 63, 106, 5, 526],
#  [12, 146, 652, 7299, 68, 4],
#  [8, 61, 44, 9, 67, 46],
#  [12, 23, 1157, 5, 1, 13, 10, 96, 38, 20, 67, 553, 36, 330],
#  [12, 37, 17, 24, 3, 44, 1342, 1, 2, 315, 121, 1, 567, 2, 61, 599, 5, 333, 66],
#  [8, 221, 2, 8, 47, 18, 78, 49, 227, 33],
#  [12, 3, 6, 23, 4, 54, 48, 159, 331, 1, 37],
#  [8,
#   138,
#   4,
#   50,
#   1,
#   1220,
#   31,
#   3,
#   18,
#   113,
#   46,
#   5,
#   480,
#   74,
#   3,
#   1021,
#   24,
#   497,
#   1,
#   37,
#   754],
#  [11, 34, 10, 774, 14, 40, 2327, 9, 1, 3, 382, 53, 14, 76],
#  [17, 20, 442, 98, 10, 51, 95, 2, 511, 63, 1, 2, 23, 336, 33, 13, 93, 17],
#  [16, 9, 6, 39, 4, 77, 1, 39, 242, 167, 6, 21, 3],
#  [8, 3, 409, 36, 7, 7, 3, 10, 3420, 109, 170, 378, 2, 29],
#  [8, 45, 1, 3, 59, 499, 1, 145, 42, 136, 776, 43, 18, 80, 2, 352, 35],
#  [8,
#   3,
#   23,
#   4,
#   28,
#   1055,
#   9,
#   2,
#   42,
#   13,
#   85,
#   5,
#   4,
#   28,
#   41,
#   1,
#   167,
#   3,
#   6,
#   3,
#   47,
#   256],
#  [11, 45, 1, 57, 5, 56, 1, 33, 35],
#  [17,
#   46,
#   1752,
#   2,
#   129,
#   1,
#   43,
#   28,
#   156,
#   25,
#   156,
#   28,
#   210,
#   25,
#   18,
#   129,
#   43,
#   25,
#   156,
#   126,
#   10,
#   37,
#   4,
#   162,
#   43,
#   2],
#  [16, 9, 1, 229, 479, 1080, 9, 116, 19, 20, 260],
#  [17,
#   231,
#   561,
#   7300,
#   1,
#   838,
#   490,
#   141,
#   7301,
#   137,
#   30,
#   15,
#   1,
#   148,
#   79,
#   3,
#   1,
#   28],
#  [16, 349, 54, 128],
#  [11,
#   3361,
#   924,
#   25,
#   359,
#   58,
#   31,
#   180,
#   36,
#   71,
#   4,
#   611,
#   6,
#   43,
#   238,
#   13,
#   176,
#   5,
#   114,
#   103,
#   79],
#  [11, 52, 18, 664, 5, 81, 199, 60, 966, 168, 9, 31],
#  [11,
#   3,
#   2099,
#   30,
#   59,
#   5,
#   126,
#   117,
#   639,
#   169,
#   2,
#   1238,
#   131,
#   56,
#   41,
#   2,
#   174,
#   122,
#   725],
#  [12, 15, 7, 323, 20, 141, 35, 1, 3, 87, 395, 3, 52, 58, 7, 99, 27],
#  [16, 21, 5, 3334, 624, 244, 27, 23, 111, 19, 6, 5, 7],
#  [8, 323, 1, 21],
#  [17,
#   97,
#   27,
#   1569,
#   19,
#   161,
#   7,
#   1317,
#   186,
#   1,
#   711,
#   1,
#   9,
#   24,
#   61,
#   27,
#   1,
#   186,
#   43,
#   1],
#  [12,
#   5,
#   64,
#   1515,
#   164,
#   1699,
#   279,
#   1333,
#   18,
#   4,
#   46,
#   46,
#   167,
#   95,
#   1333,
#   256,
#   75,
#   2,
#   7302,
#   49],
#  [8, 66, 3, 132, 923, 23, 6, 170, 5, 1, 963, 1, 20, 1, 1124, 744],
#  [16, 7, 23, 318, 36, 71, 1, 711, 52, 18, 2],
#  [8,
#   41,
#   1,
#   1291,
#   133,
#   14,
#   80,
#   23,
#   4,
#   39,
#   381,
#   2,
#   88,
#   104,
#   24,
#   424,
#   175,
#   41,
#   497],
#  [16,
#   5,
#   135,
#   78,
#   951,
#   73,
#   1,
#   18,
#   13,
#   15,
#   23,
#   3,
#   34,
#   234,
#   52,
#   89,
#   52,
#   1,
#   34,
#   15,
#   234],
#  [8, 206, 417, 101, 9, 3, 82, 178],
#  [8, 3, 26, 1, 7, 9, 31, 49, 493, 5, 23, 529, 194, 2, 4, 10, 568],
#  [12, 276, 53, 1, 35, 1, 4, 87, 73, 563],
#  [69,
#   205,
#   51,
#   66,
#   695,
#   36,
#   460,
#   7,
#   1,
#   43,
#   1,
#   463,
#   51,
#   40,
#   18,
#   2,
#   581,
#   13,
#   67,
#   28,
#   443],
#  [17, 6, 48, 4, 277, 196, 273, 176, 181, 190],
#  [11, 7, 3, 10, 73, 6, 170, 1323, 41, 97, 2, 3, 2, 88],
#  [69, 59, 4, 5, 109],
#  [11, 1412, 4, 7, 62, 21, 2, 129, 10, 96, 4, 1761],
#  [11, 4, 21, 3, 2, 96, 232, 1366, 2, 7, 1, 603],
#  [11, 2, 55, 129, 6, 45, 806, 1, 1311, 2, 18, 80, 123, 7303],
#  [16, 21, 5, 14, 74, 3, 82, 357],
#  [17,
#   106,
#   193,
#   6,
#   7,
#   1,
#   26,
#   110,
#   423,
#   6,
#   1976,
#   3,
#   1,
#   119,
#   2,
#   368,
#   13,
#   471,
#   6,
#   7304],
#  [8, 1031, 21, 110, 5, 1154, 3, 13, 148, 18, 74, 72, 84, 5, 92],
#  [8, 778, 1, 42, 9, 468, 14, 10, 10, 1037, 34, 158, 13, 2146],
#  [12, 3, 49, 79, 7, 360, 67, 84, 1, 7, 134, 14, 1275, 15, 1, 28],
#  [12, 96, 21, 658],
#  [16,
#   6,
#   56,
#   2291,
#   142,
#   56,
#   2,
#   76,
#   9,
#   34,
#   10,
#   14,
#   80,
#   15,
#   36,
#   71,
#   7,
#   26,
#   2,
#   34,
#   25,
#   80],
#  [12,
#   43,
#   108,
#   1461,
#   19,
#   14,
#   47,
#   117,
#   6,
#   56,
#   118,
#   198,
#   3,
#   1,
#   6,
#   492,
#   46,
#   15,
#   1,
#   2,
#   55],
#  [11, 2128, 840, 52, 59, 45, 422, 4],
#  [12,
#   9,
#   302,
#   60,
#   3,
#   1403,
#   25,
#   1724,
#   25,
#   2,
#   1830,
#   10,
#   1,
#   2364,
#   4,
#   3090,
#   31,
#   7,
#   10,
#   1202,
#   32,
#   22,
#   3091],
#  [16,
#   6,
#   21,
#   3,
#   26,
#   1,
#   548,
#   349,
#   6,
#   913,
#   575,
#   1,
#   14,
#   4,
#   3,
#   24,
#   272,
#   29,
#   390,
#   7,
#   3,
#   239],
#  [12, 184],
#  [8, 373, 9, 301, 75, 482, 14, 521, 7, 5, 176],
#  [16, 21, 5, 438, 75, 2, 308, 1435, 286, 440, 139, 32, 22, 43, 420],
#  [11, 221, 30, 15, 1, 389, 97, 59, 23, 3, 6],
#  [8,
#   52,
#   1,
#   1616,
#   122,
#   3,
#   266,
#   2,
#   8,
#   404,
#   1,
#   245,
#   9,
#   665,
#   49,
#   1,
#   88,
#   10,
#   6,
#   829],
#  [11, 9, 298, 81, 19, 789, 4, 120, 14, 218],
#  [16, 33, 221, 1, 18, 6, 178, 129, 2, 525, 1, 420, 141, 4, 2, 164, 1, 107],
#  [8, 703, 9, 14, 471, 10, 331, 7305],
#  [16,
#   342,
#   895,
#   14,
#   311,
#   70,
#   1,
#   89,
#   10,
#   30,
#   50,
#   18,
#   3,
#   19,
#   2,
#   15,
#   669,
#   3,
#   126,
#   32,
#   22,
#   2051],
#  [12,
#   461,
#   3,
#   82,
#   15,
#   736,
#   610,
#   782,
#   127,
#   801,
#   1,
#   815,
#   230,
#   93,
#   153,
#   41,
#   5,
#   13,
#   262],
#  [16, 263, 43, 13, 21, 3, 56, 110, 6, 2, 176, 30, 49, 3, 270],
#  [29, 17, 14, 191, 1, 192, 32, 22, 7306],
#  [11, 54, 48, 428, 1, 172, 149, 90],
#  [11, 92, 1, 57, 5, 140],
#  [8, 24, 30, 18, 1, 207, 197, 104, 20, 2, 107, 30, 59, 6, 14, 140, 7307],
#  [11, 562, 113, 1, 5, 7, 43, 22, 1, 255, 51, 10, 7, 13, 36, 150, 343, 1, 151],
#  [11, 35, 1, 57, 9, 40, 98, 386, 10, 102, 50, 382, 53, 2, 76, 154, 25],
#  [11, 893, 1165, 60, 14, 7, 58, 1, 99, 166, 6, 30, 15, 691, 216, 14, 47, 7],
#  [11, 2, 86, 20, 255, 174, 296, 67, 166],
#  [17, 3, 172, 36, 71, 2, 34, 3, 22],
#  [8, 85, 157, 2098, 4, 9, 23, 429, 146, 538, 380, 127, 287],
#  [12, 273, 15, 4, 139, 427, 21, 5, 768],
#  [11,
#   4,
#   178,
#   710,
#   33,
#   1,
#   57,
#   578,
#   24,
#   3,
#   62,
#   160,
#   4,
#   10,
#   6,
#   1573,
#   87,
#   27,
#   1428,
#   41],
#  [16, 54, 37, 40, 532, 1, 50, 27, 313, 109],
#  [17, 1283, 209, 74, 536, 113, 46, 1, 152, 2, 2293, 919, 50, 27, 206, 102],
#  [12, 51, 68, 13, 187, 1, 7, 109, 638, 2, 25, 438, 26, 48, 1, 70, 128],
#  [12, 3, 89, 6, 586, 2, 258, 488, 317, 10, 322, 67, 414],
#  [8, 573, 20, 1, 2, 210, 49, 272, 1, 700, 67, 15, 5, 3421, 7308],
#  [11,
#   36,
#   71,
#   2,
#   23,
#   136,
#   10,
#   83,
#   1,
#   1084,
#   5,
#   2,
#   37,
#   229,
#   1246,
#   472,
#   176,
#   41,
#   102,
#   24,
#   75],
#  [12, 21, 3, 2, 15, 2542, 189],
#  [12, 5, 2, 25, 33, 63, 472, 481, 6, 1, 34, 24, 48, 63, 36, 7, 637, 7309],
#  [11,
#   7,
#   605,
#   1,
#   4,
#   158,
#   1,
#   148,
#   113,
#   1,
#   198,
#   25,
#   23,
#   13,
#   36,
#   71,
#   187,
#   1,
#   57,
#   56,
#   1,
#   64,
#   28,
#   44],
#  [11, 59, 45, 1, 57, 81, 4, 1, 83, 5, 56, 33, 24, 102, 62, 4, 291],
#  [12,
#   2,
#   88,
#   141,
#   35,
#   1,
#   14,
#   118,
#   1,
#   89,
#   52,
#   275,
#   1,
#   44,
#   4,
#   9,
#   6,
#   161,
#   56,
#   340],
#  [8, 1258, 52, 24, 165, 612, 135, 1, 1076, 399, 1872, 3],
#  [17, 48, 48, 1055, 3, 3, 50, 256, 6],
#  [11, 7310, 41, 15, 1612, 133, 10, 578, 1, 285, 363, 92, 57, 65, 48, 1, 277],
#  [29, 17, 14, 191, 1, 192, 32, 22, 7311, 75],
#  [16, 397, 13, 9, 14, 683, 5, 1400, 9, 2110, 1190, 1, 310, 15],
#  [17, 7, 47, 165, 13, 34, 314, 377, 138, 25, 228, 781, 7312, 1, 280, 28, 47],
#  [8, 52, 24, 1, 26, 18, 15, 29, 18, 80, 5, 99, 1, 33, 13],
#  [69, 7, 1, 13, 13, 240, 48, 70, 92, 28, 183, 20, 52, 1, 4, 1, 1, 7, 21],
#  [8, 52, 19, 531, 251, 54, 307, 25, 1, 5, 31, 7, 170, 29, 246, 589],
#  [12, 75, 10, 102, 4, 131, 5, 35, 72, 50, 27, 23, 809, 56, 20, 4],
#  [16, 458, 201, 391, 20, 19, 51, 2, 15, 1063, 1, 90, 29, 244, 7313],
#  [17, 24, 30, 18, 631, 151, 1, 254, 10, 264, 45, 1, 55, 9, 795, 798],
#  [12, 9, 75, 18, 1, 61, 49, 9, 7314, 848, 2, 3, 21, 5, 1837],
#  [8, 153, 29, 1224, 64, 724, 2533, 1, 1, 263, 386, 170, 714, 32, 22, 7315],
#  [12, 1442, 40, 38, 5, 265, 4, 13, 84, 5, 4, 502, 658, 43, 6, 7, 21, 3],
#  [8, 6, 2, 105, 1, 311, 216, 42, 108, 42, 162, 32, 22, 7316],
#  [11,
#   183,
#   47,
#   31,
#   4,
#   81,
#   158,
#   106,
#   193,
#   66,
#   42,
#   135,
#   441,
#   35,
#   1,
#   57,
#   5,
#   92,
#   44],
#  [17, 9, 2, 78, 13, 18, 83, 664, 24, 18, 34, 113, 1, 29, 24, 18, 34, 158, 21],
#  [11, 6, 99, 48, 53, 1, 33, 1, 75, 14, 1, 75, 6, 862, 399],
#  [12, 4, 19, 3, 759, 31, 13, 10, 14, 46, 1256, 66],
#  [8, 21, 1289, 7317, 6, 5, 263, 40, 38, 208, 550, 46, 23, 1, 3, 4, 51],
#  [8, 21, 3],
#  [12, 4, 2, 1, 2, 138, 7],
#  [12, 188, 93, 577, 2, 197, 37],
#  [17,
#   80,
#   652,
#   1,
#   7318,
#   74,
#   128,
#   1,
#   2,
#   1602,
#   7319,
#   7320,
#   7321,
#   7322,
#   32,
#   22,
#   3144,
#   7323],
#  [69, 4, 6, 54, 3, 1, 26, 309, 5, 694, 130],
#  [11, 60, 18, 456, 13, 48, 5, 6, 1361, 34, 145, 229, 13, 2, 90, 10, 596, 672],
#  [16, 54],
#  [16,
#   29,
#   111,
#   232,
#   109,
#   25,
#   3,
#   36,
#   7,
#   7,
#   310,
#   182,
#   1,
#   3,
#   112,
#   24,
#   18,
#   4,
#   1,
#   125,
#   7],
#  [8, 462, 149, 13, 1, 2, 68, 4, 10, 7324, 100, 13, 33, 1, 14, 55, 2544, 7325],
#  [12, 21, 159, 10, 84, 15, 100, 339, 4, 5, 3, 261, 4, 6, 9, 3, 31, 40],
#  [8, 345, 130, 1, 23, 90, 10, 10, 2035, 5, 3, 912, 6, 9, 24, 37, 19, 6],
#  [16, 2367, 2980],
#  [8, 103, 6, 7, 58, 1, 33, 42, 1, 7326, 23, 1, 15, 37, 1842, 96, 232],
#  [16, 24, 3, 62, 200, 24, 239],
#  [11, 59, 45, 1, 57, 74, 25, 61, 343, 36, 71, 7, 5, 170, 254, 109, 62, 44],
#  [8, 75, 21, 3],
#  [8,
#   112,
#   1516,
#   53,
#   57,
#   182,
#   64,
#   1,
#   37,
#   104,
#   10,
#   1619,
#   4,
#   166,
#   137,
#   2,
#   64,
#   31,
#   180,
#   1,
#   197,
#   1235],
#  [12, 852, 6, 171, 28, 322, 73, 1992],
#  [8,
#   1210,
#   47,
#   4,
#   1,
#   374,
#   10,
#   85,
#   114,
#   127,
#   4,
#   766,
#   10,
#   1,
#   95,
#   536,
#   24,
#   446,
#   20,
#   72,
#   679],
#  [16, 23, 42, 5, 1088, 161, 1800, 1, 78, 31, 5, 90, 6, 24, 15, 165, 49, 22],
#  [12, 7327, 3, 6, 38, 3, 28, 1, 167],
#  [12, 92, 7, 5, 726, 1, 95, 48, 3, 13, 92, 317, 2, 18, 1, 181, 1048, 3137],
#  [8,
#   2,
#   45,
#   343,
#   5,
#   19,
#   9,
#   2,
#   646,
#   73,
#   153,
#   298,
#   176,
#   5,
#   402,
#   122,
#   27,
#   2,
#   4,
#   42],
#  [17,
#   310,
#   1613,
#   2,
#   834,
#   138,
#   236,
#   7328,
#   616,
#   3,
#   2,
#   547,
#   124,
#   524,
#   3,
#   6,
#   211,
#   4,
#   3,
#   357],
#  [11, 155, 7, 10, 3, 15, 206, 5, 913, 24, 194, 2, 181, 5, 2, 13, 3, 10, 3, 61],
#  [8, 6, 720, 13, 84, 1, 1052, 55, 217, 5, 342, 33, 1, 103, 213, 6, 597, 79],
#  [3237, 30, 21, 15, 26, 3, 675, 742, 14, 7],
#  [17, 246, 23, 236, 120, 1173, 41, 1, 262, 31, 34, 1, 85, 482, 23, 34],
#  [8,
#   87,
#   424,
#   6,
#   5,
#   2,
#   133,
#   23,
#   2,
#   26,
#   6,
#   1,
#   3422,
#   1,
#   124,
#   6,
#   37,
#   203,
#   5,
#   960,
#   3422],
#  [17, 21, 26, 1473, 172],
#  [69,
#   74,
#   78,
#   3,
#   2857,
#   1,
#   303,
#   19,
#   1,
#   1125,
#   19,
#   3,
#   41,
#   1,
#   1900,
#   65,
#   93,
#   78,
#   15,
#   7,
#   3,
#   10,
#   41],
#  [16,
#   26,
#   3,
#   1513,
#   67,
#   2,
#   30,
#   20,
#   63,
#   3,
#   68,
#   60,
#   30,
#   26,
#   102,
#   207,
#   996,
#   14,
#   484,
#   105],
#  [8, 178, 21, 5, 1, 721, 4, 5, 659, 13, 36, 71, 7, 35, 6, 13, 190, 74, 7329],
#  [11, 6, 2, 23, 4, 42, 14, 66, 190, 6],
#  [12,
#   83,
#   80,
#   1945,
#   31,
#   118,
#   1,
#   105,
#   84,
#   5,
#   1,
#   33,
#   1,
#   336,
#   1,
#   14,
#   76,
#   157,
#   53,
#   1,
#   118],
#  [8, 106, 1816, 5, 3, 82, 717, 7, 6, 3, 24, 837],
#  [12,
#   6,
#   260,
#   7,
#   171,
#   28,
#   28,
#   48,
#   13,
#   36,
#   150,
#   42,
#   108,
#   1,
#   13,
#   3,
#   24,
#   44,
#   41,
#   9,
#   15,
#   51,
#   116],
#  [16,
#   1389,
#   42,
#   45,
#   1269,
#   5,
#   2,
#   86,
#   136,
#   373,
#   9,
#   236,
#   23,
#   1,
#   231,
#   13,
#   42,
#   1,
#   883],
#  [8, 169, 14, 130],
#  [11, 3, 54, 25, 27, 1, 286, 43, 35, 10, 45, 536, 1, 521, 7],
#  [16, 15, 3, 3254, 1, 15, 991, 2, 308, 440, 52, 1343, 1, 436, 6, 525, 443],
#  [16, 20, 41, 13, 252, 53, 1, 1938, 84, 5, 20, 1, 13],
#  [8, 190, 47, 7, 5, 259, 1718, 2198, 114, 35],
#  [16, 65, 93, 28, 2, 245, 52],
#  [16,
#   1081,
#   1,
#   14,
#   498,
#   286,
#   723,
#   141,
#   35,
#   52,
#   46,
#   3,
#   299,
#   27,
#   5,
#   766,
#   4,
#   1,
#   310],
#  [8, 26, 51, 34, 146, 25, 13, 1, 41, 21, 2, 244, 112, 61, 6, 1, 4],
#  [17, 14, 191, 1, 192, 32, 22, 7330, 215],
#  [11, 20, 21, 3, 30, 6, 347, 321, 32, 22, 23, 7331],
#  [12, 96, 21, 658],
#  [21,
#   3,
#   8,
#   8,
#   1,
#   29,
#   6,
#   983,
#   265,
#   366,
#   26,
#   3,
#   45,
#   15,
#   168,
#   10,
#   1,
#   31,
#   4,
#   89,
#   1],
#  [11,
#   102,
#   4,
#   325,
#   279,
#   10,
#   224,
#   46,
#   1,
#   1469,
#   214,
#   6,
#   48,
#   58,
#   64,
#   31,
#   180,
#   715,
#   23,
#   46,
#   1,
#   1469],
#  [11,
#   47,
#   779,
#   199,
#   42,
#   1768,
#   24,
#   42,
#   98,
#   361,
#   199,
#   242,
#   18,
#   134,
#   42,
#   51,
#   22,
#   2468],
#  [69, 4, 986, 91, 4, 49, 918, 6, 119, 86, 47, 28, 13],
#  [8, 75, 21],
#  [69, 108, 37, 28, 138, 363, 159, 156, 43, 22],
#  [8, 3, 311, 161, 20, 1, 2, 292],
#  [12,
#   198,
#   2,
#   181,
#   105,
#   1,
#   33,
#   31,
#   180,
#   13,
#   198,
#   68,
#   1,
#   57,
#   5,
#   56,
#   33,
#   3,
#   155,
#   1,
#   95,
#   257,
#   70],
#  [16, 20, 26, 114, 43, 138, 4, 120],
#  [16, 59, 45, 1, 57, 23, 1, 33, 504, 20, 19, 2030, 32, 22, 7332],
#  [11, 35, 1, 1012, 731, 10, 14, 76, 4],
#  [69, 97, 42, 6, 1, 51, 138, 66, 851, 20, 32, 22, 7333],
#  [11, 7334, 34, 43, 34],
#  [16, 239, 759, 395, 3, 43, 87, 70, 338, 168, 39, 994, 1, 333, 234],
#  [16,
#   47,
#   264,
#   1184,
#   284,
#   79,
#   2544,
#   220,
#   1107,
#   9,
# ...
#  [16, 26, 7, 3, 10, 1365, 109, 94, 24, 343, 5, 1, 274, 7, 104, 10, 2, 691, 35],
#  [17, 7382, 93, 17, 791, 211, 40, 38],
#  [12, 21, 3],
#  [8,
#   645,
#   28,
#   1704,
#   39,
#   58,
#   1,
#   1135,
#   7,
#   9,
#   1,
#   185,
#   1,
#   2,
#   285,
#   7,
#   6,
#   30,
#   15,
#   99],
#  [11, 253, 2, 27, 38, 5, 4, 21, 3, 110],
#  [11, 47, 1, 7383, 587],
#  [12, 20, 84, 1, 46, 5, 7, 217, 5, 73, 143, 1, 277, 9, 14, 38],
#  [16, 9, 24, 261, 19, 1455, 590, 307, 888],
#  [8,
#   7,
#   64,
#   58,
#   5,
#   22,
#   10,
#   31,
#   7,
#   129,
#   35,
#   30,
#   15,
#   609,
#   84,
#   205,
#   2,
#   26,
#   754,
#   448,
#   631,
#   18,
#   80],
#  [16, 7384, 3, 89, 60, 2, 23, 280],
#  [17, 14, 191, 1, 192, 32, 22, 7385, 833],
#  [11, 13, 201, 19, 1618, 46, 4, 982, 367, 40, 38, 56, 552, 136],
#  [16, 33, 31, 7, 19, 4, 10, 27, 3, 24, 44, 4, 18, 1, 1, 274, 7, 1, 161],
#  [11, 21, 5, 132, 7, 70, 2, 173, 1, 1, 812, 1, 151, 19, 7, 238, 92, 31, 7],
#  [16, 99, 27, 2, 24, 351, 21, 20, 5, 14, 484, 1368, 30, 15, 282, 2, 450, 1932],
#  [8,
#   122,
#   3,
#   160,
#   4,
#   10,
#   6,
#   46,
#   65,
#   27,
#   1305,
#   630,
#   4,
#   24,
#   146,
#   34,
#   407,
#   1,
#   46,
#   380,
#   6,
#   32,
#   22,
#   7386],
#  [69, 540, 1, 979, 342, 479, 120, 810, 1, 2, 103, 90, 139],
#  [8, 10, 13, 20, 31, 2, 7, 388],
#  [8,
#   585,
#   1,
#   3,
#   6,
#   13,
#   240,
#   222,
#   19,
#   15,
#   20,
#   2,
#   18,
#   495,
#   30,
#   15,
#   19,
#   922,
#   68,
#   1,
#   4,
#   90],
#  [17,
#   21,
#   7387,
#   5,
#   132,
#   4,
#   15,
#   152,
#   575,
#   167,
#   185,
#   456,
#   507,
#   1,
#   6,
#   933,
#   874,
#   22],
#  [11, 14, 38, 214, 406, 1, 33, 1, 2, 356, 84, 5, 18, 1, 394, 579, 4, 166, 406],
#  [16, 66, 49, 9, 19, 255, 414, 115, 77, 6, 4],
#  [8, 96, 21, 3, 20, 54, 35],
#  [12, 14, 63, 4, 712, 421],
#  [16,
#   1,
#   1,
#   1,
#   204,
#   295,
#   1,
#   587,
#   61,
#   18,
#   1,
#   6,
#   7,
#   2,
#   213,
#   64,
#   429,
#   62,
#   44,
#   7388,
#   7389],
#  [8, 907, 110, 3, 658, 152, 1, 58, 4, 83, 203, 432, 2, 98],
#  [8,
#   1,
#   223,
#   6,
#   472,
#   40,
#   25,
#   72,
#   644,
#   139,
#   2,
#   1,
#   2,
#   85,
#   34,
#   9,
#   351,
#   6,
#   13,
#   7390],
#  [8, 18, 81, 13, 37, 106, 2, 129, 21, 2, 66, 121],
#  [12, 21],
#  [11, 96, 7, 9, 1, 37, 21, 3],
#  [16,
#   30,
#   26,
#   45,
#   121,
#   1,
#   39,
#   5,
#   553,
#   33,
#   1,
#   1,
#   34,
#   565,
#   41,
#   112,
#   547,
#   504,
#   13,
#   1,
#   145,
#   43],
#  [11, 14, 40, 38, 73, 247, 7, 13, 58, 5, 156, 5, 33, 18, 73, 1468, 40, 38],
#  [16, 24, 3, 200, 4, 24, 54, 3, 2, 185],
#  [8, 50, 31, 46, 19, 47, 124, 4, 207, 1661, 928],
#  [8, 54, 2280, 83, 9, 8, 127, 124, 4, 429, 146],
#  [17, 188],
#  [12,
#   1,
#   3,
#   15,
#   1,
#   3,
#   15,
#   87,
#   165,
#   4,
#   25,
#   60,
#   61,
#   213,
#   19,
#   3,
#   15,
#   20,
#   355,
#   4,
#   1,
#   2,
#   87,
#   135],
#  [8,
#   7391,
#   78,
#   394,
#   1,
#   14,
#   146,
#   228,
#   32,
#   22,
#   7392,
#   7393,
#   819,
#   18,
#   412,
#   25,
#   39,
#   1,
#   176,
#   1],
#  [16, 7, 555, 33, 1, 2, 55, 1, 2, 292, 310],
#  [11, 35, 3, 26, 56, 118, 1, 105, 6, 53, 9, 2, 1542],
#  [69, 85, 157, 78, 1, 624, 581, 148, 548, 52, 2598],
#  [8, 3, 15, 2, 86, 50, 120, 3, 77, 2, 2515],
#  [17, 14, 191, 1, 192, 32, 22, 1208, 7394, 3116, 7395],
#  [16,
#   23,
#   46,
#   1,
#   7,
#   286,
#   35,
#   37,
#   25,
#   99,
#   20,
#   93,
#   18,
#   134,
#   78,
#   10,
#   24,
#   2388,
#   18,
#   93],
#  [11,
#   12,
#   7396,
#   23,
#   10,
#   4,
#   1,
#   1053,
#   92,
#   226,
#   152,
#   6,
#   7,
#   42,
#   461,
#   30,
#   49,
#   2,
#   1,
#   2,
#   170],
#  [16, 2, 107, 792, 1, 44, 940, 119, 1, 812, 298, 167, 175, 9, 1476, 1, 6],
#  [12, 84, 1, 33, 35, 5, 117, 41, 117, 1, 2, 1005, 171],
#  [11, 194, 13, 10, 153, 2, 86, 66, 91],
#  [17, 390, 19, 122, 28, 1, 187, 435, 1, 2, 325, 23, 33, 429, 7],
#  [16, 182, 3, 15, 2590, 93, 40, 10, 3, 103, 174, 20, 6, 9, 3, 15, 27],
#  [11, 459, 608, 143, 60, 523, 1, 401, 106, 216, 4, 1, 125, 66, 243],
#  [12,
#   48,
#   116,
#   10,
#   1449,
#   1246,
#   24,
#   48,
#   6,
#   81,
#   106,
#   193,
#   2,
#   85,
#   7,
#   195,
#   107,
#   13,
#   1,
#   3,
#   155,
#   37],
#  [17,
#   2010,
#   54,
#   119,
#   9,
#   3,
#   1423,
#   4,
#   2,
#   2177,
#   10,
#   2,
#   119,
#   60,
#   18,
#   224,
#   2,
#   1077,
#   13],
#  [11,
#   2,
#   55,
#   1,
#   231,
#   329,
#   42,
#   9,
#   24,
#   18,
#   70,
#   1,
#   18,
#   1,
#   111,
#   7,
#   35,
#   26,
#   4,
#   285,
#   7],
#  [12, 52, 30, 18, 4, 212],
#  [39,
#   1,
#   90,
#   3,
#   423,
#   338,
#   6,
#   1,
#   192,
#   4,
#   25,
#   334,
#   29,
#   17,
#   14,
#   191,
#   1,
#   192,
#   32,
#   22,
#   215,
#   416],
#  [17, 262, 791, 105, 266, 1, 25, 9, 124],
#  [17, 139, 21, 20, 124, 63, 31, 180, 184, 2, 44],
#  [11, 63, 154, 285, 18, 67, 74, 19, 108, 108, 43, 198, 5, 154, 2902],
#  [12, 231, 561, 137, 201],
#  [8, 487, 129, 123, 516, 7397, 7398, 1796, 3078, 988, 143],
#  [12,
#   61,
#   18,
#   51,
#   6,
#   346,
#   451,
#   118,
#   25,
#   59,
#   105,
#   118,
#   61,
#   445,
#   51,
#   7,
#   32,
#   22,
#   7399],
#  [69,
#   319,
#   65,
#   25,
#   7,
#   5,
#   4,
#   6,
#   1,
#   26,
#   6,
#   1001,
#   112,
#   2,
#   85,
#   43,
#   157,
#   19,
#   101,
#   120],
#  [12, 11, 10, 3, 26, 284, 3, 97, 120, 14, 40, 38, 320, 78, 105, 118, 1325],
#  [9, 54, 12, 253, 54, 5, 3399, 9, 2, 72, 6, 381, 6, 258, 2271],
#  [12, 131, 77, 30, 15, 19, 18, 99, 219],
#  [11,
#   21,
#   5,
#   132,
#   4,
#   113,
#   46,
#   60,
#   2,
#   480,
#   13,
#   181,
#   1,
#   2,
#   7,
#   134,
#   5,
#   2,
#   29,
#   131,
#   32,
#   22,
#   2051,
#   6],
#  [8,
#   1516,
#   53,
#   95,
#   59,
#   83,
#   1,
#   656,
#   34,
#   1,
#   106,
#   1,
#   426,
#   50,
#   103,
#   49,
#   9,
#   14,
#   66,
#   79,
#   432],
#  [12,
#   13,
#   23,
#   7,
#   25,
#   13,
#   36,
#   71,
#   19,
#   1,
#   78,
#   26,
#   1,
#   4,
#   4,
#   81,
#   59,
#   45,
#   84,
#   5,
#   63],
#  [11, 21, 5, 132, 166, 137, 201, 67, 6, 1, 1081, 15, 5, 115],
#  [12, 34, 196, 3, 24, 316, 293],
#  [11,
#   65,
#   93,
#   10,
#   3,
#   122,
#   18,
#   295,
#   2,
#   78,
#   1,
#   2,
#   6,
#   45,
#   121,
#   1,
#   498,
#   1,
#   35,
#   121,
#   1,
#   389,
#   5,
#   126],
#  [12, 21],
#  [17, 15, 28, 1722, 5, 2, 7400, 3321, 32, 22, 964],
#  [8, 4, 89, 6, 2, 294, 9, 6, 20, 2, 90, 49],
#  [12, 21, 3, 6, 52, 188, 29, 326, 32, 22, 7401, 7402],
#  [16,
#   333,
#   1815,
#   426,
#   48,
#   233,
#   89,
#   101,
#   23,
#   15,
#   387,
#   100,
#   4,
#   103,
#   101,
#   13,
#   79,
#   744],
#  [8, 258, 4, 101, 1, 202, 1, 1, 84, 5, 130, 147, 1573, 20, 84],
#  [8, 6, 45, 3424, 7403, 91, 74, 6, 884, 461, 20, 103, 26, 49, 8, 91, 79],
#  [17, 9, 15, 41, 1, 37, 1410, 4, 90],
#  [19, 1, 78, 8],
#  [8, 2, 86, 66, 1, 2, 415],
#  [12, 18, 14, 18, 80, 15, 1366, 361, 40, 13, 1, 2065, 10, 307, 1934],
#  [8, 9, 1, 789, 696, 105, 614, 190, 113, 1, 922, 1, 1844, 751, 7, 526, 486],
#  [11,
#   88,
#   35,
#   1713,
#   322,
#   177,
#   53,
#   2,
#   28,
#   128,
#   578,
#   6,
#   169,
#   569,
#   797,
#   32,
#   22,
#   1571,
#   7404],
#  [8, 3420, 8, 1, 35, 311, 32, 22, 7405],
#  [8, 1999, 43, 46, 802, 1, 2, 352, 224, 147, 138, 2, 1999, 46],
#  [12,
#   88,
#   1,
#   262,
#   94,
#   5,
#   164,
#   1,
#   1,
#   74,
#   26,
#   51,
#   10,
#   115,
#   5,
#   14,
#   1101,
#   66,
#   67,
#   6,
#   3,
#   50],
#  [8,
#   1084,
#   72,
#   14,
#   767,
#   88,
#   80,
#   1423,
#   3,
#   28,
#   14,
#   183,
#   72,
#   37,
#   115,
#   128,
#   32,
#   22,
#   7406,
#   7407],
#  [8,
#   79,
#   75,
#   9,
#   24,
#   63,
#   18,
#   6,
#   560,
#   774,
#   4,
#   43,
#   294,
#   20,
#   85,
#   48,
#   157,
#   250,
#   76,
#   133,
#   62],
#  [12,
#   263,
#   347,
#   3339,
#   9,
#   135,
#   9,
#   7408,
#   20,
#   56,
#   2,
#   415,
#   52,
#   2,
#   436,
#   10,
#   702,
#   9,
#   1,
#   49,
#   9],
#  [8, 2, 27, 4, 97, 27, 5, 361, 40, 1, 30, 97, 18, 173, 5, 817],
#  [16, 52, 18, 429, 493, 72, 3, 172, 25, 5, 2, 7],
#  [69,
#   2,
#   1,
#   120,
#   5,
#   132,
#   118,
#   149,
#   34,
#   1,
#   278,
#   90,
#   60,
#   51,
#   66,
#   15,
#   368,
#   156,
#   9,
#   50,
#   701,
#   4],
#  [12, 89, 14, 309, 39, 132, 5, 332, 1587, 42, 7409, 1716],
#  [8,
#   2080,
#   162,
#   129,
#   149,
#   126,
#   4,
#   1858,
#   5,
#   162,
#   2189,
#   65,
#   26,
#   520,
#   31,
#   529,
#   1,
#   1,
#   9,
#   20,
#   2,
#   3283,
#   114],
#  [8,
#   7410,
#   1,
#   2,
#   129,
#   1,
#   3,
#   123,
#   263,
#   2,
#   4,
#   1,
#   464,
#   9,
#   51,
#   1587,
#   196,
#   49,
#   9,
#   2,
#   79,
#   1],
#  [11,
#   1,
#   277,
#   218,
#   31,
#   1226,
#   23,
#   4,
#   444,
#   401,
#   31,
#   4,
#   113,
#   1,
#   6,
#   4,
#   224,
#   1,
#   314,
#   1,
#   31,
#   180,
#   103,
#   224,
#   1],
#  [8, 9, 19, 118, 87, 18, 1, 7],
#  [8, 41, 1, 176, 97, 48, 428],
#  [8, 41, 1, 37, 15, 24, 424, 126, 5],
#  [17,
#   9,
#   65,
#   3,
#   272,
#   82,
#   9,
#   54,
#   98,
#   19,
#   2,
#   305,
#   10,
#   798,
#   1,
#   2125,
#   698,
#   32,
#   22,
#   7411,
#   3117],
#  [11, 388, 1, 7, 2, 81, 66, 21, 3, 214, 11, 220, 25, 8, 5, 44, 137, 4, 68, 6],
#  [16, 62, 24, 26, 2, 23, 83, 5, 4, 1, 27, 260, 308, 32, 22, 7412, 7413],
#  [17, 7414, 1, 161, 18, 22],
#  [17, 155, 418, 87, 1987, 43, 56, 235, 977, 75, 2059, 111, 32, 22, 2011, 7415],
#  [16, 21, 3, 78, 138, 824, 1, 281, 59, 4, 4, 981],
#  [16, 23, 130, 464, 9, 167, 130],
#  [17,
#   1,
#   465,
#   2,
#   151,
#   185,
#   1,
#   89,
#   52,
#   424,
#   2,
#   237,
#   471,
#   126,
#   13,
#   1,
#   57,
#   14,
#   1,
#   133],
#  [16, 101, 3, 10, 354, 109, 54, 24, 81, 7, 42, 2, 135, 441],
#  [69,
#   24,
#   113,
#   1,
#   29,
#   46,
#   14,
#   183,
#   1,
#   226,
#   59,
#   15,
#   288,
#   1608,
#   1,
#   148,
#   32,
#   22,
#   7416],
#  [12,
#   21,
#   19,
#   6,
#   940,
#   1,
#   67,
#   2,
#   1168,
#   438,
#   15,
#   41,
#   116,
#   165,
#   274,
#   29,
#   10,
#   1,
#   229,
#   189],
#  [8,
#   4,
#   30,
#   15,
#   1,
#   259,
#   1,
#   13,
#   1898,
#   19,
#   39,
#   2,
#   434,
#   2,
#   13,
#   7417,
#   53,
#   5,
#   3,
#   272,
#   29,
#   7418],
#  [8, 21, 5, 323, 14, 119, 23, 1, 6, 47, 155, 7, 182],
#  [12, 240, 213, 134, 94, 321, 216, 4, 5, 824, 169, 67, 227, 95],
#  [8,
#   14,
#   38,
#   61,
#   128,
#   113,
#   3,
#   6,
#   1397,
#   88,
#   40,
#   38,
#   105,
#   23,
#   1,
#   7419,
#   32,
#   22,
#   7420],
#  [8, 7, 39, 36, 71, 6, 289],
#  [12,
#   3,
#   1064,
#   288,
#   7,
#   5,
#   171,
#   63,
#   74,
#   95,
#   15,
#   4,
#   77,
#   1110,
#   1,
#   2,
#   76,
#   1,
#   316,
#   1,
#   514,
#   9],
#  [11, 21, 3],
#  [17, 1, 112, 26, 7, 445, 25, 1, 286, 607, 1, 2, 7],
#  [11,
#   273,
#   235,
#   5,
#   73,
#   728,
#   51,
#   20,
#   76,
#   87,
#   74,
#   1,
#   95,
#   2,
#   452,
#   55,
#   788,
#   6,
#   393,
#   344,
#   15],
#  [8,
#   3,
#   10,
#   1281,
#   60,
#   7,
#   1284,
#   15,
#   117,
#   783,
#   41,
#   15,
#   23,
#   10,
#   117,
#   255,
#   213,
#   4,
#   725],
#  [16, 13, 652, 6, 2, 27, 7, 38, 59, 91, 6],
#  [12,
#   52,
#   126,
#   4,
#   48,
#   18,
#   98,
#   312,
#   1113,
#   1,
#   603,
#   25,
#   85,
#   34,
#   374,
#   1191,
#   48,
#   5,
#   98,
#   1,
#   145],
#  [8,
#   9,
#   112,
#   96,
#   25,
#   2493,
#   29,
#   19,
#   3,
#   3,
#   97,
#   27,
#   56,
#   1651,
#   32,
#   22,
#   173,
#   7421,
#   120,
#   3235],
#  [8, 615, 735, 10, 7, 182, 244, 27, 7422, 73, 4],
#  [8, 13, 7, 3, 10, 202],
#  [11, 1, 500, 13, 148, 15, 3425, 452, 165, 205, 478, 7423],
#  [12, 1, 860, 3, 47, 37, 34, 79],
#  [11, 60, 3, 59, 28, 18, 41, 30, 59, 28, 580, 663],
#  [17, 20, 84, 5, 46, 5, 7, 105, 1, 33, 28],
#  [17, 319, 9, 99, 1, 32, 22, 6, 7424],
#  [17,
#   65,
#   49,
#   963,
#   22,
#   78,
#   2,
#   122,
#   7425,
#   1,
#   2,
#   7426,
#   10,
#   7427,
#   1,
#   837,
#   10,
#   3,
#   1387,
#   260],
#  [16, 112, 184, 3, 20, 288, 851, 6, 15, 364, 27, 7428],
#  [16, 50, 27, 313, 102, 1, 1, 1, 40, 532, 56, 243, 1, 52, 13, 300, 43, 40, 38],
#  [11,
#   35,
#   6,
#   278,
#   1,
#   237,
#   1409,
#   1,
#   10,
#   2,
#   254,
#   173,
#   1,
#   74,
#   2,
#   36,
#   71,
#   2,
#   7,
#   41,
#   13,
#   1],
#  [16, 387, 887, 51, 5, 9, 2, 15, 1111],
#  [11, 5, 145, 1, 1, 21],
#  [17, 93, 101, 9, 19, 26, 294, 9, 34, 10, 14, 55, 198, 1, 341],
#  [8, 115, 4, 1571],
#  [8, 8, 1080, 48, 53, 5, 345, 653, 4, 1, 33, 7, 319, 7429, 7430],
#  [17, 1, 48, 466, 13, 54, 48, 2, 7, 31, 58],
#  [8, 728, 6, 146, 25, 429, 104, 786, 1, 429, 6, 66],
#  [16, 54, 106, 26, 3391, 207, 981, 9, 4],
#  [12,
#   7431,
#   39,
#   48,
#   163,
#   2,
#   865,
#   23,
#   2,
#   46,
#   1,
#   2,
#   55,
#   2,
#   36,
#   7,
#   2,
#   7,
#   60,
#   2,
#   1125],
#  [11, 7, 2046, 213, 1085, 508, 7, 5, 757, 32, 22, 7432],
#  [69, 41, 689, 74, 10, 135, 105, 75, 1, 795, 429, 146],
#  [11,
#   397,
#   30,
#   15,
#   67,
#   415,
#   489,
#   181,
#   1,
#   2,
#   161,
#   10,
#   680,
#   116,
#   149,
#   1,
#   1915,
#   62,
#   122,
#   3,
#   44,
#   9,
#   149],
#  [12, 62, 4],
#  [11, 34],
#  [16, 54],
#  [16, 52, 24, 18, 83, 5, 505, 334, 467, 52],
#  [8, 21, 3],
#  [16, 125, 96, 7, 25, 129, 23, 286, 297, 21],
#  [8, 5, 2964, 13, 1324, 49, 863, 7433, 3, 15, 2, 86],
#  [12,
#   4,
#   14,
#   38,
#   1,
#   7434,
#   121,
#   14,
#   18,
#   80,
#   1264,
#   143,
#   1,
#   6,
#   45,
#   144,
#   296,
#   74,
#   30,
#   28,
#   41],
#  [11,
#   33,
#   37,
#   427,
#   14,
#   66,
#   43,
#   1,
#   137,
#   250,
#   1845,
#   5,
#   321,
#   884,
#   3,
#   15,
#   14,
#   40,
#   77,
#   816],
#  [17, 93, 14, 7, 19, 41, 188, 4, 37, 573],
#  [17, 90, 148, 787, 143, 1, 50, 300, 1195, 1196, 321, 32, 22, 7435],
#  [16, 501, 253, 27, 2, 27, 66],
#  [16, 23, 188, 6, 889, 19, 6, 175, 24, 27, 2, 85, 34, 9, 6, 42, 1, 7],
#  [12, 1112, 110, 2262, 86],
#  [11,
#   74,
#   603,
#   26,
#   45,
#   1,
#   7,
#   9,
#   2,
#   822,
#   1,
#   73,
#   49,
#   25,
#   1,
#   505,
#   22,
#   39,
#   48,
#   3291,
#   294],
#  [12, 21, 13, 33, 28, 686, 95, 164, 157, 1, 41, 9, 20, 2, 171, 135, 37, 4],
#  [12,
#   2,
#   10,
#   872,
#   1,
#   13,
#   1560,
#   1,
#   600,
#   2,
#   452,
#   487,
#   1,
#   4,
#   51,
#   37,
#   1465,
#   2,
#   7,
#   129,
#   125,
#   600,
#   3],
#  [11, 30, 24, 44, 3, 30, 1, 187, 118, 53, 1, 164, 60, 3, 7, 79, 309],
#  [16, 1, 55, 5, 64, 1, 95, 30, 219, 75, 70],
#  [8,
#   26,
#   510,
#   9,
#   3,
#   4,
#   1,
#   2,
#   23,
#   3,
#   10,
#   7,
#   26,
#   45,
#   58,
#   516,
#   48,
#   1,
#   136,
#   1,
#   49,
#   8],
#  [16, 111, 275, 7, 5, 859, 1631, 25, 186, 87, 1076, 271, 75, 43],
#  [11,
#   33,
#   1,
#   57,
#   6,
#   13,
#   5,
#   31,
#   100,
#   92,
#   668,
#   127,
#   77,
#   4,
#   1,
#   187,
#   4,
#   68,
#   1,
#   57,
#   5,
#   2,
#   23,
#   92],
#  [16, 61, 44, 9, 7, 269, 512],
#  [11,
#   64,
#   13,
#   25,
#   112,
#   43,
#   1178,
#   757,
#   130,
#   47,
#   213,
#   4,
#   112,
#   26,
#   28,
#   68,
#   23,
#   88,
#   382,
#   53,
#   60,
#   213],
#  [17, 24, 673, 4, 1463, 81, 4, 5, 7, 109, 24, 3, 131, 1, 6],
#  [17, 9, 24, 7436, 14, 1721, 32, 22, 7437, 59, 7438, 1, 93],
#  [16,
#   15,
#   2665,
#   6,
#   2,
#   926,
#   2904,
#   207,
#   29,
#   168,
#   15,
#   989,
#   328,
#   13,
#   2,
#   1479,
#   575,
#   1,
#   56,
#   601,
#   4],
#  [8,
#   30,
#   15,
#   87,
#   28,
#   5,
#   13,
#   5,
#   132,
#   2247,
#   298,
#   5,
#   590,
#   65,
#   3,
#   44,
#   3,
#   2248,
#   920],
#  [8,
#   18,
#   1123,
#   143,
#   173,
#   51,
#   2540,
#   7439,
#   1574,
#   205,
#   138,
#   7,
#   173,
#   32,
#   22,
#   7440,
#   6],
#  [12,
#   67,
#   2,
#   18,
#   1,
#   7,
#   5,
#   1,
#   33,
#   42,
#   385,
#   153,
#   47,
#   9,
#   1356,
#   324,
#   1,
#   265,
#   10,
#   385,
#   268,
#   27,
#   560],
#  [16,
#   50,
#   3,
#   62,
#   29,
#   615,
#   38,
#   3,
#   10,
#   1577,
#   1,
#   7441,
#   51,
#   88,
#   26,
#   381,
#   64,
#   42,
#   3],
#  [11,
#   3,
#   47,
#   124,
#   3,
#   164,
#   29,
#   10,
#   24,
#   3,
#   31,
#   711,
#   116,
#   5,
#   132,
#   2,
#   119,
#   22,
#   26,
#   83],
#  [11, 6, 2, 86, 40, 38, 26, 91, 6, 201, 42, 19, 4, 234, 1, 1, 179, 261, 4],
#  [16,
#   15,
#   1715,
#   158,
#   218,
#   1,
#   128,
#   20,
#   1,
#   57,
#   72,
#   5,
#   1466,
#   381,
#   88,
#   48,
#   81,
#   451,
#   49],
#  [12, 11, 61, 36, 7, 7, 168, 274, 94, 15, 3, 148, 56, 211],
#  [16, 188, 60, 49, 13, 7442],
#  [12,
#   8,
#   137,
#   3,
#   169,
#   30,
#   61,
#   27,
#   6,
#   1,
#   698,
#   1,
#   134,
#   36,
#   460,
#   447,
#   978,
#   5,
#   606],
#  [8,
#   21,
#   5,
#   1,
#   488,
#   4,
#   347,
#   7,
#   279,
#   6,
#   224,
#   46,
#   95,
#   36,
#   460,
#   7,
#   1230,
#   4,
#   48,
#   125,
#   64,
#   31,
#   180],
#  [12,
#   24,
#   3,
#   437,
#   4,
#   212,
#   237,
#   231,
#   13,
#   33,
#   1,
#   57,
#   20,
#   255,
#   45,
#   148,
#   405,
#   2,
#   107],
#  [16,
#   10,
#   3,
#   93,
#   78,
#   15,
#   886,
#   18,
#   1332,
#   19,
#   2106,
#   117,
#   29,
#   14,
#   207,
#   2078,
#   106,
#   32,
#   22,
#   2107,
#   2108],
#  [11, 1, 277, 295, 6, 43, 114, 65, 77, 27, 267, 608, 5, 288, 7],
#  [11,
#   36,
#   71,
#   7,
#   212,
#   105,
#   1,
#   34,
#   80,
#   463,
#   216,
#   3,
#   122,
#   59,
#   631,
#   6,
#   34,
#   162,
#   32,
#   22,
#   43,
#   1405],
#  [17, 39, 23, 225, 742, 14, 706],
#  [11, 96, 39, 198, 14, 712, 76, 133, 1, 2, 276, 53, 1, 4],
#  [11, 59, 45, 1, 57, 5, 1, 39, 87, 81, 140],
#  [12,
#   36,
#   71,
#   7,
#   1,
#   185,
#   4,
#   1,
#   24,
#   85,
#   216,
#   43,
#   76,
#   19,
#   24,
#   18,
#   152,
#   1,
#   80,
#   1324,
#   49],
#  [12, 21],
#  [8, 656, 4, 659, 2, 305, 59, 5, 2, 5, 4, 1, 809, 74, 232],
#  [16, 122, 3, 160, 4, 10, 1, 197, 15, 234, 1, 7, 3, 10, 23, 109, 170],
#  [8, 20, 87, 18, 157, 662, 3, 1, 3, 26, 4, 428, 68],
#  [16,
#   43,
#   339,
#   6,
#   41,
#   1,
#   4,
#   334,
#   2,
#   493,
#   1,
#   303,
#   4,
#   1,
#   31,
#   7,
#   134,
#   1096,
#   6,
#   5,
#   41],
#  [12, 75, 21, 6, 30, 126, 339, 5, 18, 171],
#  [12, 7443, 1, 156, 3, 29, 10, 26, 299, 157, 3, 20, 88, 811],
#  [8,
#   52,
#   24,
#   3,
#   1,
#   89,
#   72,
#   13,
#   33,
#   10,
#   3,
#   67,
#   1,
#   2,
#   55,
#   9,
#   1,
#   46,
#   70,
#   31,
#   2,
#   55,
#   914],
#  [17, 113, 62],
#  [17, 9, 401, 3, 39, 98, 141, 312, 34, 10, 231, 720, 79, 1, 6, 78, 190, 289],
#  [17,
#   1350,
#   6,
#   139,
#   104,
#   34,
#   10,
#   14,
#   602,
#   220,
#   1272,
#   1,
#   44,
#   1139,
#   979,
#   3,
#   15,
#   34,
#   10,
#   2,
#   28,
#   34],
#  [11,
#   7444,
#   15,
#   108,
#   42,
#   19,
#   60,
#   4,
#   18,
#   547,
#   63,
#   1,
#   15,
#   578,
#   56,
#   13,
#   33,
#   1,
#   57,
#   5,
#   92,
#   256,
#   49],
#  [11, 24, 1, 3411, 1, 438, 4, 350, 95, 2, 6, 12, 715, 5, 375, 333, 7445, 2234],
#  [16, 7, 195, 107, 20, 31, 7, 771, 135, 2, 3, 354, 275, 7, 483],
#  ...]

# %%
X_test = pad_sequences(X_test,padding = 'post', maxlen =max_len)
X_test
# Out:
# array([[ 12,  61, 189, ...,   0,   0,   0],
#        [ 11,  72,  36, ...,   0,   0,   0],
#        [ 17,  21, 110, ...,   0,   0,   0],
#        ...,
#        [ 16,  39,   6, ...,   0,   0,   0],
#        [ 12,   9, 337, ...,   0,   0,   0],
#        [ 12,  52,  24, ...,   0,   0,   0]], dtype=int32)

# %%
sentiment_Test = np.array(list(map(lambda x:"positive" if x== "1" else ("negative" if x == 0 else "neutral"), sentiment_Test)))

# %%
dataTest['Predicted airline_sentiment'] = sentiment_Test

df_prediction_sentiments = pd.DataFrame(dataTest['Predicted airline_sentiment'], columns = ['Predicted airline_sentiment'])
df_tweetid                 = pd.DataFrame(dataTest['tweet_id'], columns = ['tweet_id'])
df_text           = pd.DataFrame(dataTest['text'], columns = ['text'])
df_airline_sentiment           = pd.DataFrame(dataTest['airline_sentiment'], columns = ['airline_sentiment'])


dfx=pd.concat([df_tweetid, df_text,df_airline_sentiment, df_prediction_sentiments],axis =1)

dfx.head(5)
# Out:
#              tweet_id                                               text  \
# 0  570252000000000000                        @AmericanAir I need refund.
# 1  568173000000000000  @USAirways after 3 Cancelled Flightlations and...
# 2  569321000000000000  @JetBlue thanks so much. Can't wait to fly wit...
# 3  569503000000000000  @united I have never been more frustrated than...
# 4  568981000000000000  @USAirways - the worst! Hold time crazy, agent...
#
#   airline_sentiment Predicted airline_sentiment
# 0          negative                    negative
# 1          negative                    negative
# 2          positive                     neutral
# 3          negative                    negative
# 4          negative                    negative

# %%
# Out:
# 'n'
